# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from scipy.spatial.distance import cosine
from collections import Counter
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem.snowball import SnowballStemmer
import re
from geopy.geocoders import Nominatim

# %%
df = pd.read_csv('../data/all_df')
df_cities = pd.read_csv("../data/us_cities.csv")
us=df[df['country'] == 'us']

# %%
for i in us.job_description:
    print i
    print '**************************************'
# Out:
# Conceptualize, design and build data-fueled products to help the company improve our proprietary industry analytics and customized reporting in service to our diverse customer base. Work with cross-functional team members to identify and prioritize actionable, high-impact analyses across a variety of core industry areas Understand the information needs of industry stakeholders and work closely with the data team to ensure New Frontier has the necessary data to achieve the intended analysis and outcomes Develop expertise in cannabis industry data sets Assess New Frontiers existing data, and identify potential data gaps Coordinate with the research team to identify and prioritize new data sources Develop ingestion and quality control protocols to ensure timely incorporation of all new datasets into New Frontiers data platform equio Provide insight into leading analytic practices and identify ways to incorporate into New Frontier operations Produce new and creative analytic solutions that will become part of New Frontiers core deliverables Research, design, implement, and validate leading-edge algorithms to analyze diverse data sources and achieve targeted outcomes Inspire the adoption of creative analytics and data solutions Work closely with our sales and marketing teams to help articulate the value and impact of the analytics to our stakeholder groups PhD or Masters Degree in operations research, applied statistics, data mining, machine learning, physics or a related quantitative discipline 5+ years of experience delivering world-class data science outcomes Deep understanding of statistical and predictive modeling concepts, machine-learning approaches, clustering and classification techniques, and recommendation and optimization algorithms Ability to solve complex analytical problems using quantitative approaches with a unique blend of analytical, mathematical and technical skills Highly detailed-oriented and exceptional organizational and follow-through skills a must Passion for using large datasets to answer complex business problems, and unveil evolving industry trends Expertise analyzing large, complex multi-dimensional datasets with a variety of tools such as R, MATLAB, SAS or SPSS Experience with BI tools such as Tableau, Cognos or MicroStrategy Understanding of and experience managing relational databases NoSQL/JSON data formats Familiarity with SQL, Python, Java, JavaScript, PHP/HTML, and C/C++ preferred Experience with Social Media analytics is a plus Excellent judgment and creative problem solving skills Entrepreneurial team player who can multitask Superior management skills Self-reliant, good problem solver, results oriented Energetic, flexible, collaborative, and proactive; a team player Exceptional written, oral, interpersonal, and presentation skills and the ability to effectively interface with senior management and staff Ability to operate as an effective tactical as well as strategic thinker Commensurate with experience Stock Incentive Plan Comprehensive benefits package No relocation package
# **************************************
# 2 years of industry experience in a Data Science role Ability to illuminate complex problems with data analysis Proven product success derived from research and analysis results Familiarity with Hadoop, Map/Reduce and NoSQL databases Strong facility with one of Matlab, R or similar tool Experience with Classifiers, Maximum Likelihood Estimation, Probabilistic Graphical Models Comfortable in a programming language like Python or Go Experience with Search is a plus
# **************************************
# Are you passionate about solving interesting and challenging big data problems? Do you have experience and interest in working with big data to solve interesting business problems using large-scale analytics and algorithms? If yes, you could be a great fit for this role with the Data Science team at Groupon A passion for building data driven products and working with big data  Proficiency with distributed computing and large-scale data
# **************************************
# BS in Computer Science, Engineering or Statistics. 5 plus years of experience Extensive experience solving Big Data analytic problems using quantitative approaches and a proven passion for generating insights from data. Experience in manipulating and analyzing complex, high-volume (large data sets), high-dimensionality data from varying sources. Present as part of customer sales presentations, putting forward Big Data domain specific information within the context of HP sales campaign. Strong knowledge of statistical methods generally, and particularly in the areas of modeling and business analytics. Experience with Statistical modeling and data scoring a plus Advanced research in machine learning and data analytics. Also design and develop data model prototypes for customer proof of concept Experience with ETL tools like Talend, Pentaho, Informatica. Exposure to databases such Hadoop, Greenplum, Netezza, AsterData, Paracel, Exadata a plus. Experience integrating with enterprise BI platforms such as Spotfire, Tableau, QlikView, MicroStrategy, Business Objects, Cognos, etc&hellip; Experience developing custom database functions (user defined functions) using Java,C++ and /or R Vertica Certification from Vertica
# **************************************
# Following requirements/skills are necessary:  - Proven track record of quickly learning new things and producing results  - Curious, Open minded, healthy self critical approach  - Strong written and verbal communication skills;  - Strong in statistical and analytical skills;  - Strong in problem solving skills;  - High level of independence and initiative proven track records of driving changes & solutions  - Having the ability to query databases and perform statistical analysis;  - Being able to advise senior management in clear language about the implications of their work for the organization;  - Being able to create examples, prototypes, demonstrations to help management better understand the work
# **************************************
# Leverage a strong background in mathematics, statistics, data mining, or computer science, to extract value from internal and external data Help our users spend, save and live smarter, with predictions built using machine-learning techniques to do pattern recognition, and apply concepts of learning theory Design rich data visualizations to communicate complex ideas to Moven users Utilize open-source software and functional languages to perform data munging and coalesce data into ready for consumption data Using a wide array of skills, form and test hypotheses, solving complex business problems Drive creative value using appropriate analytical and software solutions (predictive models, visualizations, insights) to evaluate hypotheses and improve strategic decision-making Be Agile by demonstrating the value potential data through the application of core Data Science principles and skills Shut out the industry by researching new techniques and technologies to stay ahead of the curveon advanced analytic and predictive capabilities Write software and code that puts your idea in front of a customer Serious bonus points if youve won a Kaggle competition Be ready to do what it takes to make data awesome at Moven Inquisitive: You want to know why, diving into the unknown is fun. You blurt out your preposterous ideas because youre that excited about them. Analytical: You hack your phone. You took apart your computer, and upgraded the components. Calculus is cool. Passionate about Data: Youre fascinated by data, structuring it, cleaning it, and understanding the human and financial behaviors it represents. Unstructured problems and big data sets dont faze you. Youre too busy searching for root causes. Action-Oriented: You want to act, not wait - get something done, and add value. Youll attempt to teach an old dog new tricks. You expect to sometimes fail, but you know you learn from it. Bold: Big, undefined problems are what get you up in the morning. Solutions wake you up from a deep sleep; you have to keep a pad near your nightstand. Idealistic: You get excited about the idea of helping people. Movens strategy to help people live, spend and save smarter speaks to you, aligning with your core values. Masters Degree or BS Major with at least 4 years experience, in a quantitative discipline or similar: Statistics, Quantitative Analysis, Computer Science, Mathematics / Applied Mathematics, Operations Research / Decision Sciences, Economics, Engineering, Physics, etc. PhD preferred. Extensive experience with relational databases and SQL experience in a Unix/Linux environment Experience in unstructured or Big Data strongly preferred (preferably MongoDB) and MapReduce Extensive experience working with SAS, Weka, MATLAB/Octave, R or some other statistical analysis package Experience with an object-oriented programming language (e.g., Java, C++, Python, Ruby) or Functional/Procedural programming language (C, Perl, JS), preferably Javascript Experience with machine learning or advanced statistical methods Able to simply explain complex information to both technical and non-technical audiences Its preferred you also have experience with statistical sampling, simulations, and optimization Experience with advanced data visualization techniques is a plus, preferably using D3 Experience with advanced statistical / econometric / machine learning methods, such as: GLMs, Principal Components, Clustering, Time Series Analysis, Forecasting, Survival / Duration Analysis, Mixed Methods, Singular Value Decomposition, Decision Trees, KNN, SVMs, Random Forests, Boosting would put you ahead of the pack
# **************************************
# Create enterprise-level entity matching engine through algorithm and/or data rules. Create data derivation and linkage through algorithm and/or data rules. Create and select predictive features from raw data. Create model reports for stakeholder review and model documentation. Perform pattern recognition model creation and training using various types of algorithms and machine learning modeling techniques for unknown or less well-defined - an unknown problem, solve new problems (e.g., scorecards, logistic regression, neural networks, CART, support vector machines, boosting trees, unsupervised models). Develop analytics tool using SQL, R, Java, Perl, Python and big data tools such as Jaspersoft BI Suite, Talend Open Studio, Skytree Server, Tableau, and Splunk. Develop analytics solutions using traditional database technology such as SQL and big data technology such as Hadoop, MongoDB, Cassandra, Redis, Riak, CouchDB, and Neo4j, NoSQL databases. Perform complex data analysis on large volumes of property and consumer data and present model performance to stakeholders. Provide data science and analytic support for the Enterprise Data Group (EDG), and interact with other EDG teams as well as other business units. QA and analyze large amounts of data to create appropriate data sets for model building. Prepare and maintain programs and documentation for analytic models. Conduct defined quantitative and qualitative research projects independently and communicates research results to internal and external stakeholders. Act as a consultant to EDG's data management and data technology teams Master's or higher in machine learning, a hard science, math, statistics or an engineering field, or equivalent work experience. Ability to thrive in a team environment and adapt to quickly changing priorities. 4-8 years of directly related experience. Strong problem solving and analytical ability. Strong communication skills. Ability to quickly and efficiently adapt to new concepts. Demonstrated knowledge of statistical techniques. Strong working knowledge in multiple analytic development tools, statistical tools, programming languages, and big data tools. Data mining/data analysis experience. Ability to work collaborative with cross-function teams and business units. Demonstrated general business acumen; experience working in a real estate and mortgage related data industry a plus.
# **************************************
# Senior Data Scientist   Looking for 5-10 years of professional experience as a Data Scientist NLP Specialist   - Candidates must have expereince and depth of knowledge in a topic that will be relevant for this group Some of these topics are mentioned about, of course, there are many other areas of expertise that would be highly sought-after - Candidate must live and breath NLP and be able to apply deep learning and cutting edge research on new classification algorithms to big problems - Strong communication skills Preferred -  - PhD in Machine Learning/NLP  - Experience working at IBM's Watson Lab or similar group Data Scientist Roles-  - Candidates must have strong data science skills (general)
# **************************************
# Be responsible for architecting, planning, and delivery of engineering components Partner to data scientists on solving technical challenges Architect and build data pipelines and data stores specialized for data science needs Standardize and build tools for use across the data science team Build, automate and deploy specialized research environments Design and implement systems for large-scale data analysis and machine learning Optimize code and design architecture to streamline data science processes Define and implement best practices and development processes Partner with engineering teams on deployments of data science driven solutions Participate in training and mentoring of data engineers 5+ years of experience in software engineering Excellent interpersonal and communication skills Strong hands-on Java coding Superb understanding of algorithms, scalability and various tradeoffs in a Big Data setting In-depth understanding of object oriented programming concepts Expertise in using Hadoop (e.g., MR, HBase, Hive, Pig, Impala) and/or MPP databases (e.g., RedShift, Netezza, Vertica, Greenplum) for complex data assembly and transformation Solid knowledge of database technology, SQL, schema design and query optimization techniques Understanding of full software development life cycle, agile development and continuous integration Expertise with version control systems, especially with Git Deep experience working in Unix/Linux environment A graduate degree in a quantitative discipline Digital advertising or web technology experience Experience with high performance key-value stores Expertise working with public cloud deployments (Amazon, Google CE or other) Exposure to parallel analytics platforms (e.g., Spark, H2O) Experience implementing machine learning algorithms Programming experience with Python or Scala Familiarity with R or Matlab
# **************************************
# Fluent with English, tech slang, startup slang, pop-culture and colloquialisms A lover of technology; you keep up on the latest of everything in tech Technical enough to get the subjects of data and analytics....so much so that you have developed the respect of technical audiences through your written communications A background in analytics, big data, data science, data engineering, cloud services, software/app development. Write blogs Assist others with their blogs, presentations, etc Research for articles, including self-guided online research as well as talking with internal and external subject matter experts. Please send us links to some of the content you've written so we can see you in action. All the better if youve written for/about enterprise software products.
# **************************************
# Responsibilities: Work with large amounts of data to identify opportunities that would help improve the experience that Zynga provides to the users Apply predictive modeling and Data Mining techniques for a variety of user modeling tasks within Zyngas Game Network Work closely with game teams to design, test, verify and implement statistical models with Zyngas games that impact the daily life of millions of users Design and evaluate novel approaches to experiments for gameplay Requirements: Obtaining a degree in Computer Science, Math, Statistics, Economics, or other quantitative field; Masters or PhD strongly preferred Experience with some or all of the following: data mining, predictive modeling, statistics, experimental design, computational analytics, econometric modeling Fluent in SQL Fluent in some or all of the following: SAS, STATA, R, Python, C++ Experience working with large datasets, preferably in a Hadoop environment Ability to work independently to get an idea from inception to implementation, including knowledge of techniques for validation and testing Strong written and oral communication skills Ability to work effectively in a fast-paced environment with changing priorities Ability to collaborate effectively with engineers, product managers, analysts, business, and marketing functions Strong business acumen
# **************************************
# Building out a team of strong machine learning data engineers as well as managing their day to day responsibilities Work closely with our VP, Engineering to set strategic initiatives, goals and metrics Performing research and develop sophisticated recommendations, personalization, and search engines. Performing data mining, machine learning, and information retrieval techniques on very large data sets. Using distributed big data storage and processing tools like Hadoop, MapReduce and Spark. Working on products which serve millions of users every day. Studying image recognition/understanding, performing natural language processing and sentiment analysis, discovering trending memes, modeling user behaviors, and much more. Exploring future data-driven products. PhD or Masters in Computer Science or related discipline focusing on machine learning, information retrieval, computer vision, natural language processing, and related areas. Minimum of 4 years of relevant experience working on search relevancy, personalization/recommender systems, big data, and related areas. Experience leading a team of data engineers Expert in supervised, unsupervised, and reinforcement learning techniques. Have ready knowledge of linear regression, support vector machines, logistic regression, clustering, decision trees, multi-layer perceptron, belief nets, genetic algorithms, etc. Expert in scientific and systems programming languages such as: Java, Python, R, etc. Expert in big data computing frameworks like Spark, Pig, or MapReduce. Familiar with open source machine learning packages like Spark MLlib, NumPy, Pandas, scikit-learn, Weka, Mahout, etc. Working knowledge of SQL.
# **************************************
# Partner with the leadership team to identify and execute on high-impact opportunities to leverage our extensive data, and integrate Data Scientists into department and product roadmaps Lead a team of high performing data scientists, reaching across multiple functions (e.g. Product Management and Data Engineering) to implement models into production Present to high-level business stakeholders stories that tell cohesive, logical stories about the value and uses of Data Science 2+ years of experience managing a high-performing Data Science team. It's a plus if that Data Science team contributed to product development. Expertise working with large, complex SQL and NoSQL database infrastructure Solid understanding of statistics and common machine learning techniques A Master's degree in statistics, math, engineering, physical sciences, computer science, or another quantitative discipline A home at our award-wining NYC workplace 100% employer-covered health insurance A competitive salary and stock options Catered lunch every day The chance to create a better healthcare experience for millions of patients!
# **************************************
# PhD or Masters degree in Data Science, Statistics, Economics, Econometrics, Operations Research, or other relevant analytics fields Business experience in analytics strongly preferred Experience working with statistical software packages like R, SAS, Python, or JMP. Experience with Visualization tools like Tableau or Power BI Experience in applying statistical and machine learning techniques such as regression and classification models, cluster analysis, neural networks, ensembles, random forests Experience in Design and Analysis of Experiments and Optimization a plus Experience in Text Analytics a plus Highly analytical with strong problem solving skills Strong attention to detail Strong verbal and written communication skills Desire and ability to work well with others in a team environment
# **************************************
# Role Description     Internal change agent with an unrelenting focus on closing the gap between a innovative ideas and actual real world solutions Work across the analytical workflow from data acquisition, exploratory data analysis, feature engineering, modeling, and interactive storytelling Lead agile prototyping teams applying innovative big data capabilities to address corporate-wide business problems Initiate and establish internal and external partnerships/collaborations       Responsibilities     Partners with senior leaders to develop and drive analytical capabilities throughout the organization Leads the development of the business case and prototype for next-gen analytics Architect and product manager for analytical products which leverage emerging data sources, advanced methodologies, and new efficient technologies Manages cross-functional team to address high-priority business problems Research, identify, and apply new algorithms and technologies to current business needs Hands-on data engineering across multiple systems and data types       Qualifications     Bachelors degree required, Masters preferred in a quantitative discipline At least 10 years experience in pharmaceutical/biotech industry with preferably 5+ years in consultative role Expert knowledge in statistical/scripting packages such as R/Python with fluency in SQL Passion for data with experience working with large distributed data sets in Hadoop/Spark, graph databases Demonstrated ability to advise senior level executives, and applies consultative skills including problem definition, consultative listening, hypothesis generation, data analysis, translation to insigh, and story-telling for impact Ability to solve ambiguous problems*Ability to communicate complex analysis in a clear and actionable manner through interactive tools such as Tableau, Ipython, Shiny, etc       EEO & Employment Eligibility     Pfizer is committed to equal opportunity in the terms and conditions of employment for all employees and job applicants without regard to race, color, religion, sex, sexual orientation, age, gender identity or gender expression, national origin, disability or veteran status Pfizer is an E-Verify employer
# **************************************
# Bachelor's Degree in CS, Mathematics, Statistics or similar field of study or equivalent work experience. Masters Degree is a plus. A minimum of 5 years of industry experience working in a similar role with similar seniority and level of responsibility. Experience in developing data-driven algorithms in information retrieval, relevance, or machine learning. Experience working with distributed systems, and strong understanding of technologies like Spark, Hadoop/Hive, StarDog, Amazon Redshift, MongoDB.
# **************************************
# Successful candidates for this position will be self-starters with strong design and coding skills who love shipping great product The reward? You will get to work with the latest in big data analytics platforms and work as one of the technical leaders in a team of brilliant engineers looking to make history! In joining our team, you'll enjoy a competitive salary, great benefits, a creative and comfortable work environment, and the exciting opportunity to be part of a fast-paced and growing technology company Key Responsibilities: - Work with business leaders to help define product requirements - Design and deliver advertising, brand analytics, and machine learning products within an Agile/Scrum environment - Build and maintain world-class customer experience and operational excellence for your deliverables   Basic Qualifications    Masters degree or equivalent* in Computer Science, Computer or Electrical Engineering, Mathematics, or a related field plus at least three years of experience in software development (*Bachelors degree plus five years of progressively responsible software development experience may also be accepted)
# **************************************
# Experience with, and a strong desire to use, the latest machine learning and data mining algorithms. Strong coding ability. Desire to work in Python. Experience with any of these is a plus: scikit-learn, Pandas, matplotlib, R, ggplot, JavaScript, D3, SQL, Hadoop, and Spark. Preference towards open source software. Appreciation of good design in both software UI and slideshow presentations. Willingness to give equal weight to both generating great results and communicating those results to technical and non-technical business partners. Hunger to continue learning and developing as a data scientist. Willingness to help further build the team, including contributing fresh ideas, establishing best practices, interviewing data science candidates, following trends, and attending conferences (e.g. KDD, NIPS). Strong academic background preferred, but all backgrounds (e.g. startup) considered. Love of television and film a plus!
# **************************************
# Were already the most innovative lender in the world in our use of machine learning and statistics, but we want you to take us to the next level - exploring the cutting edge and bringing us years of sophistication ahead of the rest of the space Difficult takes a day, impossible takes a week. Youll help us scale our work in data science, not only by growing the team, but through automation, testing, and tools to help us release models faster Take charge of the strategic direction of data science at LendUp Grow the team: recruit the best talent and develop a public reputation for the ground-breaking data science work at LendUp Partner with data engineering and software engineering to understand dependencies, develop good interfaces, and ensure uniform technical standards Lead the way: clear blockers, make ruthless prioritization decisions, and make sure the business has what it needs on-time, every time Communicate with leaders to maximize the effectiveness of the data science team Deep experience on how to prototype, build, release, and monitor mission-critical machine learning models Success in leading a data science team. Youve recruited and grown top talent, executed a strategic agenda, and simultaneously managed multiple high priority projects on tight timelines Some familiarity with best practices in software engineering and distributed systems, in particular data engineering Able to make hands-on contributions, when necessary, as an individual to modeling and/or software engineering Excellent communication skills. Fluent in translating high-level business goals into technical specs and communicating low-level technical concerns about implementation back to business leaders. Performed original research in some area of statistics or machine learning. Areas of particular interest include: transfer learning, active learning, and online learning. Good understanding of OOP and functional programming styles Experience with machine learning in a distributed setting e.g. with Hadoop, Spark, or Storm Prior modeling experience in the financial services industry
# **************************************
# You will be part of a highly focused group of talented and creative engineers and scientists Our work is varied, ranging from our patented human-in-the-loop interactive search and optimization, to state-of-the-art choice modeling and volumetric forecasting Our R&D efforts focus on developing new capabilities to meet the expanding scope of our business, improving the performance and scalability of our current optimization and measurement platforms, as well as integrating our solutions with the unique range of data sources available within Nielsen   POSITION DESCRIPTION     You will be responsible for the design and implementation of scalable analytic solutions. These range from simple ones, such as regression models and clustering and classification algorithms, to complex systems that integrate a number of procedures in a tool chain optimized to run in real-time. Specific responsibilities include: Design and documentation of technical requirements and architecture for data processing, statistical modeling and analysis applications Design, implementation and validation of analytics scripts and applications Prototyping, implementation and validation of new algorithms, using simulation-based models Improving the computational efficiency and scalability of various statistical models (MCMC GLMs, clustering algorithms, etc.) Development, implementation and maintenance of standard programming practices across analytics codebase Keeping up with the state-of-the art in relevant areas  software packages, computational frame works and techniques This position reports to the VP Computational Engineering MS or PhD in Computer Science, Data Science or a relevant scientific/engineering field, with high academic achievement Knowledge of: Microsoft and Linux operating systems Relational and NoSQL database systems and programming, including SQL Server and MongoDB Java and C# R High performance and distributed computing Web languages and technologies (JavaScript, web services) Knowledge of: Numerical programming Machine learning Algorithm development (design and evaluation) Knowledge of software engineering practice, tools and processes Demonstrated ability to lead a small, high-performing team of engineers and scientists Ability to manage several projects with competing priorities and deadlines Eagerness to take ownership of and responsibility for challenging assignments Ability to communicate with audiences with varied technical backgrounds Experience with scientific electronic workflow automation Interest in working in an environment that brings together the hard sciences and the social sciences Academic or industry experience with Genetic and Evolutionary Computation Academic or industry experience with Choice Modeling
# **************************************
# Assess and understand all key structured and unstructured data sources. Lead initiatives around a global data architecture strategy around Global CEM (Consumer Engagement Management) Critical member of team leading the development and deployment of analytical tools and data science techniques to analyze large data sets and develop custom models/algorithms to uncover trends, patterns and insights in the data Develop and enhance statistical techniques and models for deploying PEP proprietary Demand Spaces framework across key markets globally. As an active member of the extended Demand Science Development and Deployment team, consult with local markets and be 'Go To Person' on all things related to demand analytics Detect, monitor, and forecast trend forces utilizing data sets from multiple sources. Helps drive new thinking around shape of demand forecasting Monitor data science trends, emerging tools and technologies and supports strategic leadership in developing common, best and continually improving frameworks, processes and best practices for predictive science Provides support for analytics work within the Regions, ensuring it is in alignment with global analytics agenda and rigor 6-8+ years of experience in market research/insights/analytics, competitive intelligence or other similar function with demonstrated ability to manage function in a complex environment with multiple constituencies BA/BS required Exposure to complex modeling and analytical methodology including, but not exclusively, longitudinal analyses, multi-level modeling and multivariate analyses of variance Strong communication skills that is able to educate and influence management and senior leaders to act in a desired manner through written and verbal communication. Ability to simplify highly complex analyses and output into terms that are easily accessible and impactful in both written and verbal formats Future-oriented thinker with expertise in external practices and trends Demonstrates a sense of calmness under periods of uncertainty or change while dealing with stress in a manner that sets the necessary tone for the team and function High character and integrity, is consistent and acts in line with a clear and visible set of values and beliefs Global outlook with sensitivity and awareness of social and cultural differences
# **************************************
# The RSA data scientists are expected to perform end-to-end research steps involved in solution development, while establishing subject-matter expertise in relevant themes Strong oral and written communication skills, fluent in English, with good communication skills and the ability to work in a cross-functional global team
# **************************************
# Participate in defining data science product strategy, drive architectural direction, and plan activities with thorough investigation on the state-of-the-art and the technology trends in the field Applying engineering best practices, including use of design patterns, code review, pair programming and automated unit/functional testing Apply state of the art code development, data processing, machine learning, statistics or data mining in a variety of areas. Invent and fast iterate on novel solutions to challenging data related problems. Develop scalable and efficient methods for large-scale data analyses and model development. Collaborate with developers, program managers, and product managers in an open, creative environment. Bachelor's Degree in Computer Science or a related technical field Computer Science fundamentals in algorithm design, problem solving, and complexity analysis Proficiency in at least one programming language such as Java or Python Experience with software development and integrated quality methodologies Experience with machine learning methodologies Familiarity with Hadoop eco system 4+ years of software development experience Demonstrated self-direction Experience with SPARK, Scala Experience building platform software Familiarity with SQL and noSQL databases Experienced with statistical scripting languages such as R or SAS
# **************************************
# Enhancing our machine learning software with the latest in machine learning algorithms Employing machine learning and statistical modeling over our petabytes of data to generate new features to feed into our bid-time predictions Creating systems that monitor inputs and performance on a real-time basis to inform engineers when unexpected changes arise. Performing automated market analyses to dynamically react to changing market conditions Discover new predictive insights in our dataset Design systems that regularly compute new predictive models Read and conduct research to develop mathematical solutions to our most pressing problems Engineer to put your research into practice Ownership of a system that is the core of our intelligence products BS or MS in Computer Science, Computer Engineering, Mathematics. Strength in both fields is necessary; double majors are a big plus. 3+ years experience with C, C++, or Java Proven ability at architecting scalable, high performance systems Experience translating math into efficient code Enthusiasm to work in a fast-paced engineering team Prior experience with machine learning algorithms and their implementations Experience with manipulating large data sets Understanding of online ad industry Humor. Old school video games. Robots.
# **************************************
# Develop risk, profitability, fraud and targeting models used to support rapid growth across multiple channels (in-store, mail, mobile and/or web) Discover insights from a myriad of data sources to understand and influence consumer financial behavior. Develop new complex attributes to be used to build next generation of predictive models by combining machine learning and business acumen Drive business strategy and company growth rates by leveraging advanced analytics. Recommend analytic solutions to increase Oportuns marketable universe and identify profitable prospects Design and build credit risk and marketing analytics infrastructure for managing risk/marketing for online/mobile channel Support direct marketing program for consumers that lack a traditional bureau score Communicate and partner with third party data vendors Masters degree (or PhD) in Statistics, Mathematics, Operations Research, Computer Science or Economics. Bachelors degree with significant relevant experience will be considered 5+ years of experience building predictive models for Credit Risk in financial services Experience with modeling techniques like logistic regression, binning regression, random forest, gradient boosting, neural networks and decision trees. Other machine learning methods a plus Proven experience to drive growth and improve underwriting framework Strong with SAS, SQL and Python. Functional knowledge of R a plus. A relentless problem solver and out of the box thinker Excellent written and oral communication skills Experience with experimental designs a plus
# **************************************
# nan
# **************************************
# If you are a Senior Analyst - Data Science, Economics & Pricing with experience, please read on! Work within a Fortune 500 Holdings Company to develop, enhance and maintain economic models to best implement profit-enhancing pricing strategies You will be expected to utilize state-of-the art statistical tools and modeling techniques on both a scheduled and ad-hoc basis, as well as prepare analytics and document models What You Will Be Doing  - Developing profit-enhancing pricing strategies - Perform scheduled and ad-hoc data driven tasks - Design and implement modeling and analysis procedures - Support ongoing pricing determination and implementation across thousands of stores and millions of items - Accomplish timely ad-hoc statistical analysis and projects What You Need for this Position  At Least 1 Year of experience and knowledge of: - Economic Models - Financial Models - Data Analysis Software - Statistical Analysis (Regression, Propensity Score, ANOVA) - R - Excel   So, if you are a Senior Analyst - Data Science, Economics & Pricing with experience, please apply today!  Looking forward to receiving your resume through our website and going over the position with you You must keep the JobID: linkedin : MG3-1242525 -- in the email subject line for your application to be considered ***   Monty Gill - Executive Recruiter - CyberCoders Applicants must be authorized to work in the U
# **************************************
# Specify requirements for current and future data-science products by working with external & internal stakeholders Working with engineering & data-science teams to scope product delivery and understand development alternatives as well as support build/buy economics when applicable Define product vision and future direction, develop and communicate roadmaps Lead product decisions on priorities and help resolve issues. Own the delivery of the product end to end, proactively identifying risks and opportunities and keeping stakeholders informed Be the resident expert on the topic for all internal stakeholders BS/BA in advanced technical degree or MBA are preferred Experience of working in data-science centric environments is strongly preferred Excellent written and oral communication skills; superior organizational and analytical skills. Proven ability to work with OffShore teams Exceptional technical abilities and proven ability to work with engineers Demonstrated skills in requirements gathering, resource organization, and schedule development Strong bias for action and results; ability to juggle multiple priorities and create a sense of urgency in a fast-paced, dynamic environment. Nimbleness and comfort with ambiguity Proven ability to make smart trade-offs of features versus time-to-market
# **************************************
# Work closely with different business functions (Enterprise Analytics, Marketing, Retail, Institutional, etc.) within TD Ameritrade team to derive important business insights and decide how data science can help achieve objectives. Collaborate with application development, universities, Analytics Center of Expertise (ACoE) groups to identify and develop new analytical capabilities for the firm. Develop experiments and prototypes leveraging advanced statistical algorithms For the successful experiments and prototypes, work with the data development teams to design the solution for broader adoption Assist with the presentation of prototypes to TDA stakeholders to demonstrate capabilities, value proposition, and alignment to strategy Work with key stakeholders and assist in developing business case and value proposition to facilitate go/no go decision made by business units for new analytical solution deployment into the firm. Partner with data development, architects and ACOE and provide technical guidance to launch solution into production. Document technical design and patterns to provide initial engineering plans for new solution. Work with the team in developing a communication strategy towards the launch and adoption of the new capability Participate in Think-offs to demonstrate disruptive capabilities Participate and selectively present in different conferences and technology meet ups to learn and contribute to industry trends as it relates to analytics Strong experience with advanced analytics, mathematical modeling, programming in R, Python, Spark, knowledge in data engineering and data architecture Experience working in an agile, iterative manner to foster innovation Excellent communication and collaboration skills to work across multiple groups within organization 2+ years related work experience Graduate degree
# **************************************
# Data Scientist Lead - Research and Machine Learning      ABOUT THE POSITION:   Lead Data Scientist to join its Liquid Strategies team D in a science: physics, biology, statistics    Dissertation involving the use of computational tools    3-5 years in the finance industry, using Big Data & machine learning techniques on real datasets    Multivariate time series analysis    Algorithm complexity, Supervised & Unsupervised learning, Support Vector Machine, Ensembles, Nerual Net C++, MATLAB a plus    Expert in pandas, scikit-learn, statsmodels, scipy, matplotlib, HDF5 libraries    Windows and Linux    Strong data visualization techniques    Proactive and solutions-oriented; innovative and results-driven    Ability to share code and participate in the development of software with multiple contributors    Ability to absorb new information quickly    Comfortable in a fast paced environment    Comfortable juggling multiple projects and managing time independently   Excellent communication skills  DATA@connectionsny
# **************************************
# Customer profiling and segmentation : evaluate customer segment characteristics across multiple dimensions, producing customer demographic, psychographic, financial, and behavioral profiles to drive client marketing strategies and tactics. Statistical modeling : Analyze customer data across multiple dimensions to inform the marketing campaign and test strategy. Utilize this data to build targeted marketing models using algorithms such as Logistic Regression, CHAID, SVM etc. Provide actionable recommendations based on insights, and report on these insights to business and technical partners. Experience creating various response models and incorporating cross-channel behavior is a plus. Campaign test design : Design test structure to support revenue and learning objectives across segments, offers, creative, and channels. Prioritize across various business objectives and set up campaign design to ensure statistically sound results. Experience evaluating performance and incremental contribution is a plus Collaboration with global team : Actively engage with other team members in Mumbai to fully explain business requirements and implementation strategies 2+ years experience in customer analytics and modeling in CRM or client side environment Broad experience analyzing and manipulating data in Big Data environment as well relational databases Experience designing and validating models using logistic regression, decision trees, non-linear regressions, and support vector machine methodology Expert knowledge of statistical software such SAS or R Experience programming in Hive, Pig, and Python MS/PhD, preferably within statistics, mathematics, economics or a technology focused degree
# **************************************
# Overall, a highly driven, results-oriented, creative and nimble problem solver and a willingness to do whatever it takes to deliver business impact quickly. Ability to prioritize and set direction in a semi-chaotic fast moving environment. As the technical lead, work with a team of high-performing data scientists, software engineers and data engineers to build scalable data applications. Create and execute a vision of data and technology. Propose venture ideas and quickly turn them into real-word prototype for validation. Effectively communicates complex analytics to broader audience in writing and presentation formats. Bachelors or Masters degree in a quantitative field such as Computer Science, Engineering, Operational Research, Statistics, Economics, etc. 3+ years' experience working in an Analytics, Data Science, or Engineering function Experience using SQL Experience coding in Python, Java, or equivalent 5+ years experience working in an Analytics, Data Science or Engineering function Experience working in the consumer web/internet domain Experience with large-scale data on Hadoop using Hive or Pig Web development experience (Javascript/CSS/HTML/D3/Highcharts) Experience with statistical programming environments like R or equivalent Experience with data mining, modeling, or machine learning
# **************************************
# ...
# **************************************
# MS/PhD in quantitative field such as Mathematics, Operations Research, Engineering, Statistics or Equivalent Minimum of 2 years+ experience in consumer or business lending Knowledge of portfolio risk management, early warnings, customer management and collection best practices Ability to express yourself in a clear and concise manner in both written and verbal discussions and ability to work within very tight deadlines Strong ability to shift gears quickly Ability to transform data and prototype quickly to conduct statistical analysis using tools primarily written in SAS, R, Python or Java; Proficiency with SQL language and relational databases
# **************************************
# Exceptional communication, collaboration and critical thinking skills are required Strong statistical, machine learning and data mining background Ability and experience gathering cross-functional requirements and translating them into practical tasks Proficiency in MapReduce development Fluency with statistical analysis packages such as R/SciPy/NumPy/etc 2+ years of Data Science experience with large scale data analysis using Big Data Technologies (Hadoop/Cassandra/HDFS/HIVE/Pig/Spark)
# **************************************
# Our small team is comprised of passionate, brilliant folks and we're backed by a well-respected, global investor base If you are a Data Scientist with experience, please read on!  Top Reasons to Work with Us  - You'll be getting in at the ground level of a growth stage company - We provide lunch, snacks and drinks every day - We offer a competitive benefits package - Most importantly, you'll have a chance to work with amazingly talented and passionate people Be prepared to be busy!  What You Need for this Position  - Skills in Large Scale Data Management and Manipulation - Skills in Statistical Inference on Large Scale Data, broadly defined - Experience with graph data is a plus though not a requirement - Specific preferences for those with an MS or PhD in data mining, machine learning, econometrics, statistical analysis, applied mathematics or the equivalent - Fluency in one or more programming languages: C/ C++, Java, scripting languages like Perl or Python, etc - Fluency with databases (relational or NoSQL) - Strong experience with distributed systems such as Hadoop/MapReduce, Hive, Pig, Spark, streaming data processing, and cloud architecture - Knowledge in different simulation approaches such as Monte Carlo methods is a plus You must keep the JobID: linkedin : RN2-1255567 -- in the email subject line for your application to be considered ***   Robin Napier - Executive Recruiter - CyberCoders Applicants must be authorized to work in the U
# **************************************
# Data Scientist - Biz Analytics role will be a member of the Small Business, Developer, and Partner Support Offering team, and will be devoted to uncovering opportunities to improve Microsoft Partner Cloud Economy and drive Customer Value Creation with analytics and insight Minimum seven years professional experience in data science, applied statistics, machine learning, data mining, statistical modeling tools and underlying algorithms Minimum three years professional experience in Subscription Business or Financial Industry (securitization market, actuary, or related field) Extensive experience with experiment design and A/B and multivariate tests Proficiency in R, SAS, Perl, Python, SQL, or other languages appropriate for large scale analysis of numerical and textual data  Proven mastery of analysis, development of models, and model evaluation Strong understanding of how a business and strategy works Experienced in Financials, Marketing and/or Insurance industry Experience working with and applying Neural Networks, LDA, SVM, Clustering algorithms, survival analysis, and social network analysis Experience with Hadoop and Map/Reduce desirable Must Have Personal Attributes / Skills  Passion for research and solving business puzzles with data and insights Analytical thinker and ability to diagnose business problems and opportunity Flexible and resourceful, with a figure-it-out-and-get-it-done mentality  Being able to work in a fast-paced multidisciplinary environment  Ability to forward the failure toward the new collective corrections  Desire to learn and adopt new technologies and analysis methodologies Results oriented with the ability to self-manage and work independently  Ability to communicate with technology partners, business partners, and data scientist Willing to share best practices with others to augment institutional knowledge Must be creative and agile in adjusting execution approach with given resources Desired Personal Attributes / Skills  Enthusiastic with scope; not afraid to make suggestions, challenge or offer new ideas Strong problem solving skills Confident in managing the uncertainty Demonstrated cross-group collaboration and interpersonal awareness  Self-initiating, independent thinker who is able to suggest/develop both long-term business strategies and short-term tactical plans Ability to meet Microsoft, customer and/or government security screening requirements are required for this role
# **************************************
# Design, develop, and implement statistical and machine learning models for data center operations and interconnection platform by mining vast amounts of machine generated data. Analyze data to identify useful relations, patterns and features that are predictive of events of interest. Continuously identify and explore new and unconventional data sources. Apply advanced statistical, machine learning, and other types of analytical techniques to improve various forecasting models and other real-time analytics. Build, mentor and lead a world class data science team to answer big data questions for business stakeholders, lead team to utilize sophisticated data analysis techniques aimed at deriving meaningful insights to drive business results. Provide key input to the technical team on data requirements. Look for key opportunities and take a proactive approach to analysis; initiate proactive projects to uncover key insights. Collaborate with business partners to identify strategic opportunities, understa n d business problems, translate them into data science projects and appropriately prioritize and execute them. Educate and evangelize data driven approaches across the organization MS or PhD in Statistics, Applied Mathematics, Computer Science or another quantitative discipline 3+ years of professional experience in statistical analysis, quantitative analytics, forecasting/predictive analytics, machine learning, experimental design, statistical inference, econometrics, multivariate testing, and optimization algorithms 6+ Professional experience in High Tech , Mathematics or statistical field. Proficient programming skills in multiple languages including R, Python, SQL, MATLAB and Java Proficiency with big data technology such as Hadoop, Pig, Hive, NoSQL, Spark, GraphDBs Strongly analytical, with an ability to multitask multiple projects Experience with Network analytics and data center industry is a strong plus. Excellent communications skills with the ability to present complex analytical concepts to different audiences. Ability to work independently on complex tasks Be a talent multiplier who gets the team around them to excel Be persistent, creative and driven to get results relentlessly Exhibit a strong backbone to challenge the status quo, when needed Exhibit a high level of curiosity, keeping abreast of the latest trends & technologies Show pride of ownership and strive for excellence in everything undertaken
# **************************************
# In this exciting role, you will design, create, implement, and manage predictive analytics that leverage large and varied datasets, both financial and non-financial, using a wide range of analytical tools, methods, and platforms If you're looking to work in an environment where your technical creativity will flourish -- look no further and apply today! Responsibilities: - Design lean proofs of concepts (POC) to answer targeted business questions Be creative! - You will be relied upon for technical leadership in this role We need the best and brightest! - Engage in data analysis in a practical way Be innovative! - Collaborate with Bloomberg's advanced visualization team Be colorful! -Educate other analysts and business team members Be generous! Required Qualifications: - Advanced Degree in Computer Science, Statistics, Math, Engineering, or another quantitative discipline - Experience working with programming and scripting languages like Python, R and Java - 3 - 5 years of experience in the use of advanced development, statistical analysis, or machine learning methods in a professional working environment - Industry experience with Natural Language Processing or Machine Learning - Substantial experience with the Big Data stack (Hadoop, Spark, NoSQL, Solr, HBase) - Professional working experience in the financial services industry - Strong understanding of core financial concepts Preferred Skills: - Experience with mapping business needs to a data science solution - Experience using SQL for data extraction and management (MSSQL, Oracle, MySQL) - Must be able to address multiple priorities in an extremely fast-paced environment
# **************************************
# We are at the forefront of change and move at an amazing pace, thanks to our remarkable people, who bring cutting-edge products and services to life for millions of customers every day If you share in our passion for teamwork, our vision to revolutionize industries and our goal to lead the future in media and technology, we want you to fast-forward your career at Comcast Do you want to work on unlocking the true power of big data? Are you ready to go beyond classic predictive analytics and machine learning to newer areas like deep learning and micro-contextual analytics to obtain fundamentally new business insights from petabytes of behavioral data? Join the Comcast Big Data Science Team to work in a dynamic, startup-like environment with the resource backing of one of the world's largest companies What you will be doing: - Diving into huge, noisy, and complex real-world behavioral data to produce innovative analysis and new types of predictive models of customer behaviors and TV product performance - Unleashing your creativity to find hidden gems that improve our understanding of TV and internet that will drive actionable business decisions - Collaborating with executive leaders and business owners, leading teammates to solve business problems using broad spectrum of data science tools, packages and visualization techniques - Using your deep knowledge of the big data ecosystem to build efficient and scalable analytical solutions - Discovering and implementing new tools and technologies to keep current with the trends and advances in the data science community - Bringing strategic vision to the team and serving as a subject matter expert in the capabilities of Data Science What you need for this position: - Expert knowledge of machine learning, data mining and natural language processing algorithms with special emphasis to the advanced algorithms like neural networks, SVM, random forests, bagging, gradient boosting machines, k-means++, etc - Solid experience in practical predictive modeling - Good understanding of the experimental design, simulation, optimization, mixed methods and market research - Exposure to the representation learning, including deep learning - Advanced knowledge of two or more of the analytics languages/toolkits such as R, SAS, SPSS, Matlab or Python with analytical extensions - SQL and advanced data processing - Proficient in at least one programming/scripting language like Python, Scala, Julia, Ruby, or Java, C#, etc - Strong understanding of big data concepts and knowledge of big data languages/tools such as Hive, Pig, Mahout or Spark Educational Level and Experience - PhD (preferred) or Master degree in Computer Science, Applied Mathematics, Statistics, Econometrics, Quantitative Social Sciences or related field - At least 10-15 years of experience depending on educational level and relevance Core responsibilities: - Leads development of analytical models using statistical, machine learning and data mining methodologies - Defines requirements for exploratory and ad hoc data analysis - Introduces new classes of business metrics - Defines new approaches to feature engineering, extraction and learning - Collaborates with the data architects of various data platforms (big data, relational and non-relational) to define requirements for data architecture enhancements and new data ingestion - Utilizes Hadoop, SQL and NoSQL languages, tools and technologies to extract and process data for analytical needs - Utilizes Big Data Analytical tools and packages to design and build highly scalable analytical models - Leads the analysis and formalization of the business problems - Leads the team in adoption of new analytical algorithms, tools and technologies - Consistent exercise of independent judgment and discretion in matters of significance - Regular, consistent and punctual attendance - Other duties and responsibilities as assigned
# **************************************
# If you are a Big Data Engineer with data science experience, please read on! We are a fast growing, well-established early startup who is working on solving a very unique and exciting problem that deals with causality of big data analytics Be part of a world-class engineering team 3 HUGE growth potential  What You Will Be Doing  - Working within a small team to solve very interesting and unique problems that deal with terabytes of data and deriving meaning from it's analytics What You Need for this Position  Computer Science education/background - Experience working within a team to solve problems - Experience with big data analytics - Experience with Data Science, Machine Learning, Predictive analytics - a plus  What's In It for You  A lot :-) - Very competitive salary plus bonus and equity - Full benefits - 401k - Great PTO - Work with the best people - Fun & casual work environment - Other perks such as meals, happy hours, ping pong table, dart board, and much more :-)   So, if you are a Big Data Engineer with data science experience, please apply today!  Looking forward to receiving your resume through our website and going over the position with you You must keep the JobID: linkedin : SA-1252159 -- in the email subject line for your application to be considered ***   Serj Amirian - Executive Recruiter - CyberCoders Applicants must be authorized to work in the U
# **************************************

# %%
df = df[df['job_description'] != 'Data Extraction Failed']
df = df.dropna()
df = df.drop_duplicates(['company', 'job_description', 'job_title', 'location'])

# %%
df_cities['city'].head(3)
# Out:
# 0    holtsville
# 1      adjuntas
# 2        aguada
# Name: city, dtype: object

# %%
geolocator = Nominatim()
location = geolocator.geocode("Menlo Park, CA")
location[1]
# Out:
# (37.4538274, -122.182187)

# %%
def replace_words(city):
    city = city.replace('Metro', '')
    city = city.replace('Area', '')
    city = city.replace('Bay', '')
    city = city.replace('Greater', '')
    city = city.replace('(HQ)', '')
    city = city.replace('L5-', '')
    city = city.replace('- CNVR  60606', '')
    city = city.replace('San Francisco / ','')
    city = city.replace('North America','')
    city = city.replace('US','')
    city = city.replace('DC','')
    city = city.replace('Downtown','')
    city = city.replace('Manhattan','NYC')
    city = city.replace('-',' ') 
    city = city.strip()
    city = city.split('/')[0]
    return city

# %%
address, longitude = featurizing_locations(us)
# Out:
# Washington D.C.
# Washington, District of Columbia, United States of America
# (38.8949549, -77.0366455)
#
# **********************
# San Francisco   California
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Palo Alto, CA,
# Palo Alto, Santa Clara County, California, United States of America
# (37.442156, -122.1634471)
#
# **********************
# Herndon, VA
# Herndon, Fairfax County, Virginia, United States of America
# (38.9695316, -77.3859478)
#
# **********************
# Oregon, Hillsboro
# Hillsboro, Washington County, Oregon, United States of America
# (45.5228939, -122.9898269)
#
# **********************
# Philadelphia
# Philadelphia, Philadelphia County, Pennsylvania, United States of America
# (39.9523993, -75.1635898)
#
# **********************
# Irvine, California
# Irvine, Orange County, California, United States of America
# (33.6856969, -117.8259818)
#
# **********************
# NYC
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Mountain View, CA
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Norwood, MA
# Norwood, Norfolk County, Massachusetts, United States of America
# (42.194543, -71.1994975)
#
# **********************
# New York, New York
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# WA Seattle
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Beverly Hills, California
# Beverly Hills, Los Angeles County, California, United States of America
# (34.0736204, -118.4003562)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# MA Waltham
# Waltham, Middlesex County, Massachusetts, United States of America
# (42.3756401, -71.2358003)
#
# **********************
# Purchase, New York
# Purchase, Town of Harrison, Westchester County, New York, United States of America
# (41.0409305, -73.7145745)
#
# **********************
# Washington D.C.
# Washington, District of Columbia, United States of America
# (38.8949549, -77.0366455)
#
# **********************
# Santa Monica, CA,
# Santa Monica, Los Angeles County, California, United States of America
# (34.0195598, -118.4869738)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Dallas
# Dallas, Dallas County, Texas, United States of America
# (32.7762719, -96.7968558)
#
# **********************
# Chicago
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Chicago, IL
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# San Francisco,CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Ann Arbor
# Ann Arbor, Washtenaw County, Michigan, United States of America
# (42.2681569, -83.731229)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Mountain View, CA
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Chicago, IL
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Milpitas California
# Milpitas, Santa Clara County, California, United States of America
# (37.4282724, -121.9066237)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Chicago
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Sunnyvale, CA
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# California   San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# CA San Diego
# San Diego, San Diego County, California, United States of America
# (32.7174209, -117.1627713)
#
# **********************
# Richland
# Richland County, Illinois, United States of America
# (38.7060457, -88.0949351)
#
# **********************
# Richland
# Richland County, Illinois, United States of America
# (38.7060457, -88.0949351)
#
# **********************
# Sunnyvale, CA,
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco,CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Chicago, IL
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Seattle
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Raleigh, NC
# Raleigh, Wake County, North Carolina, United States of America
# (35.7804015, -78.6390778)
#
# **********************
# Richland
# Richland County, Illinois, United States of America
# (38.7060457, -88.0949351)
#
# **********************
# WA   Seattle
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Santa Monica, CA,
# Santa Monica, Los Angeles County, California, United States of America
# (34.0195598, -118.4869738)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Seattle, WA
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Round Rock, TX
# Round Rock, Williamson County, Texas, United States of America
# (30.5725805, -97.6484073341624)
#
# **********************
# Reno, Nevada
# Reno, Washoe County, Nevada, United States of America
# (39.52927, -119.8136743)
#
# **********************
# Phoenix, AZ
# Phoenix, Maricopa County, Arizona, United States of America
# (33.4485866, -112.0773455)
#
# **********************
# Tampa, FL
# Tampa, Hillsborough County, Florida, United States of America
# (27.9477595, -82.4584439)
#
# **********************
# A Alpharetta, GA
# Alpharetta, Fulton County, Georgia, United States of America
# (34.0709576, -84.2747328)
#
# **********************
# Cambridge, MA
# Cambridge, Middlesex County, Massachusetts, United States of America
# (42.3750997, -71.1056156)
#
# **********************
# Silicon Valley
# Le Silicon Valley, Boulevard Georges Pompidou, Beaulieu - Maladrerie - Saint-Paul, Caen, Calvados, Normandie, France métropolitaine, 14000, France
# (49.179302, -0.394566848275862)
#
# **********************
# Portland, OR
# Portland, Multnomah County, Oregon, United States of America
# (45.5202471, -122.6741948)
#
# **********************
# Santa Monica, CA,
# Santa Monica, Los Angeles County, California, United States of America
# (34.0195598, -118.4869738)
#
# **********************
# A Alpharetta, GA
# Alpharetta, Fulton County, Georgia, United States of America
# (34.0709576, -84.2747328)
#
# **********************
# Menlo Park  California
# Menlo Park, San Mateo County, California, United States of America
# (37.4538274, -122.182187)
#
# **********************
# Palo Alto, CA
# Palo Alto, Santa Clara County, California, United States of America
# (37.442156, -122.1634471)
#
# **********************
# Menlo Park  California
# Menlo Park, San Mateo County, California, United States of America
# (37.4538274, -122.182187)
#
# **********************
# Boston
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# California   San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York        NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Naperville, IL
# Naperville, DuPage County, Illinois, United States of America
# (41.7729107, -88.1478669)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Oak Ridge, Tennessee
# Oak Ridge, Anderson County, Tennessee, United States of America
# (36.0103562, -84.2696448)
#
# **********************
# Seattle
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# New York
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Mountain View, CA
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Roswell, GA
# Roswell, Fulton County, Georgia, United States of America
# (34.02332, -84.3600219)
#
# **********************
# Redwood City, CA
# Redwood City, San Mateo County, California, United States of America
# (37.4852152, -122.2363547)
#
# **********************
# Newark, Ohio
# Newark, Licking County, Ohio, United States of America
# (40.0581205, -82.4012642)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# PHILADELPHIA, PA
# Philadelphia, Philadelphia County, Pennsylvania, United States of America
# (39.9523993, -75.1635898)
#
# **********************
# Philadelphia, PA
# Philadelphia, Philadelphia County, Pennsylvania, United States of America
# (39.9523993, -75.1635898)
#
# **********************
# Mountain View
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# Midtown NYC
# Queens-Midtown Tunnel, Tudor City, Manhattan, New York County, NYC, New York, 10017, United States of America
# (40.7472224, -73.9672061)
#
# **********************
# PHILADELPHIA, PA
# Philadelphia, Philadelphia County, Pennsylvania, United States of America
# (39.9523993, -75.1635898)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Menlo Park, CA
# Menlo Park, San Mateo County, California, United States of America
# (37.4538274, -122.182187)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Bellevue    WA
# Bellevue, King County, Washington, United States of America
# (47.6144219, -122.1923371)
#
# **********************
# Mountain View, CA
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# TX Dallas Ft Worth   Southlake
# TX Dallas Ft Worth   Southlake
# None
#
# **********************
# IL, Chicago
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Los Gatos, California
# Los Gatos, Santa Clara County, California, United States of America
# (37.226611, -121.9746796)
#
# **********************
# Sunnyvale, CA
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# K8 Santa Barbara  93103
# Santa Barbara MTD Bus Garage, Hall Contracting, Santa Barbara County, California, 93101, United States of America
# (34.42356715, -119.689947999713)
#
# **********************
# Portland, OR
# Portland, Multnomah County, Oregon, United States of America
# (45.5202471, -122.6741948)
#
# **********************
# Menlo Park  California
# Menlo Park, San Mateo County, California, United States of America
# (37.4538274, -122.182187)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# CA San Diego
# San Diego, San Diego County, California, United States of America
# (32.7174209, -117.1627713)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
#
#
# None
#
# **********************
# San Jose, CA
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Mountain View, CA
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# Mountain View, CA
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# San Jose, CA
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# , CA, Santa Clara
# Santa Clara, Santa Clara County, California, United States of America
# (37.3541132, -121.9551743)
#
# **********************
# Palo Alto, CA
# Palo Alto, Santa Clara County, California, United States of America
# (37.442156, -122.1634471)
#
# **********************
# California   Palo Alto
# Palo Alto, Santa Clara County, California, United States of America
# (37.442156, -122.1634471)
#
# **********************
# NY New York City   NY A, CLT
# NY New York City   NY A, CLT
# None
#
# **********************
# NY New York City   NY A, CLT
# NY New York City   NY A, CLT
# None
#
# **********************
# Home Base
# Home Base, Emery County, Utah, United States of America
# (38.8072899, -110.6998159)
#
# **********************
# Durham,  NC
# Durham, Durham County, North Carolina, United States of America
# (35.9940329, -78.8986189)
#
# **********************
# Morrisville NC 27560
# Morrisville, Wake County, North Carolina, United States of America
# (35.823483, -78.825562)
#
# **********************
# Arlington, VA
# Arlington, Arlington County, Virginia, United States of America
# (38.8903961, -77.0841584)
#
# **********************
# Chicago, IL
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Arlington, VA
# Arlington, Arlington County, Virginia, United States of America
# (38.8903961, -77.0841584)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Los Angeles
# LA, Los Angeles County, California, United States of America
# (34.0543942, -118.2439408)
#
# **********************
# Boston
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# Columbus, Ohio
# Columbus, Franklin County, Ohio, United States of America
# (39.9622601, -83.0007064)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Washington D.C.
# Washington, District of Columbia, United States of America
# (38.8949549, -77.0366455)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Norwood, MA,
# Norwood, Norfolk County, Massachusetts, United States of America
# (42.194543, -71.1994975)
#
# **********************
# Culver City, CA,
# Culver City, Los Angeles County, California, United States of America
# (34.0211224, -118.3964664)
#
# **********************
# Redwood City, CA,
# Redwood City, San Mateo County, California, United States of America
# (37.4852152, -122.2363547)
#
# **********************
# Washington, D.C., ,
# D,C, Buccaneer Ridge Drive, Johnson City, Washington County, Tennessee, 37614, United States of America
# (36.29885175, -82.3591932141095)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Washington, D.C., ,
# D,C, Buccaneer Ridge Drive, Johnson City, Washington County, Tennessee, 37614, United States of America
# (36.29885175, -82.3591932141095)
#
# **********************
# San Francisco, CA, United States
# SF, California, United States of America
# (37.7647993, -122.4629896)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Herndon, VA,
# Herndon, Fairfax County, Virginia, United States of America
# (38.9695316, -77.3859478)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Mather, PA,
# Mather, Greene County, Pennsylvania, United States of America
# (39.934797, -80.0736686)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Shelton, CT,
# Shelton, Fairfield County, Connecticut, United States of America
# (41.3164856, -73.093164)
#
# **********************
# Indianapolis, IN,
# Indianapolis, Marion County, Indiana, United States of America
# (39.7683331, -86.1583501)
#
# **********************
# Ann Arbor, MI,
# Ann Arbor, Washtenaw County, Michigan, United States of America
# (42.2681569, -83.731229)
#
# **********************
# Ann Arbor, MI,
# Ann Arbor, Washtenaw County, Michigan, United States of America
# (42.2681569, -83.731229)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Ann Arbor, MI,
# Ann Arbor, Washtenaw County, Michigan, United States of America
# (42.2681569, -83.731229)
#
# **********************
# Ann Arbor, MI,
# Ann Arbor, Washtenaw County, Michigan, United States of America
# (42.2681569, -83.731229)
#
# **********************
# New Brunswick, NJ,
# New Brunswick, Middlesex County, New Jersey, United States of America
# (40.4862174, -74.4518172)
#
# **********************
# Portland, ME,
# Portland, Cumberland County, Maine, United States of America
# (43.6610277, -70.2548595)
#
# **********************
# Santa Barbara County, CA,
# Santa Barbara County, California, United States of America
# (34.7136533, -119.9858231)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Seattle, WA,
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Jose, CA,
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Seattle
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Boston, MA,
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Minneapolis, MN,
# Minneapolis, Hennepin County, Minnesota, United States of America
# (44.9772995, -93.2654691)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Atlanta, GA,
# Atlanta, Fulton County, Georgia, United States of America
# (33.7490987, -84.3901848)
#
# **********************
# Atlanta, GA,
# Atlanta, Fulton County, Georgia, United States of America
# (33.7490987, -84.3901848)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco,San Francisco,California,United States
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Cambridge, MA,
# Cambridge, Middlesex County, Massachusetts, United States of America
# (42.3750997, -71.1056156)
#
# **********************
# Ann Arbor, MI,
# Ann Arbor, Washtenaw County, Michigan, United States of America
# (42.2681569, -83.731229)
#
# **********************
# NYC, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Seattle, WA,
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Redwood City, CA,
# Redwood City, San Mateo County, California, United States of America
# (37.4852152, -122.2363547)
#
# **********************
# Mahwah, NJ,
# Mahwah, Bergen County, New Jersey, United States of America
# (41.0887072, -74.1437551)
#
# **********************
# Alpharetta, GA,
# Alpharetta, Fulton County, Georgia, United States of America
# (34.0709576, -84.2747328)
#
# **********************
# Alpharetta, GA,
# Alpharetta, Fulton County, Georgia, United States of America
# (34.0709576, -84.2747328)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Madison, WI,
# Madison, Dane County, Wisconsin, United States of America
# (43.074761, -89.3837612)
#
# **********************
# Pasadena, CA,
# Pasadena, Los Angeles County, California, United States of America
# (34.1476452, -118.1444778)
#
# **********************
# Woonsocket, RI,
# Woonsocket, Providence County, Rhode Island, United States of America
# (42.0028761, -71.5147838)
#
# **********************
# Bridgewater, NJ,
# Bridgewater, Main Street, Bridgewater Township, Somerset County, New Jersey, 08805, United States of America
# (40.5599163, -74.5516572)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Pennington, NJ,
# Pennington, Mercer County, New Jersey, United States of America
# (40.3284403, -74.7907179)
#
# **********************
# Austin, TX,
# Austin, Travis County, Texas, United States of America
# (30.2711286, -97.7436994)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Seattle, WA,
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# St. Louis, MO,
# St. Louis, City of St. Louis, Missouri, United States of America
# (38.6272733, -90.1978888)
#
# **********************
# St. Louis, MO,
# St. Louis, City of St. Louis, Missouri, United States of America
# (38.6272733, -90.1978888)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Hoffman Estates, IL,
# Hoffman Estates, Cook County, Illinois, United States of America
# (42.0426639, -88.0798709)
#
# **********************
# Alpharetta, GA,
# Alpharetta, Fulton County, Georgia, United States of America
# (34.0709576, -84.2747328)
#
# **********************
# Boston, MA,
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# Woodland Hills, CA,
# Woodland Hills, LA, Los Angeles County, California, United States of America
# (34.1683386, -118.6059196)
#
# **********************
# St. Louis, MO,
# St. Louis, City of St. Louis, Missouri, United States of America
# (38.6272733, -90.1978888)
#
# **********************
# Atlanta, GA,
# Atlanta, Fulton County, Georgia, United States of America
# (33.7490987, -84.3901848)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Hartford, CT,
# Hartford, Hartford County, Connecticut, United States of America
# (41.7634935, -72.6830522)
#
# **********************
# Simsbury, CT,
# Simsbury, Hartford County, Connecticut, United States of America
# (41.8759152, -72.801221)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Redwood City, CA,
# Redwood City, San Mateo County, California, United States of America
# (37.4852152, -122.2363547)
#
# **********************
# Chicago, IL,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Denver, CO,
# Denver, Denver County, Colorado, United States of America
# (39.7391536, -104.9847033)
#
# **********************
# Dallas, TX,
# Dallas, Dallas County, Texas, United States of America
# (32.7762719, -96.7968558)
#
# **********************
# Boston, MA,
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Jose, CA,
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# Scottsdale, AZ,
# Scottsdale, Maricopa County, Arizona, United States of America
# (33.5091215, -111.8992364)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# California, MD,
# California, Saint Mary's County, Maryland, United States of America
# (38.3004029, -76.5074541)
#
# **********************
# Boston, MA,
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# Arlington, WA,
# Arlington, Snohomish County, Washington, United States of America
# (48.1810957, -122.1389547)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Boston
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Jose, CA
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# NYC
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Orange County, California
# Orange County, California, United States of America
# (33.7500378, -117.870493)
#
# **********************
# Seattle, WA,
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# San Jose, CA,
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA,
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Hillsboro, OR,
# Hillsboro, Washington County, Oregon, United States of America
# (45.5228939, -122.9898269)
#
# **********************
# Boston, MA,
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Zeeland, MI,
# Zeeland, Ottawa County, Michigan, United States of America
# (42.8124349, -86.0288166)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Saint Paul, MN,
# St. Paul, Ramsey County, Minnesota, United States of America
# (44.9504037, -93.1015025)
#
# **********************
# San Jose, CA,
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# Columbus, OH,
# Columbus, Franklin County, Ohio, United States of America
# (39.9622601, -83.0007064)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Evanston, IL,
# Evanston, Cook County, Illinois, United States of America
# (42.0447388, -87.6930458)
#
# **********************
# Scottsdale, AZ,
# Scottsdale, Maricopa County, Arizona, United States of America
# (33.5091215, -111.8992364)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Santa Barbara, California
# Santa Barbara, Santa Barbara County, California, United States of America
# (34.4098107, -119.6970238)
#
# **********************
# Philadelphia, PA
# Philadelphia, Philadelphia County, Pennsylvania, United States of America
# (39.9523993, -75.1635898)
#
# **********************
# Seattle, WA
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Financial District
# Financial District, Toronto, Ontario, Canada
# (43.6486382, -79.3802816)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Los Angeles, CA,
# LA, Los Angeles County, California, United States of America
# (34.0543942, -118.2439408)
#
# **********************
# Princeton, NJ,
# Princeton, Mercer County, New Jersey, United States of America
# (40.3492744, -74.6592957)
#
# **********************
# San Jose, CA
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Santa Monica
# Santa Monica, Los Angeles County, California, United States of America
# (34.0195598, -118.4869738)
#
# **********************
# Boston
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Charlotte, NC,
# Charlotte, Mecklenburg County, North Carolina, United States of America
# (35.2270869, -80.8431267)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, California
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Boston, MA,
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Palo Alto, CA,
# Palo Alto, Santa Clara County, California, United States of America
# (37.442156, -122.1634471)
#
# **********************
# San Jose, CA
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# San Francisco   California
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Seattle
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Westford, MA
# Westford, Middlesex County, Massachusetts, United States of America
# (42.5792583, -71.437841)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# RTP, NC
# RTP, Wake County, North Carolina, 27709, United States of America
# (35.857977, -78.8824859)
#
# **********************
# Los Angeles
# LA, Los Angeles County, California, United States of America
# (34.0543942, -118.2439408)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco California A
# A, Marina Boulevard, Marina District, SF, California, 94123, United States of America
# (37.80644615, -122.432125654681)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Santa Clara Valley   California
# SJSU, El Paseo de Cesar E Chavez, SoFA, Japantown, San José, Santa Clara County, California, 95112, United States of America
# (37.3352583, -121.88130228815)
#
# **********************
# Santa Clara Valley   California
# SJSU, El Paseo de Cesar E Chavez, SoFA, Japantown, San José, Santa Clara County, California, 95112, United States of America
# (37.3352583, -121.88130228815)
#
# **********************
# Bridgewater   A   New Jersey
# Bridgewater, Main Street, Bridgewater Township, Somerset County, New Jersey, 08805, United States of America
# (40.5599163, -74.5516572)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco ,CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Austin, TX
# Austin, Travis County, Texas, United States of America
# (30.2711286, -97.7436994)
#
# **********************
# Reston, VA
# Reston, Fairfax County, Virginia, United States of America
# (38.9312353, -77.3570209298624)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Palo Alto, CA,
# Palo Alto, Santa Clara County, California, United States of America
# (37.442156, -122.1634471)
#
# **********************
# NYC
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Livermore, CA
# Livermore, Alameda County, California, United States of America
# (37.6820583, -121.768053)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Based
# Based, XX-lecia, Mużaków, Łęknica, powiat żarski, lubuskie, Polska
# (51.5412504, 14.7308212)
#
# **********************
# Seattle, WA
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Seattle
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Boston, MA
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# McLean, VA
# McLean, Fairfax County, Virginia, United States of America
# (38.9342888, -77.1776326)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# MD Columbia_MD
# MD Columbia_MD
# None
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Campbell, CA,
# Campbell, Santa Clara County, California, United States of America
# (37.2883259, -121.9456327)
#
# **********************
# Austin
# Austin, Travis County, Texas, United States of America
# (30.2711286, -97.7436994)
#
# **********************
# Dallas
# Dallas, Dallas County, Texas, United States of America
# (32.7762719, -96.7968558)
#
# **********************
# Natick, MA,
# Natick, Middlesex County, Massachusetts, United States of America
# (42.2836393, -71.3469959)
#
# **********************
# IL Chicago
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# Minneapolis, MN,
# Minneapolis, Hennepin County, Minnesota, United States of America
# (44.9772995, -93.2654691)
#
# **********************
# Austin
# Austin, Travis County, Texas, United States of America
# (30.2711286, -97.7436994)
#
# **********************
# San Francisco, California, United States
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Palo Alto, CA
# Palo Alto, Santa Clara County, California, United States of America
# (37.442156, -122.1634471)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# A California, Santa Clara
# A, John Montgomery Drive, Alum Rock, San José, Santa Clara County, California, 95148, United States of America
# (37.338045, -121.822342)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York        NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Des Moines IA
# Des Moines, Polk County, Iowa, United States of America
# (41.5910641, -93.6037148)
#
# **********************
# San Carlos, CA
# San Carlos, San Mateo County, California, United States of America
# (37.4982065, -122.266149723864)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# Kansas City
# Kansas City, Jackson County, Missouri, United States of America
# (39.0844687, -94.5630297)
#
# **********************
# Jersey City, NJ
# Jersey City, Hudson County, New Jersey, United States of America
# (40.7281575, -74.0776416)
#
# **********************
# San Francisco, California
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Dallas
# Dallas, Dallas County, Texas, United States of America
# (32.7762719, -96.7968558)
#
# **********************
# Columbus, Ohio
# Columbus, Franklin County, Ohio, United States of America
# (39.9622601, -83.0007064)
#
# **********************
# Omaha, NE
# Omaha, Douglas County, Nebraska, United States of America
# (41.2587317, -95.9378731)
#
# **********************
# Cincinnati  Ohio
# Cincinnati, Hamilton County, Ohio, United States of America
# (39.1014537, -84.5124601)
#
# **********************
# Chicago, IL
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Herndon, VA
# Herndon, Fairfax County, Virginia, United States of America
# (38.9695316, -77.3859478)
#
# **********************
# New York city
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# NJ All
# New Jersey, United States of America
# (40.0757384, -74.4041621)
#
# **********************
# Santa Clara, CA,
# Santa Clara, Santa Clara County, California, United States of America
# (37.3541132, -121.9551743)
#
# **********************
# Austin, TX
# Austin, Travis County, Texas, United States of America
# (30.2711286, -97.7436994)
#
# **********************
# PA Lancaster
# Lancaster, Lancaster County, Pennsylvania, United States of America
# (40.03813, -76.3056685)
#
# **********************
# Campbell, CA,
# Campbell, Santa Clara County, California, United States of America
# (37.2883259, -121.9456327)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Emeryville, CA
# Emeryville, Alameda County, California, United States of America
# (37.8314089, -122.2865265)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Philadelphia, PA
# Philadelphia, Philadelphia County, Pennsylvania, United States of America
# (39.9523993, -75.1635898)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
#
#
# None
#
# **********************
# Utah South Jordan
# South Jordan, Utah, United States of America
# (40.5621704, -111.9296579)
#
# **********************
# Orange County, California
# Orange County, California, United States of America
# (33.7500378, -117.870493)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Chicago, IL
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# New York, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Oakland , CA
# Oakland, Alameda County, California, United States of America
# (37.8044557, -122.2713562)
#
# **********************
# Utah South Jordan
# South Jordan, Utah, United States of America
# (40.5621704, -111.9296579)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# New York        NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Portland, OR
# Portland, Multnomah County, Oregon, United States of America
# (45.5202471, -122.6741948)
#
# **********************
# Northbrook, IL
# Northbrook, Cook County, Illinois, United States of America
# (42.1296875, -87.8305419)
#
# **********************
# RTP, NC
# RTP, Wake County, North Carolina, 27709, United States of America
# (35.857977, -78.8824859)
#
# **********************
# Sunnyvale, CA
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# CA Santa Monica
# Santa Monica, Los Angeles County, California, United States of America
# (34.0195598, -118.4869738)
#
# **********************
# Cambridge, MA,
# Cambridge, Middlesex County, Massachusetts, United States of America
# (42.3750997, -71.1056156)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# Redmond, WA,
# ...
# (1.3092327, 103.938911)
#
# **********************
# San Francisco, California
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Diego, CA
# San Diego, San Diego County, California, United States of America
# (32.7174209, -117.1627713)
#
# **********************
# Dallas or Houston, TX
# Dallas or Houston, TX
# None
#
# **********************
# Los Angeles, CA
# LA, Los Angeles County, California, United States of America
# (34.0543942, -118.2439408)
#
# **********************
# McLean, VA,
# McLean, Fairfax County, Virginia, United States of America
# (38.9342888, -77.1776326)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Phoenix, Arizona
# Phoenix, Maricopa County, Arizona, United States of America
# (33.4485866, -112.0773455)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Atlanta, GA
# Atlanta, Fulton County, Georgia, United States of America
# (33.7490987, -84.3901848)
#
# **********************
# New York, NY,
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Chicago
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Irvine, CA
# Irvine, Orange County, California, United States of America
# (33.6856969, -117.8259818)
#
# **********************
# Philadelphia, PA
# Philadelphia, Philadelphia County, Pennsylvania, United States of America
# (39.9523993, -75.1635898)
#
# **********************
# Los Angeles, CA
# LA, Los Angeles County, California, United States of America
# (34.0543942, -118.2439408)
#
# **********************
# Los Gatos, California
# Los Gatos, Santa Clara County, California, United States of America
# (37.226611, -121.9746796)
#
# **********************
# Irvine, CA,
# Irvine, Orange County, California, United States of America
# (33.6856969, -117.8259818)
#
# **********************
# Oregon, Hillsboro
# Hillsboro, Washington County, Oregon, United States of America
# (45.5228939, -122.9898269)
#
# **********************
# Sunnyvale, CA
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# New York  NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Evanston, IL,
# Evanston, Cook County, Illinois, United States of America
# (42.0447388, -87.6930458)
#
# **********************
# Arlington, TX,
# Arlington, Tarrant County, Texas, United States of America
# (32.7355816, -97.1071185)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Dallas    TX
# Dallas, Dallas County, Texas, United States of America
# (32.7762719, -96.7968558)
#
# **********************
# SOMERS
# Somers, Town of Somers, Westchester County, New York, United States of America
# (41.3281498, -73.6856856)
#
# **********************
# A Alpharetta, GA
# Alpharetta, Fulton County, Georgia, United States of America
# (34.0709576, -84.2747328)
#
# **********************
# Chicago, Illinois,
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Denver, CO
# Denver, Denver County, Colorado, United States of America
# (39.7391536, -104.9847033)
#
# **********************
# Denver, CO
# Denver, Denver County, Colorado, United States of America
# (39.7391536, -104.9847033)
#
# **********************
# Miami
# Miami, Miami-Dade County, Florida, United States of America
# (25.7742658, -80.1936588)
#
# **********************
# Bridgewater   A   New Jersey
# Bridgewater, Main Street, Bridgewater Township, Somerset County, New Jersey, 08805, United States of America
# (40.5599163, -74.5516572)
#
# **********************
# Bridgewater   A   New Jersey
# Bridgewater, Main Street, Bridgewater Township, Somerset County, New Jersey, 08805, United States of America
# (40.5599163, -74.5516572)
#
# **********************
# Seattle, WA   SODO
# SODO, 500, South Lander Street, International District/Chinatown, Seattle, King County, Washington, 98134, United States of America
# (47.5812603, -122.327405)
#
# **********************
# Miami, FL
# Miami, Miami-Dade County, Florida, United States of America
# (25.7742658, -80.1936588)
#
# **********************
# Silicon Valley
# Le Silicon Valley, Boulevard Georges Pompidou, Beaulieu - Maladrerie - Saint-Paul, Caen, Calvados, Normandie, France métropolitaine, 14000, France
# (49.179302, -0.394566848275862)
#
# **********************
# San Jose, CA
# San José, Santa Clara County, California, United States of America
# (37.3361905, -121.8905832)
#
# **********************
# Boston
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New Brunswick, NJ,
# New Brunswick, Middlesex County, New Jersey, United States of America
# (40.4862174, -74.4518172)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Augusta, GA
# Augusta, Richmond, Georgia, United States of America
# (33.4709714, -81.9748428)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# RTP, NC
# RTP, Wake County, North Carolina, 27709, United States of America
# (35.857977, -78.8824859)
#
# **********************
# New York City, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Massachusetts Boston
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Seattle, WA
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# Menlo Park, CA
# Menlo Park, San Mateo County, California, United States of America
# (37.4538274, -122.182187)
#
# **********************
# A Alpharetta, GA
# Alpharetta, Fulton County, Georgia, United States of America
# (34.0709576, -84.2747328)
#
# **********************
# New York, NY, A
# A, Van Wyck Expressway, Bayswater, Queens County, NYC, New York, 11010, United States of America
# (40.644839, -73.7976493)
#
# **********************
#
#
# None
#
# **********************
# Princeton, New Jersey ,
# Princeton, Mercer County, New Jersey, United States of America
# (40.3492744, -74.6592957)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Carlos, CA
# San Carlos, San Mateo County, California, United States of America
# (37.4982065, -122.266149723864)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Austin
# Austin, Travis County, Texas, United States of America
# (30.2711286, -97.7436994)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# New York, NY; Los Angeles, CA; Sacramento, CA; Boston, MA; Reno, NV
# New York, NY; Los Angeles, CA; Sacramento, CA; Boston, MA; Reno, NV
# None
#
# **********************
# San Mateo, CA
# San Mateo County, California, United States of America
# (37.496904, -122.3330572)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Boston
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Philadelphia
# Philadelphia, Philadelphia County, Pennsylvania, United States of America
# (39.9523993, -75.1635898)
#
# **********************
# Hartford, CT,
# Hartford, Hartford County, Connecticut, United States of America
# (41.7634935, -72.6830522)
#
# **********************
# San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# Palo Alto
# Palo Alto, Santa Clara County, California, United States of America
# (37.442156, -122.1634471)
#
# **********************
# CA Mountain View
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Pleasanton, CA, A
# Pleasanton, Alameda County, California, United States of America
# (37.6624312, -121.8746788)
#
# **********************
# Lake Forest or Rosemont IL or Fond du Lac, WI
# Lake Forest or Rosemont IL or Fond du Lac, WI
# None
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# Englewood, CO
# Englewood, Arapahoe County, Colorado, United States of America
# (39.6482059, -104.987964)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# Austin, TX
# Austin, Travis County, Texas, United States of America
# (30.2711286, -97.7436994)
#
# **********************
# Boston, MA,
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# CA Sunnyvale
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# California   San Francisco
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Provo, UT
# Provo, Utah County, Utah, United States of America
# (40.2338438, -111.6585336)
#
# **********************
# Provo, UT
# Provo, Utah County, Utah, United States of America
# (40.2338438, -111.6585336)
#
# **********************
# Portland, OR
# Portland, Multnomah County, Oregon, United States of America
# (45.5202471, -122.6741948)
#
# **********************
# Dearborn   Michigan
# Dearborn, Wayne County, Michigan, United States of America
# (42.3222599, -83.1763144)
#
# **********************
# Sunnyvale, CA
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# Armonk, NY
# Armonk, Town of North Castle, New York, United States of America
# (41.1264849, -73.7140194)
#
# **********************
# Portland, OR
# Portland, Multnomah County, Oregon, United States of America
# (45.5202471, -122.6741948)
#
# **********************
# Pasadena, CA   Los Angeles
# Pasadena, Los Angeles County, California, United States of America
# (34.1476452, -118.1444778)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# Kirkland, Wa
# Kirkland, King County, Washington, United States of America
# (47.6859573, -122.1920248)
#
# **********************
# Seattle, WA
# Seattle, King County, Washington, United States of America
# (47.6038321, -122.3300623)
#
# **********************
# New York
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Sunnyvale, CA
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# Baltimore, Maryland
# Baltimore, Maryland, United States of America
# (39.2908608, -76.6108072)
#
# **********************
# Tampa,FL
# Tampa, Hillsborough County, Florida, United States of America
# (27.9477595, -82.4584439)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Tampa, Florida
# Tampa, Hillsborough County, Florida, United States of America
# (27.9477595, -82.4584439)
#
# **********************
# Chicago
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# RTP, NC
# RTP, Wake County, North Carolina, 27709, United States of America
# (35.857977, -78.8824859)
#
# **********************
# Chicago
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Georgia Atlanta
# Atlanta, Fulton County, Georgia, United States of America
# (33.7490987, -84.3901848)
#
# **********************
# Utah South Jordan
# South Jordan, Utah, United States of America
# (40.5621704, -111.9296579)
#
# **********************
# Illinois Chicago
# Chicago, Cook County, Illinois, United States of America
# (41.8755546, -87.6244211)
#
# **********************
# Mountain View
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# Boston, MA
# Boston, Suffolk County, Massachusetts, United States of America
# (42.3604823, -71.0595677)
#
# **********************
# CA Mountain View
# Mountain View, Santa Clara County, California, United States of America
# (37.3855745, -122.0820499)
#
# **********************
# Hartford, Connecticut
# Hartford, Hartford County, Connecticut, United States of America
# (41.7634935, -72.6830522)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Englewood, CO
# Englewood, Arapahoe County, Colorado, United States of America
# (39.6482059, -104.987964)
#
# **********************
# Kirkland, WA
# Kirkland, King County, Washington, United States of America
# (47.6859573, -122.1920248)
#
# **********************
# Cambridge, MA
# Cambridge, Middlesex County, Massachusetts, United States of America
# (42.3750997, -71.1056156)
#
# **********************
# Sunnyvale, CA
# Sunnyvale, Santa Clara County, California, United States of America
# (37.3688301, -122.0363495)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# New York
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# New York City
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Santa Clara Valley   California
# SJSU, El Paseo de Cesar E Chavez, SoFA, Japantown, San José, Santa Clara County, California, 95112, United States of America
# (37.3352583, -121.88130228815)
#
# **********************
# San Francisco, CA
# SF, California, United States of America
# (37.7792768, -122.4192703)
#
# **********************
# Redmond, WA,
# Redmond, King County, Washington, United States of America
# (47.6694141, -122.1238766)
#
# **********************
# A Sunnyvale, CA
# Sunnyvale, Santa Clara County, California, CA 94086, United States of America
# (37.3554646486399, -122.010835772708)
#
# **********************
# New York, NY, A
# A, Van Wyck Expressway, Bayswater, Queens County, NYC, New York, 11010, United States of America
# (40.644839, -73.7976493)
#
# **********************
# New York, NY
# NYC, New York, United States of America
# (40.7305991, -73.9865811)
#
# **********************
# Los Angeles, CA
# LA, Los Angeles County, California, United States of America
# (34.0543942, -118.2439408)
#
# **********************

# %%
us['full_address'] = address

# %%
def featurizing_locations(us):
    address = []
    longitude = []
    for city in us['location']: 
        geolocator = Nominatim()
        city = replace_words(city)
        print str(city)
        try:
            location = geolocator.geocode(city)
            address.append(location.address)
            longitude.append(location[1])
        except:
            address.append(city)
            longitude.append(None)
        print address[-1]
        print longitude[-1]
        print '\n**********************'
    return address, longitude

# %%
us['full_address'] = address
us
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3584d165dc76> in <module>()
# ----> 1 us['full_address'] = address
#       2 us
#
# NameError: name 'address' is not defined

# %%
address = pd.Series(address)
print address.shape
us.shape
# Out:
# (547,)
# (547, 9)

# %%
us.add({'Full Address' : pd.Series(str(address))}, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-6913c587d8c6> in <module>()
# ----> 1 us.add({'Full Address' : pd.Series(str(address))}, axis = 1)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/ops.pyc in f(self, other, axis, level, fill_value)
#    1025                                  (other.shape, ))
#    1026         else:
# -> 1027             return self._combine_const(other, na_op)
#    1028
#    1029     f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_const(self, other, func, raise_on_error)
#    3480             return self
#    3481
# -> 3482         new_data = self._data.eval(func=func, other=other, raise_on_error=raise_on_error)
#    3483         return self._constructor(new_data)
#    3484
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, **kwargs)
#    2838
#    2839     def eval(self, **kwargs):
# -> 2840         return self.apply('eval', **kwargs)
#    2841
#    2842     def setitem(self, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2821
#    2822             kwargs['mgr'] = self
# -> 2823             applied = getattr(b, f)(**kwargs)
#    2824             result_blocks = _extend_blocks(applied, result_blocks)
#    2825
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, func, other, raise_on_error, try_cast, mgr)
#    1129             raise
#    1130         except Exception as detail:
# -> 1131             result = handle_error()
#    1132
#    1133         # technically a broadcast error in numpy can 'work' by returning a
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/internals.pyc in handle_error()
#    1113             if raise_on_error:
#    1114                 raise TypeError('Could not operate %s with block values %s'
# -> 1115                                 % (repr(other), str(detail)))
#    1116             else:
#    1117                 # return the values
#
# TypeError: Could not operate {'Full Address': 0    0      Washington, District of Columbia, Unite...
# dtype: object} with block values unsupported operand type(s) for +: 'int' and 'dict'

# %%
for city in cities:
    for c
    df_cities
# Out:
# [['washington', 'd', 'c', 'metro', 'area'],
#  ['san', 'francisco', '', 'california', '', 'us'],
#  ['palo', 'alto', 'ca', 'us'],
#  ['herndon', 'va'],
#  ['us', 'oregon', 'hillsboro'],
#  ['greater', 'philadelphia', 'area'],
#  ['irvine', 'california'],
#  ['l5', 'chicago', 'il', '', 'cnvr', '60606'],
#  ['chicago', 'il', 'us'],
#  ['mountain', 'view', 'ca'],
#  ['redmond', 'wa', 'us'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['new', 'york', 'ny'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['nj', 'all'],
#  ['columbia', 'md'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['washington', 'd', 'c', 'metro', 'area'],
#  ['santa', 'monica', 'ca', 'us'],
#  ['philadelphia', 'pa'],
#  ['irvine', 'ca'],
#  ['augusta', 'ga'],
#  ['denver', 'co'],
#  ['dallas', 'tx'],
#  ['irvine', 'ca'],
#  ['greater', 'boston', 'area'],
#  ['houston', 'texas', 'area'],
#  ['cambridge', 'ma', 'us'],
#  ['redmond', 'wa', 'us'],
#  ['lake', 'forest', 'or', 'rosemont', 'il', 'or', 'fond', 'du', 'lac', 'wi'],
#  ['new', 'york', 'ny', 'usa'],
#  ['new', 'york', 'ny'],
#  ['new', 'york', 'ny'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['austin', 'tx', 'us'],
#  ['boston', 'massachusetts'],
#  ['redmond', 'wa', 'us'],
#  ['dallas', 'tx'],
#  ['greater', 'chicago', 'area'],
#  ['us', 'wa', 'bellevue'],
#  ['redmond', 'wa', 'us'],
#  ['mayfield', 'village', 'oh'],
#  ['bellevue', '', 'wa', '', 'us'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['usa', 'texas', 'dallas', 'metroplex'],
#  ['irvine', 'ca'],
#  ['denver', 'co'],
#  ['new', 'york', 'ny'],
#  ['charlotte', 'north', 'carolina', 'area'],
#  ['palo', 'alto', 'ca'],
#  ['rtp', 'nc'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['el', 'segundo', 'california', 'us'],
#  ['chicago', 'il'],
#  ['dallas', 'tx'],
#  ['chicago', 'il'],
#  ['chicago', 'il'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['san', 'francisco', 'ca'],
#  ['austin', 'tx', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['hershey', 'pa', 'us'],
#  ['santa', 'monica', 'ca', 'us'],
#  ['west', 'des', 'moines', 'ia', 'us'],
#  ['seattle', 'wa', 'us'],
#  ['charlottesville', 'va', 'us'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['philadelphia', 'pa', 'area'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['boston'],
#  ['boston', 'ma'],
#  ['plano', 'tx'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['new', 'york', 'ny'],
#  ['san', 'francisco', '', 'ca'],
#  ['downtown', 'manhattan'],
#  ['downtown', 'seattle'],
#  ['lincoln', 'ne'],
#  ['palo', 'alto', 'ca'],
#  ['na', 'usa', 'iowa', 'johnston'],
#  ['redmond', 'wa', 'us'],
#  ['bellevue', 'wa', 'us'],
#  ['mountain', 'view', 'ca'],
#  ['bellevue', 'wa', 'us'],
#  ['greater', 'los', 'angeles', 'area'],
#  ['redwood', 'city', 'ca'],
#  ['dallas', 'tx', ''],
#  ['bellevue', 'wa', 'us'],
#  ['us', 'wa', 'seattle'],
#  ['boise', 'id', 'us'],
#  ['greater', 'chicago', 'area'],
#  ['miami/fort', 'lauderdale', 'area'],
#  ['englewood', 'co'],
#  ['new', 'york', 'ny'],
#  ['redmond', 'wa', 'us'],
#  ['redmond', 'wa', 'us'],
#  ['annapolis', 'junction', 'maryland'],
#  ['seattle', 'wa'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['mayfield', 'village', 'oh'],
#  ['boston', 'ma', 'or', 'los', 'angeles', 'ca'],
#  ['dallas'],
#  ['andover', 'ma'],
#  ['greater', 'los', 'angeles', 'area'],
#  ['greater', 'new', 'york', 'area'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['greater', 'atlanta', 'area'],
#  ['san', 'jose', 'ca'],
#  ['homewood'],
#  ['mclean', 'va'],
#  ['cambridge', 'ma', 'us'],
#  ['culver', 'city', 'ca'],
#  ['greater', 'denver', 'area'],
#  ['phoenix', 'arizona', 'area'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['mclean', 'va', 'us'],
#  ['mclean', 'va', 'us'],
#  ['mclean', 'va', 'us'],
#  ['mclean', 'va', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['chicago', 'il'],
#  ['new', 'york', 'ny'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'jose', 'ca', 'us'],
#  ['mclean', 'va', 'us'],
#  ['arlington', 'va', 'us'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['birmingham', 'al', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'jose', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['boston', 'ma', 'us'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['carlsbad', 'ca', 'us'],
#  ['ann', 'arbor', 'mi', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['san', 'jose', 'ca', 'us'],
#  ['bristol', 'ct', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['calabasas', 'ca', 'us'],
#  ['columbia', 'md', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['carlsbad', 'ca', 'us'],
#  ['menlo', 'park', 'ca', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['beverly', 'hills', 'ca', 'us'],
#  ['carlsbad', 'ca', 'us'],
#  ['carlsbad', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['louisville', 'ky', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['folsom', 'ca', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['medford', 'ma', 'us'],
#  ['palo', 'alto', 'ca', 'us'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['austin', 'tx', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['chicago', 'il', 'area'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['chicago'],
#  ['san', 'francisco'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['arlington', 'va', 'us'],
#  ['vinings', 'ga', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['santa', 'barbara', 'california', 'area'],
#  ['chicago', 'illinois'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['austin', 'tx', 'us'],
#  ['golden', 'valley', 'mn', 'us'],
#  ['san', 'bruno', 'ca'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['framingham'],
#  ['usa', 'alpharetta', 'ga'],
#  ['chicago', '', 'illinois'],
#  ['mclean', '', 'virginia'],
#  ['wilmington', '', 'de'],
#  ['san', 'francisco', '', 'california'],
#  ['santa', 'barbara', 'california', 'area'],
#  ['seattle', '', 'wa'],
#  ['portland', 'or'],
#  ['sunnyvale', 'ca'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['woodlands', 'texas'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['san', 'francisco', 'ca'],
#  ['carlsbad', 'ca', 'us'],
#  ['draper', 'ut', ''],
#  ['venice', 'ca'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['boston', 'ma'],
#  ['chantilly', 'va', 'us'],
#  ['port', 'washington'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['grand', 'rapids'],
#  ['springfield', 'va', 'us'],
#  ['springfield', 'va', 'us'],
#  ['us', 'dc', 'washington', 'd', 'c', '', '1300', 'con'],
#  ['wayne', 'pa', 'us'],
#  ['san', 'ramon', '', 'ca'],
#  ['boston', 'ma', 'us'],
#  ['gaithersburg', 'md'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['greenville', 'sc', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['springfield', 'va', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['st', 'louis', 'mo', 'us'],
#  ['fairfield', 'ca', 'us'],
#  ['san', 'jose', 'ca', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['east', 'hartford', 'ct', 'us'],
#  ['oldsmar', 'fl', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['chantilly', 'va', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['st', 'louis', 'mo', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['boston', 'ma', 'us'],
#  ['boston', 'ma', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['herndon', 'va', 'us'],
#  ['springfield', 'va', 'us'],
#  ['america', 'il', 'us'],
#  ['honolulu', 'hi', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['boston', 'ma', 'us'],
#  ['alexandria', 'va', 'us'],
#  ['dallas', 'tx', 'us'],
#  ['boston', 'ma', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['bentonville', 'ar', 'us'],
#  ['tampa', 'fl', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['pittsburgh', 'pa', 'us'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['seattle', 'wa', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['mountain', 'view', 'ca', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['denver', 'co', 'us'],
#  ['boston', 'ma', 'us'],
#  ['austin', 'tx', 'us'],
#  ['columbus', 'in', 'us'],
#  ['philadelphia', 'pa', 'us'],
#  ['windsor', 'ct', 'us'],
#  ['woburn', 'ma', 'us'],
#  ['chicago', 'il', 'us'],
#  ['ridge', 'ny', 'us'],
#  ['columbus', 'in', 'us'],
#  ['mclean', 'va', 'us'],
#  ['ridge', 'ny', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['redwood', 'city', 'ca', 'us'],
#  ['herndon', 'va', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['eagan', 'mn', 'us'],
#  ['santa', 'monica', 'ca', 'us'],
#  ['louisville', 'ky', 'us'],
#  ['mountain', 'view', 'ca', 'us'],
#  ['dallas', 'tx', 'us'],
#  ['glen', 'burnie', 'md', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['scotts', 'valley', 'ca', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['seattle', 'wa', 'us'],
#  ['baltimore', 'md', 'us'],
#  ['framingham', 'ma', 'us'],
#  ['silver', 'spring', 'md', 'us'],
#  ['norwalk', 'ct', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['hoffman', 'estates', 'il', 'us'],
#  ['windsor', 'locks', 'ct', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['washington', 'ma', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'antonio', 'tx', 'us'],
#  ['reston', 'va', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['philadelphia', 'pa', 'us'],
#  ['sunnyvale', 'sunnyvale', 'california', 'united', 'states'],
#  ['natick', 'ma', 'us'],
#  ['san', 'francisco', 'ca', 'united', 'states'],
#  ['plano', 'tx', 'us'],
#  ['chicago', 'il', 'us'],
#  ['austin', 'tx', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['reston', 'va', 'us'],
#  ['arlington', 'va', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['salt', 'lake', 'city', 'ut', 'us'],
#  ['irving', 'tx', 'us'],
#  ['plano', 'tx', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['costa', 'mesa', 'ca', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['reston', 'va', 'us'],
#  ['boulder', 'co', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['alexandria', 'va', 'us'],
#  ['homewood', 'il', 'us'],
#  ['san', 'jose', 'california'],
#  ['seattle', 'wa', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['chicago', 'il', 'us'],
#  ['brooklyn', 'ny', 'us'],
#  ['worcester', 'ma', 'us'],
#  ['kent', 'wa', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['boston', 'ma', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['chicago', 'il', 'us'],
#  ['mclean', 'va', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['rochester', 'mn', 'us'],
#  ['charlottesville', 'va', 'us'],
#  ['nashville', 'tn', 'us'],
#  ['raleigh', 'nc', 'us'],
#  ['austin', 'tx', 'us'],
#  ['provo', 'ut', 'us'],
#  ['fort', 'collins', 'co', 'us'],
#  ['greenville', 'sc', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['ridgecrest', 'ca', 'us'],
#  ['oldsmar', 'fl', 'us'],
#  ['indianapolis', 'in', 'us'],
#  ['boise', 'id', 'us'],
#  ['hartford', 'ct', 'us'],
#  ['denver', 'co', 'us'],
#  ['birmingham', 'al', 'us'],
#  ['mountain', 'view', 'ca', 'us'],
#  ['detroit', 'mi', 'us'],
#  ['miami', 'fl', 'us'],
#  ['austin', 'tx', 'us'],
#  ['berkeley', 'heights', 'nj', 'us'],
#  ['bentonville', 'ar', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['princeton', 'nj', 'us'],
#  ['chicago', 'il', 'us'],
#  ['reston', 'va', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['austin', 'tx', 'us'],
#  ['chicago', 'il', 'us'],
#  ['southfield', 'mi', 'us'],
#  ['dearborn', 'mi', 'us'],
#  ['vienna', 'va', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['mountain', 'view', 'ca', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['springfield', 'va', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['morrisville', 'nc', 'us'],
#  ['denver', 'co', 'us'],
#  ['denver', 'co', 'us'],
#  ['pittsburgh', 'pa', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['mclean', 'va', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['arlington', 'va', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['torrance', 'ca', 'us'],
#  ['tampa', 'fl', 'us'],
#  ['warren', 'county', 'oh', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['mesa', 'az', 'us'],
#  ['redmond', 'wa', 'us'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['jacksonville', 'fl', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['west', 'jordan', 'ut', 'us'],
#  ['crystal', 'spring', 'va', 'us'],
#  ['hopewell', 'va', 'us'],
#  ['mountain', 'view', 'ca', 'us'],
#  ['bethesda', 'md', 'us'],
#  ['wilmington', 'de', 'us'],
#  ['fort', 'washington', 'pa', 'us'],
#  ['somerville', 'ma', 'us'],
#  ['camden', 'nj', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['charlotte', 'nc', 'us'],
#  ['boston', 'ma', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['alpharetta', 'ga', 'us'],
#  ['mclean', 'va', 'us'],
#  ['san', 'jose', 'ca', 'us'],
#  ['alpharetta', 'ga', 'us'],
#  ['philadelphia', 'pa', 'us'],
#  ['boston', 'ma', 'us'],
#  ['draper', 'ut', 'us'],
#  ['baltimore', 'md', 'us'],
#  ['white', 'plains', 'ny', 'us'],
#  ['mclean', 'va', 'us'],
#  ['seattle', 'wa', 'us'],
#  ['fort', 'washington', 'pa', 'us'],
#  ['springfield', 'va', 'us'],
#  ['alexandria', 'va', 'us'],
#  ['emeryville', 'ca', 'us'],
#  ['mclean', 'va', 'us'],
#  ['green', 'bay', 'wi', 'us'],
#  ['port', 'washington', 'ny', 'us'],
#  ['fort', 'washington', 'pa', 'us'],
#  ['fort', 'washington', 'pa', 'us'],
#  ['jenkintown', 'pa', 'us'],
#  ['fairfield', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['chicago', 'il', 'us'],
#  ['philadelphia', 'pa', 'us'],
#  ['springfield', 'va', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['san', 'jose', 'ca', 'us'],
#  ['redwood', 'city', 'ca', 'us'],
#  ['kansas', 'city', 'mo', 'us'],
#  ['boston', 'ma', 'us'],
#  ['south', 'san', 'francisco', 'ca', 'us'],
#  ['chicago', 'il', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['bentonville', 'ar', 'us'],
#  ['boston', 'ma', 'us'],
#  ['downstown', 'nj', 'us'],
#  ['springfield', 'va', 'us'],
#  ['irvine', 'ca', 'us'],
#  ['portland', 'or', 'us'],
#  ['san', 'carlos', 'ca', 'us'],
#  ['waltham', 'ma', 'us'],
#  ['greensboro', 'nc', 'us'],
#  ['troy', 'mi', 'us'],
#  ['boston', 'ma', 'us'],
#  ['princeton', 'nj', 'us'],
#  ['auburn', 'hills', 'mi', 'us'],
#  ['boston', 'ma', 'us'],
#  ['burlingame', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'jose', 'ca'],
#  ['greater', 'seattle', 'area'],
#  ['seattle', 'wa'],
#  ['palo', 'alto', 'ca', 'us'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['charlottesville', 'va', 'us'],
#  ['hanover', 'md', 'us'],
#  ['denver', 'co', 'us'],
#  ['san', 'antonio', 'tx', 'us'],
#  ['st', 'louis', 'mo', 'us'],
#  ['santa', 'clara', 'valley', '', 'california', '', 'us'],
#  ['san', 'francisco'],
#  ['cincinnati', '', 'ohio', '', 'us'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['redmond', 'wa', 'us'],
#  ['emeryville', 'ca'],
#  ['redmond', 'wa', 'us'],
#  ['redmond', 'wa', 'us'],
#  ['san', 'francisco', 'ca', ''],
#  ['dallas', 'or', 'houston', 'tx'],
#  ['south', 'norwalk', 'ct'],
#  ['new', 'york', 'ny'],
#  ['usa', 'alpharetta', 'ga'],
#  ['santa', 'clara', 'valley', '', 'california', '', 'us'],
#  ['provo', 'ut'],
#  ['houston', '', 'us'],
#  ['sunnyvale', 'ca'],
#  ['us', 'mn', 'golden', 'valley'],
#  ['new', 'york', 'ny'],
#  ['grapevine', 'us', 'tx'],
#  ['philadelphia', 'pa'],
#  ['washington', 'd', 'c'],
#  ['santa', 'clara', 'california', ''],
#  ['us', 'maryland', 'chevy', 'chase'],
#  ['los', 'gatos', 'california'],
#  ['redmond', 'wa', 'us'],
#  ['palo', 'alto', 'ca'],
#  ['us', 'virginia', 'arlington'],
#  ['santa', 'monica', 'ca'],
#  ['southlake', 'us', 'tx'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['cambridge', 'massachusetts'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['san', 'jose', 'ca'],
#  ['palo', 'alto'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['austin'],
#  ['austin'],
#  ['rtp', 'nc'],
#  ['greater', 'los', 'angeles', 'area'],
#  ['greater', 'seattle', 'area'],
#  ['campbell', 'ca'],
#  ['santa', 'clara', 'valley', '', 'california', '', 'us'],
#  ['beverly', 'hills', 'california'],
#  ['greater', 'boston', 'area'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['san', 'francisco'],
#  ['chicago', 'il'],
#  ['san', 'francisco', 'ca'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['san', 'francisco', 'ca'],
#  ['usa', 'california', 'santa', 'clara'],
#  ['redmond', 'wa', 'us'],
#  ['san', 'francisco', '', 'california', '', 'us'],
#  ['chicago', 'il'],
#  ['north', 'america', 'us', 'ca', 'san', 'francisco'],
#  ['santa', 'monica', 'ca'],
#  ['shelton', 'ct'],
#  ['los', 'angeles', 'ca'],
#  ['redmond', 'wa', 'us'],
#  ['oakland', '', 'ca'],
#  ['redmond', 'wa', 'us'],
#  ['new', 'york'],
#  ['bellevue', 'wa', 'us'],
#  ['san', 'francisco', ''],
#  ['san', 'francisco', 'ca'],
#  ['rtp', 'nc'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['redmond', 'wa', 'us'],
#  ['home',
#   'based',
#   '',
#   'ideally',
#   'us',
#   'west',
#   'coast',
#   'or',
#   'mountain',
#   'region'],
#  ['san', 'francisco', 'financial', 'district'],
#  ['pleasanton', 'ca', 'usa'],
#  ['redmond', 'wa', 'us'],
#  ['usa', 'sunnyvale', 'ca'],
#  ['seattle', 'wa'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['mahwah', '', 'nj', '', 'us'],
#  ['menlo', 'park', 'ca'],
#  ['dallas', '', 'tx', '', 'us'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['new', 'york', 'city', 'ny'],
#  ['rockville', 'md'],
#  ['us', 'ca', 'mountain', 'view'],
#  ['new',
#   'york',
#   'ny',
#   'los',
#   'angeles',
#   'ca',
#   'sacramento',
#   'ca',
#   'boston',
#   'ma',
#   'reno',
#   'nv'],
#  ['san', 'jose', 'ca'],
#  ['chicago', 'illinois', 'us'],
#  ['redmond', 'wa', 'us'],
#  ['bellevue', '', 'wa', '', 'us'],
#  ['boston', 'ma', 'us'],
#  ['pleasanton', 'ca', 'usa'],
#  ['new', 'york'],
#  ['dearborn', '', 'michigan'],
#  ['us', 'co', 'longmont', 'colorado'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['redmond', 'wa', 'us'],
#  ['new', 'york', 'ny'],
#  ['boston', 'ma'],
#  ['seattle', 'wa'],
#  ['san', 'francisco', 'ca'],
#  ['los', 'altos', 'california'],
#  ['bellevue', '', 'wa', '', 'us'],
#  ['houston', '', 'us'],
#  ['alpharetta'],
#  ['redmond', 'wa', 'us'],
#  ['new', 'york', 'ny'],
#  ['us', 'california', 'westlake', 'village'],
#  ['norfolk', 'virginia', 'area'],
#  ['redmond', 'wa', 'us'],
#  ['new', 'york', 'ny'],
#  ['usa', 'sunnyvale', 'ca'],
#  ['san', 'jose', 'ca'],
#  ['san', 'francisco', 'ca', '', 'us'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['new', 'york', 'ny'],
#  ['seattle', 'wa'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['boston', 'ma'],
#  ['new', 'york', 'city', 'ny'],
#  ['los', 'gatos', 'california'],
#  ['san', 'francisco', 'ca', '(downtown)', ''],
#  ['london'],
#  ['bellevue', '', 'wa', '', 'us'],
#  ['santa', 'monica', 'ca'],
#  ['san', 'mateo'],
#  ['national'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['irvine', 'usa', 'ca'],
#  ['ca', 'san', 'mateo'],
#  ['bellevue', 'wa', 'us'],
#  ['new', 'york', 'us', 'ny'],
#  ['redmond', 'wa', 'us'],
#  ['redmond', 'wa', 'us'],
#  ['us', 'ny', 'new', 'york'],
#  ['us', 'ny', 'new', 'york'],
#  ['redmond', 'wa', 'us'],
#  ['irvine', 'ca'],
#  ['culver', 'city', 'ca'],
#  ['raleigh', 'durham', 'north', 'carolina', 'area'],
#  ['sunnyvale', 'ca'],
#  ['san', 'ramon', 'ca'],
#  ['san', 'jose', 'or', 'san', 'francisco'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['houston', 'tx', 'us'],
#  ['eden', 'prairie', 'mn', 'us'],
#  ['westminster', 'co', 'us'],
#  ['hershey', 'pa', 'us'],
#  ['fayetteville', 'nc', 'us'],
#  ['fairfax', 'va', 'us'],
#  ['plano', 'tx', 'us'],
#  ['phoenix', 'az', 'us'],
#  ['sunnyvale', 'ca', 'us'],
#  ['chicago', 'il', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['boston', 'ma', 'us'],
#  ['bellevue', 'wa', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['sunnyvale', 'ca', 'us'],
#  ['redwood', 'city', 'ca', 'us'],
#  ['alpharetta', 'ga', 'us'],
#  ['houston', 'texas'],
#  ['santa', 'monica'],
#  ['austin', 'texas', 'area'],
#  ['san', 'francisco'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['boston', 'ma', 'us'],
#  ['fairfax', 'va', 'us'],
#  ['austin', 'tx', 'us'],
#  ['boston', 'ma', 'us'],
#  ['lafayette', 'la', 'us'],
#  ['lehi', 'ut', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['greater', 'chicago', 'area'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['new', 'york', 'metro'],
#  ['san', 'francisco', 'california', 'us'],
#  ['redwood', 'city', '', 'california', '', 'us'],
#  ['new', 'york', 'city'],
#  ['san', 'francisco', 'california', 'usa'],
#  ['santa', 'clara', 'valley', '', 'california', '', 'us'],
#  ['san', 'francisco'],
#  ['north', 'america', 'us', 'md', 'columbia_md'],
#  ['chicago', 'il'],
#  ['santa', 'clara', 'valley', '', 'california', '', 'us'],
#  ['boston', 'ma'],
#  ['san', 'jose', 'ca'],
#  ['us', 'oregon', 'hillsboro'],
#  ['new', 'york', 'ny', 'us'],
#  ['san', 'francisco', 'california', 'us'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['bellevue', 'wa', 'us'],
#  ['sunnyvale', 'ca'],
#  ['washington'],
#  ['austin', 'tx', 'us'],
#  ['greater', 'baltimore', 'area'],
#  ['redmond', 'wa', 'us'],
#  ['los', 'angeles', 'ca'],
#  ['seattle', 'wa'],
#  ['mountain', 'view'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['hanover', 'ma'],
#  ['redmond', 'wa', 'us'],
#  ['redmond', 'wa', 'us'],
#  ['austin'],
#  ['cambridge', 'ma'],
#  ['new', 'york', 'ny'],
#  ['san', 'francisco', 'ca'],
#  ['campbell', 'ca', 'us'],
#  ['greater', 'baltimore', 'area'],
#  ['san', 'francisco', 'california', 'us'],
#  ['san', 'francisco', 'california', 'us'],
#  ['phoenix', 'arizona', 'area'],
#  ['menlo', 'park', '', 'california', '', 'us'],
#  ['redwood', 'city', 'ca'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['somers'],
#  ['menlo', 'park', '', 'california', '', 'us'],
#  ['orlando', 'florida', 'area'],
#  ['seattle', 'wa', 'us'],
#  ['san', 'francisco', 'ca'],
#  ['austin', 'tx', 'us'],
#  ['san', 'francisco'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['round', 'rock', 'tx'],
#  ['new', 'york', 'city', 'ny'],
#  ['rtp', 'nc'],
#  ['us'],
#  ['phoenix',
#   'az',
#   '',
#   'will',
#   'relocate',
#   'you',
#   'from',
#   'any',
#   'us',
#   'state',
#   '(ny',
#   'ma',
#   'etc',
#   ')'],
#  ['us', 'wa', 'seattle'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['atlanta', 'ga'],
#  ['san', 'mateo', 'ca'],
#  ['portland', 'or'],
#  ['bellevue', 'wa', 'us'],
#  ['bellevue', 'wa', 'us'],
#  ['san', 'francisco', '', 'california', '', 'us'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['redmond', 'wa', 'us'],
#  ['nan'],
#  ['armonk', 'ny'],
#  ['baltimore', 'maryland', 'area'],
#  ['scotts', 'valley', 'ca'],
#  ['us', 'tx', 'dallas', 'ft', 'worth', '', 'southlake'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['philadelphia', 'pa'],
#  ['palo', 'alto', 'ca'],
#  ['seattle', 'wa'],
#  ['sunnyvale', 'ca', 'us'],
#  ['cincinnati', 'area'],
#  ['boston', 'ma', 'or', 'los', 'angeles', 'ca'],
#  ['boston', 'ma'],
#  ['nyc'],
#  ['seattle', 'wa'],
#  ['us', 'ca', 'sunnyvale'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['sunnyvale'],
#  ['san', 'francisco', 'ca'],
#  ['san', 'francisco', '', 'ca'],
#  ['us', 'tx', 'houston', '', 'corp'],
#  ['greater', 'chicago', 'area'],
#  ['dearborn', '', 'michigan'],
#  ['san', 'francisco'],
#  ['mountain', 'view', '', 'castro', 'station'],
#  ['seattle'],
#  ['redmond', 'wa', 'us'],
#  ['mountain', 'view', 'ca'],
#  ['chicago', 'illinois', 'us'],
#  ['redmond', 'wa', 'us'],
#  ['northbrook', '', 'il'],
#  ['seattle'],
#  ['mc', 'lean', 'va'],
#  ['chicago'],
#  ['sunnyvale', 'ca'],
#  ['new', 'york', 'ny'],
#  ['mc', 'lean', 'va'],
#  ['san', 'francisco', 'ca'],
#  ['greater', 'boston', 'area'],
#  ['seattle'],
#  ['chicago', 'il', 'us'],
#  ['mountain', 'view'],
#  ['redmond', 'wa', 'us'],
#  ['menlo', 'park', '', 'california', '', 'us'],
#  ['national'],
#  ['chicago', 'illinois'],
#  ['sunnyvale', 'ca'],
#  ['us', '', 'california', '', 'palo', 'alto'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['alpharetta', 'ga', 'us'],
#  ['cleveland', 'oh'],
#  ['redmond', 'wa', 'us'],
#  ['st', 'louis', 'missouri'],
#  ['chicago', '', 'illinois', '', 'us'],
#  ['multiple', 'locations'],
#  ['us', 'morrisville', 'nc', '27560'],
#  ['us', 'morrisville', 'nc', '27560'],
#  ['us', 'morrisville', 'nc', '27560'],
#  ['us', 'austin', 'tx', '78759'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'francisco', 'ca'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['manhattan'],
#  ['denver', 'co'],
#  ['new', 'york', 'ny'],
#  ['san', 'jose', 'ca', 'us'],
#  ['cleveland',
#   'boston',
#   'nashville',
#   'atlanta',
#   'tampa',
#   'midwest',
#   '/',
#   'east',
#   'location'],
#  ['herndon', 'va', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['omaha', 'ne'],
#  ['boston'],
#  ['annapolis', 'md', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['annapolis', 'md', 'us'],
#  ['saint', 'paul', 'mn', 'us'],
#  ['austin', 'tx', 'us'],
#  ['columbus', 'oh', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['mahwah', 'nj', 'us'],
#  ['plano', 'tx', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['carlsbad', 'ca', 'us'],
#  ['carlsbad', 'ca', 'us'],
#  ['houston', 'tx', 'us'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['mahwah', 'nj', 'us'],
#  ['jacksonville', 'fl', 'us'],
#  ['mclean', 'va', 'us'],
#  ['mahwah', 'nj', 'us'],
#  ['usa', 'alpharetta', 'ga'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['mountain', 'view', 'ca', 'us'],
#  ['south', 'jordan', 'ut', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['mountain', 'view', 'ca', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['mahwah', 'nj', 'us'],
#  ['mahwah', 'nj', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['irvine', 'ca', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['seattle', 'wa', 'us'],
#  ['islandia', 'ny', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['st', 'louis', 'mo', 'us'],
#  ['lafayette', 'la', 'us'],
#  ['islandia', 'ny', 'us'],
#  ['mahwah', 'nj', 'us'],
#  ['sunnyvale', 'ca', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['denver', 'co', 'us'],
#  ['mahwah', 'nj', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['us', 'ca', 'san', 'diego'],
#  ['broomfield', 'co', 'us'],
#  ['pleasanton', 'ca', 'us'],
#  ['santa', 'monica', 'ca', 'us'],
#  ['raleigh', 'nc', 'us'],
#  ['mahwah', 'nj', 'us'],
#  ['plano', 'tx', 'us'],
#  ['los', 'angeles', 'ca', 'us'],
#  ['boston', 'ma', 'us'],
#  ['miami', 'fl', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['gaithersburg', 'md', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['palo', 'alto', 'ca', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['kansas', 'city', 'mo', 'us'],
#  ['kansas', 'city', 'mo', 'us'],
#  ['sunnyvale', 'ca', 'us'],
#  ['palo', 'alto', 'ca', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['sunnyvale', 'ca'],
#  ['new', 'york', 'ny'],
#  ['nyc'],
#  ['charlotte', 'nc', 'us'],
#  ['boca', 'raton', 'fl', 'us'],
#  ['washington', 'd', 'c', '', 'dc', 'us'],
#  ['santa', 'clara', 'santa', 'clara', 'california', 'united', 'states'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['seattle', 'wa', 'us'],
#  ['township', 'of', 'hazlet', 'nj', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['raleigh', 'nc', 'us'],
#  ['blue', 'bell', 'pa', 'us'],
#  ['englewood', 'co', 'us'],
#  ['long', 'island', 'ny', 'us'],
#  ['philadelphia', 'pa', 'us'],
#  ['seattle', 'wa', 'us'],
#  ['nashville', 'tn', 'us'],
#  ['redwood', 'city', 'ca', 'us'],
#  ['redwood', 'city', 'ca', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['broomfield', 'co', 'us'],
#  ['cambridge', 'ma', 'us'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['austin', 'tx', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['redwood', 'city', 'ca', 'us'],
#  ['seattle', 'wa', 'us'],
#  ['fairfax', 'va', 'us'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['saint', 'petersburg', 'fl', 'us'],
#  ['san', 'mateo', 'ca', 'us'],
#  ['palo', 'alto', 'ca', 'us'],
#  ['austin', 'tx', 'us'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['san', 'diego', 'ca', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['san', 'diego', 'county', 'ca', 'us'],
#  ['santa', 'clara', 'ca', 'us'],
#  ['north', 'america', 'us', 'il', 'schaumburg'],
#  ['buffalo'],
#  ['buffalo'],
#  ['dallas/fort', 'worth', 'area'],
#  ['san', 'francisco', 'california', 'usa'],
#  ['mountain', 'view', 'ca', 'usa'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['maryland', '', 'annapolis'],
#  ['pennsylvania', 'usa'],
#  ['san', 'francisco', 'ca', 'us'],
#  ['alexandria', 'va'],
#  ['austin', 'tx', 'us'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['cleveland'],
#  ['palo', 'alto', 'ca'],
#  ['san', 'francisco', '', 'ca'],
#  ['austin'],
#  ['san', 'carlos'],
#  ['cleveland'],
#  ['mountain', 'view', 'ca'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['san', 'francisco', 'ca'],
#  ['bethesda', 'md', 'us'],
#  ['palo', 'alto', 'ca', 'us'],
#  ['malvern', 'pa'],
#  ['bellevue', 'wa'],
#  ['stamford', 'ct'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['greater', 'new', 'york', 'city', 'area'],
#  ['los', 'altos', 'ca'],
#  ['boston', 'ma'],
#  ['reston', 'va'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['multiple', 'locations'],
#  ['plano', '', 'texas'],
#  ['plano', '', 'texas'],
#  ['san', 'francisco'],
#  ['san', 'francisco'],
#  ['irvine', 'ca'],
#  ['crystal', 'city', 'va', ''],
#  ['los', 'angeles', 'county', 'ca', 'us'],
#  ['reston', 'va'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['north', 'sc', 'us'],
#  ['atlanta', 'ga', 'us'],
#  ['linthicum', 'heights', 'md'],
#  ['boston', 'ma'],
#  ['charlotte', 'north', 'carolina', 'area'],
#  ['san', 'francisco', 'bay', 'area'],
#  ['deerfield', 'il'],
#  ['nyc'],
#  ['seattle', 'wa'],
#  ['san', 'francisco', 'ca'],
#  ['boston', 'ma'],
#  ['menlo', 'park', '', 'california', '', 'us'],
#  ['santa', 'monica', 'ca'],
#  ['new', 'york', '', 'ny', '', 'us'],
#  ['dallas', 'tx', 'us'],
#  ['boca', 'raton', 'fl', 'us'],
#  ['plano', '', 'texas'],
#  ['san', 'jose', 'ca', '95131', '(', '408', ')'],
#  ['boston', 'ma', 'us'],
#  ['mountain', 'view'],
#  ['menlo', 'park', 'ca'],
#  ['los', 'gatos', 'california'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ['us', 'ny', 'rensselaer'],
#  ['los', 'gatos', 'california'],
#  ['us', 'wa', 'bothell'],
#  ['palo', 'alto', '', 'california'],
#  ['st', 'louis', 'missouri'],
#  ['us', 'ca', 'sunnyvale'],
#  ['mountain', 'view', 'ca'],
#  ['greater', 'boston', 'area'],
#  ['nashville', 'tn'],
#  ['somerville', 'ma'],
#  ['new', 'york', 'city', 'ny', 'us'],
#  ...]

# %%
df
# Out:
#       Unnamed: 0                                       company  \
# 0              0                         Data Talent Australia
# 1              1                         Data Talent Australia
# 2              2                             Curtin University
# 3              3                                        Oracle
# 4              4                    Opus Recruitment Solutions
# 5              5                                      ansarada
# 6              6                                        Oracle
# 7              7                                        Oracle
# 8              8                                Freelancer.com
# 9              9                                        Aconex
# 10            10                                        KIXEYE
# 11            11                             Commonwealth Bank
# 12            12                                       Telstra
# 13            13                               carsales.com.au
# 14            14                                           IBM
# 15            15                                      Teradata
# 16            16                                Freelancer.com
# 17            17                               Talent Insights
# 18            18                                Recruit Direct
# 19            19                                           SAS
# 20            20                                           SAS
# 21            21                                       Experis
# 22            22                                           IBM
# 23            23                                      Rome2rio
# 24            24                          Paxus IT Recruitment
# 25            25                              SMG Technologies
# 26            26                                     Redbubble
# 27            27                                 Suncorp Group
# 28            28                                       Telstra
# 29            29                                       Telstra
# ...          ...                                           ...
# 1927        1927                             Havas Media Group
# 1928        1928                                    Findasense
# 1929        1929                                    Intelletec
# 1930        1930                                      Teradata
# 1931        1931                                        Amazon
# 1932        1932                                    Findasense
# 1933        1933                          Talent Search People
# 1934        1934                                    Findasense
# 1935        1935                                    Findasense
# 1936        1936                                         Cisco
# 1937        1937                                    Findasense
# 1938        1938                                           EMC
# 1939        1939                                 Expedia, Inc.
# 1940        1940                                         Nestl
# 1941        1941                       Open Search Network Ltd
# 1942        1942                                    Axpo Group
# 1943        1943                                     Cognizant
# 1944        1944                                    ETH Zurich
# 1945        1945  EPFL (cole polytechnique fdrale de Lausanne)
# 1946        1946                                 Credit Suisse
# 1947        1947                                           IHS
# 1948        1948  EPFL (cole polytechnique fdrale de Lausanne)
# 1949        1949                                    ETH Zurich
# 1950        1950                          Electronic Arts (EA)
# 1951        1951                                        LBi US
# 1952        1952                                         Cisco
# 1953        1953                                         Cisco
# 1954        1954                          World Economic Forum
# 1955        1955                                    DigitasLBi
# 1956        1956                                    DigitasLBi
#
#                                            company_link country  \
# 0     https://www.linkedin.com/company/data-talent-a...      au
# 1     https://www.linkedin.com/company/data-talent-a...      au
# 2     https://www.linkedin.com/company/curtinunivers...      au
# 3     https://www.linkedin.com/company/oracle/career...      au
# 4     https://www.linkedin.com/company/opus-recruitm...      au
# 5     https://www.linkedin.com/company/ansarada?trk=...      au
# 6     https://www.linkedin.com/company/oracle/career...      au
# 7     https://www.linkedin.com/company/oracle/career...      au
# 8     https://www.linkedin.com/company/freelancer-co...      au
# 9     https://www.linkedin.com/company/aconex/career...      au
# 10    https://www.linkedin.com/company/kixeye/career...      au
# 11    https://www.linkedin.com/company/commonwealthb...      au
# 12    https://www.linkedin.com/company/telstra/caree...      au
# 13    https://www.linkedin.com/company/carsales.com....      au
# 14    https://www.linkedin.com/company/ibm/careers?t...      au
# 15    https://www.linkedin.com/company/teradata/care...      au
# 16    https://www.linkedin.com/company/freelancer-co...      au
# 17    https://www.linkedin.com/company/talent-insigh...      au
# 18    https://www.linkedin.com/company/recruit-direc...      au
# 19    https://www.linkedin.com/company/sas/careers?t...      au
# 20    https://www.linkedin.com/company/sas/careers?t...      au
# 21    https://www.linkedin.com/company/experis?trk=j...      au
# 22    https://www.linkedin.com/company/ibm/careers?t...      au
# 23    https://www.linkedin.com/company/rome2rio-pty-...      au
# 24    https://www.linkedin.com/company/paxus?trk=job...      au
# 25    https://www.linkedin.com/company/smg-technolog...      au
# 26    https://www.linkedin.com/company/redbubble/car...      au
# 27    https://www.linkedin.com/company/suncorp/caree...      au
# 28    https://www.linkedin.com/company/telstra/caree...      au
# 29    https://www.linkedin.com/company/telstra/caree...      au
# ...                                                 ...     ...
# 1927  https://www.linkedin.com/company/havas-media/c...      es
# 1928  https://www.linkedin.com/company/findasense?tr...      es
# 1929  https://www.linkedin.com/company/intelletec-lt...      es
# 1930  https://www.linkedin.com/company/teradata/care...      es
# 1931  https://www.linkedin.com/company/amazon/career...      es
# 1932  https://www.linkedin.com/company/findasense?tr...      es
# 1933  https://www.linkedin.com/company/talent-search...      es
# 1934  https://www.linkedin.com/company/findasense?tr...      es
# 1935  https://www.linkedin.com/company/findasense?tr...      es
# 1936  https://www.linkedin.com/company/cisco/careers...      es
# 1937  https://www.linkedin.com/company/findasense?tr...      es
# 1938  https://www.linkedin.com/company/emc/careers?t...      es
# 1939  https://www.linkedin.com/company/expedia/caree...      ch
# 1940  https://www.linkedin.com/company/nestle-s-a-/c...      ch
# 1941  https://www.linkedin.com/company/open-search-n...      ch
# 1942  https://www.linkedin.com/company/axpo-group/ca...      ch
# 1943  https://www.linkedin.com/company/cognizant/car...      ch
# 1944  https://www.linkedin.com/company/eth-zurich_49...      ch
# 1945  https://www.linkedin.com/company/epfl?trk=job_...      ch
# 1946  https://www.linkedin.com/company/credit-suisse...      ch
# 1947  https://www.linkedin.com/company/ihs/careers?t...      ch
# 1948  https://www.linkedin.com/company/epfl?trk=job_...      ch
# 1949  https://www.linkedin.com/company/eth-zurich_49...      ch
# 1950  https://www.linkedin.com/company/electronic-ar...      ch
# 1951  https://www.linkedin.com/company/lbi-us?trk=jo...      ch
# 1952  https://www.linkedin.com/company/cisco/careers...      ch
# 1953  https://www.linkedin.com/company/cisco/careers...      ch
# 1954  https://www.linkedin.com/company/world-economi...      ch
# 1955  https://www.linkedin.com/company/lbi/careers?t...      ch
# 1956  https://www.linkedin.com/company/lbi/careers?t...      ch
#
#                                         job_description  \
# 0     Identifies unique opportunities to collect new...
# 1     Identifies unique opportunities to collect new...
# 2     Data Scientist   Curtin Teaching and Learning ...
# 3     Prefer candidates with at least 5 years workin...
# 4     Perform and interpret data studies across mult...
# 5     Data Scientist Data & Analytics - Sydney, New ...
# 6     Prefer candidates with at least 5 years workin...
# 7     Prefer candidates with at least 5 years workin...
# 8     Equip the team with a strong platform to condu...
# 9     Data Assembly & Analysis of large data sets to...
# 10    Data Scientist Brisbane Do you like big data? ...
# 11    You build and evaluate a variety of machinelea...
# 12    You will be working in an Agile methodology en...
# 13    Immediate start for thr new year! Ensuring our...
# 14    The Predictive Analytics Data Scientist provid...
# 15    Appliances and Platform Family Integrated Data...
# 16    Equip the team with a strong platform to condu...
# 17    3-5 years experience developing analytical mod...
# 18    Understand the business issues and provide rec...
# 19    Possess 5 years of  data science  and  analyti...
# 20    Possess 5 years of  data science  and  analyti...
# 21    They provide high quality, cost-effective stra...
# 22    Listing Info Job Description The Predictive An...
# 23    Optimize the accuracy and speed of our multi-m...
# 24    10+ experience in advanced analytics with stro...
# 25    Develop applicationsand predictive analytic to...
# 26    Developing a strategy and flexible plan, from ...
# 27    Design and provide guidance to the data infras...
# 28    You will be working in an Agile methodology en...
# 29    You will be working in an Agile methodology en...
# ...                                                 ...
# 1927  BS or MS in Computer Science or equivalent (IT...
# 1928  We are Alternative Consulting People. Born dig...
# 1929  Apply for Lead JavaScript Developer  Up to 75,...
# 1930  The Teradata Unified Data Architecture (UDA) p...
# 1931  Translate complex data and information into ea...
# 1932  We are  Alternative Consulting People . Digita...
# 1933  Descripcin de la oferta   Duracin de la oferta...
# 1934  1. We are Alternative Consulting People. Born ...
# 1935  Somos  Alternative Consulting People . Nativos...
# 1936  Our employees' revolutionary ideas impact ever...
# 1937  We are Alternative Consulting People. Born dig...
# 1938  At Pivotal, our mission is to enable customers...
# 1939                                                NaN
# 1940  Leads data management roadmap, database and re...
# 1941  Role: Permanent Location: Zurich/Switzerland T...
# 1942  Leading the desk analysis team of Continental ...
# 1943  The first 18 months you have the opportunity f...
# 1944
# 1945  We are seeking candidates for tenure-track  as...
# 1946  Possibility helping to identify strategic and ...
# 1947  Independently interacts with clients on increa...
# 1948  Research in close collaboration with other tea...
# 1949
# 1950  Work with marketing analytics teams to develop...
# 1951  Einen sehr verlsslichen, sympathischen und lan...
# 1952  Our employees' revolutionary ideas impact ever...
# 1953  Listing Info Additional Location(s) or Informa...
# 1954  Listing Info   PROJECT LEAD, KNOWLEDGE NETWORK...
# 1955  Einen sehr verlsslichen, sympathischen und lan...
# 1956  Einen sehr verlsslichen, sympathischen und lan...
#
#                                                job_link  \
# 0     https://www.linkedin.com/jobs2/view/95509188?t...
# 1     https://www.linkedin.com/jobs2/view/95507522?t...
# 2     https://www.linkedin.com/jobs2/view/107456900?...
# 3     https://www.linkedin.com/jobs2/view/91741653?t...
# 4     https://www.linkedin.com/jobs2/view/62371715?t...
# 5     https://www.linkedin.com/jobs2/view/107848773?...
# 6     https://www.linkedin.com/jobs2/view/100540024?...
# 7     https://www.linkedin.com/jobs2/view/100254015?...
# 8     https://www.linkedin.com/jobs2/view/97868007?t...
# 9     https://www.linkedin.com/jobs2/view/92556195?t...
# 10    https://www.linkedin.com/jobs2/view/107849398?...
# 11    https://www.linkedin.com/jobs2/view/109337294?...
# 12    https://www.linkedin.com/jobs2/view/97639361?t...
# 13    https://www.linkedin.com/jobs2/view/107847222?...
# 14    https://www.linkedin.com/jobs2/view/96503747?t...
# 15    https://www.linkedin.com/jobs2/view/40896526?t...
# 16    https://www.linkedin.com/jobs2/view/92586662?t...
# 17    https://www.linkedin.com/jobs2/view/89035154?t...
# 18    https://www.linkedin.com/jobs2/view/96555316?t...
# 19    https://www.linkedin.com/jobs2/view/95562091?t...
# 20    https://www.linkedin.com/jobs2/view/95561148?t...
# 21    https://www.linkedin.com/jobs2/view/105495226?...
# 22    https://www.linkedin.com/jobs2/view/102965444?...
# 23    https://www.linkedin.com/jobs2/view/109608136?...
# 24    https://www.linkedin.com/jobs2/view/104481943?...
# 25    https://www.linkedin.com/jobs2/view/96548694?t...
# 26    https://www.linkedin.com/jobs2/view/91745173?t...
# 27    https://www.linkedin.com/jobs2/view/93854918?t...
# 28    https://www.linkedin.com/jobs2/view/97638477?t...
# 29    https://www.linkedin.com/jobs2/view/97636940?t...
# ...                                                 ...
# 1927  https://www.linkedin.com/jobs2/view/93820306?t...
# 1928  https://www.linkedin.com/jobs2/view/109606182?...
# 1929  https://www.linkedin.com/jobs2/view/109405757?...
# 1930  https://www.linkedin.com/jobs2/view/104760800?...
# 1931  https://www.linkedin.com/jobs2/view/104282397?...
# 1932  https://www.linkedin.com/jobs2/view/103340738?...
# 1933  https://www.linkedin.com/jobs2/view/103743090?...
# 1934  https://www.linkedin.com/jobs2/view/101989613?...
# 1935  https://www.linkedin.com/jobs2/view/101782752?...
# 1936  https://www.linkedin.com/jobs2/view/98476446?t...
# 1937  https://www.linkedin.com/jobs2/view/96892107?t...
# 1938  https://www.linkedin.com/jobs2/view/86525832?t...
# 1939  https://www.linkedin.com/jobs2/view/94838259?t...
# 1940  https://www.linkedin.com/jobs2/view/96532386?t...
# 1941  https://www.linkedin.com/jobs2/view/96543392?t...
# 1942  https://www.linkedin.com/jobs2/view/97623794?t...
# 1943  https://www.linkedin.com/jobs2/view/62376581?t...
# 1944  https://www.linkedin.com/jobs2/view/108805736?...
# 1945  https://www.linkedin.com/jobs2/view/95351727?t...
# 1946  https://www.linkedin.com/jobs2/view/97052587?t...
# 1947  https://www.linkedin.com/jobs2/view/93843116?t...
# 1948  https://www.linkedin.com/jobs2/view/109384237?...
# 1949  https://www.linkedin.com/jobs2/view/106980312?...
# 1950  https://www.linkedin.com/jobs2/view/105909328?...
# 1951  https://www.linkedin.com/jobs2/view/105373671?...
# 1952  https://www.linkedin.com/jobs2/view/95194728?t...
# 1953  https://www.linkedin.com/jobs2/view/95195550?t...
# 1954  https://www.linkedin.com/jobs2/view/92443287?t...
# 1955  https://www.linkedin.com/jobs2/view/98332970?t...
# 1956                                                NaN
#
#                                               job_title  \
# 0                                        Data Scientist
# 1                                        Data Scientist
# 2                                        Data Scientist
# 3                                        Data Scientist
# 4                                        Data Scientist
# 5                                        Data Scientist
# 6                                        Data Scientist
# 7                                        Data Scientist
# 8                                        Data Scientist
# 9                                        Data Scientist
# 10                                       Data Scientist
# 11                                       Data Scientist
# 12                                         Data Analyst
# 13                                         Data Analyst
# 14                  Predictive Analytics Data Scientist
# 15               Data Scientist Consultant (NSW or VIC)
# 16                          Data Scientist, Growth Team
# 17                               Senior Data Scientist
# 18                   Head of Analytics / Data Scientist
# 19                      Risk Data Scientist / Pre Sales
# 20    Fraud and Financial Crimes Data Scientist / Pr...
# 21                      Data Scientist  Hadoop, Bigdata
# 22                  Predictive Analytics Data Scientist
# 23    Data Scientist Software Engineer @ Exciting Tr...
# 24                                  Lead Data Scientist
# 25                                     Python Developer
# 26                               Senior Product Manager
# 27                            Pricing Analytics Advisor
# 28                                         Data Analyst
# 29                                         Data Analyst
# ...                                                 ...
# 1927                                   Programador Java
# 1928                   Digital Graphic Designer - Spain
# 1929            Lead JavaScript Developer  Up to 75,000
# 1930                                  Hadoop Consultant
# 1931                Sr. Retail Business Analyst - Spain
# 1932                         Social Media Agent - Spain
# 1933                 Senior Software Engineer - Backend
# 1934             Digital Senior Account Manager - Spain
# 1935                       Digital Intelligence Analyst
# 1936            Technical Sales Engineer Intern (Spain)
# 1937   Corporate Communications Account Manager - Spain
# 1938                            Field Engineer, Pivotal
# 1939  Internship: Data Science, Competitive Intellig...
# 1940                            PCE Senior Data Manager
# 1941  Front End and Data Visualization Software Engi...
# 1942                          Head Fundamental Analysis
# 1943  Graduate Analyst in Quality Engineering & Assu...
# 1944  Postdoctoral Position for Citizen Design Scien...
# 1945  Faculty Positions in Data Science and Machine ...
# 1946                                  IT Data Scientist
# 1947                           Director, Trade Analysis
# 1948                           PhD Position at CDM IIPP
# 1949  Highly Motivated PhD Student to work on the Pl...
# 1950                         Marketing Analytics Intern
# 1951             Director Consulting / Account Director
# 1952      Technical Sales Engineer Intern - Switzerland
# 1953        Field Sales Specialist Intern - Switzerland
# 1954      Project Lead, Knowledge Networks and Analysis
# 1955             Director Consulting / Account Director
# 1956             Director Consulting / Account Director
#
#                                       location  \
# 0                         Melbourne, Australia
# 1                                       Sydney
# 2                             Perth, Australia
# 3                Sydney, Melbourne or Canberra
# 4     Sydney and Melbourne Positions Available
# 5                                   Sydney, AU
# 6                               North Ryde, AU
# 7                               North Ryde, AU
# 8                                   Sydney, AU
# 9                                    Melbourne
# 10                                Brisbane, AU
# 11                                  Sydney, AU
# 12                             NSW: Sydney CBD
# 13                               Melbourne, AU
# 14                                       PERTH
# 15      Australia-New South Wales-North Sydney
# 16                                      Sydney
# 17                      Sydney Area, Australia
# 18                           Sydney, Australia
# 19                                   Melbourne
# 20                        Melbourne, Australia
# 21                                   Perth, AU
# 22                                   Perth, AU
# 23                        Melbourne, Australia
# 24                                   Perth, AU
# 25                         Brisbane, Australia
# 26                        Melbourne, Australia
# 27       Various, Sydney - Inner Suburbs & CBD
# 28                        VIC: Melbourne - CBD
# 29                           QLD: Brisbane CBD
# ...                                        ...
# 1927                        Madrid Area, Spain
# 1928                                Madrid, ES
# 1929                              Marbella, ES
# 1930                                Madrid, ES
# 1931                     Pozuelo de Alarcn, ES
# 1932                                Madrid, ES
# 1933                             Barcelona, ES
# 1934                                Madrid, ES
# 1935                                Madrid, ES
# 1936                                Madrid, ES
# 1937                                Madrid, ES
# 1938                                Madrid, ES
# 1939                     Geneva  - Switzerland
# 1940                                      Vevy
# 1941                                    Zurich
# 1942               Zrich und Umgebung, Schweiz
# 1943                 Switzerland-Zurich-Zurich
# 1944                                 Zrich, CH
# 1945                              Lausanne, CH
# 1946                                 Zrich, CH
# 1947            CH,,Geneva,24 Chemin de la Mai
# 1948                                 Genve, CH
# 1949                                 Zrich, CH
# 1950                                 Genve, CH
# 1951                                 Zrich, CH
# 1952                           Wallisellen, CH
# 1953                           Wallisellen, CH
# 1954                                 Genve, CH
# 1955                                 Zrich, CH
# 1956                                 Zrich, CH
#
#                                                    logo
# 0     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 2     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 3     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 4     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 5     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 6     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 7     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 8     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 9     https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 10    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 11    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 12    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 13    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 14    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 15    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 16    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 17    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 18    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 19    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 20    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 21    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 22    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 23    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 24    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 25    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 26    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 27    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 28    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 29    https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# ...                                                 ...
# 1927  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1928  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1929  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1930  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1931  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1932  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1933  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1934  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1935  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1936  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1937  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1938  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1939  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1940  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1941  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1942  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1943  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1944  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1945  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1946  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1947  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1948  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1949  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1950  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1951  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1952  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1953  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1954  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1955  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
# 1956  https://media.licdn.com/mpr/mpr/shrinknp_200_2...
#
# [1957 rows x 9 columns]

# %%
def describe_results(v_job_desc, nmf_weights, nmf_features, words = 100):
    
    for job_desc_type, skill in enumerate(nmf_features):
        print("\nTopic number:%d" % job_desc_type) 
        print(" ".join([feature_words[i] for i in skill.argsort()[:-words - 1:-1]]))
    return

# %%
vectorizer = TfidfVectorizer(stop_words='english')
vectorizer = vectorizer.fit(df['job_description'])
v_job_desc = vectorizer.transform(df['job_description']).todense()

feature_words = vectorizer.get_feature_names()

nmf = NMF(n_components=5)
nmf_weights = nmf.fit_transform(v_job_desc)
nmf_features = nmf.components_

# %%
describe_results(v_job_desc, nmf_weights, nmf_features)
# Out:
# Topic number:0
# business data management work team ability skills product client experience technical analytics solutions teams customer marketing development clients strong project projects technology analytical new analysis support develop manage drive communication ensure knowledge sales design able identify including working requirements environment strategy understanding high lead deliver provide internal level digital delivery opportunities excellent insights media tools services solution key degree customers industry understand written quality issues processes best strategic problem leadership use help years performance build relationships science results end stakeholders implementation market global people multiple company products consulting needs complex self information process senior partners create problems reporting external driven
#
# Topic number:1
# role category area functional specialization doctorate intelligence analytics software business required graduation ecommerce application pg programming datawarehousing post ug dba postgraduate tion computers education analyst details modelling internet maintenance good job advanced looking ph 00 scientist industry end bi description regressive exposure graduate involves sas designing engineer responsibility responsibilities refer conducting worked senior structured concepts great risk artificial 10 dependant analytic build algebra opportunity candidate testable location years communicating statistics building tier essential solid hands person typical able colleges tech kind lead key statistical association additionally linear f500 smart deriving individuals consume retail decision sc immediate designed deals znajomo cluster
#
# Topic number:2
# data experience learning machine science python big statistical mining algorithms hadoop programming analysis statistics computer large knowledge analytics years sql java modeling techniques language software working models strong systems tools skills research processing engineering spark plus predictive using technologies mathematics like phd design related hive methods scientist degree scale advanced field distributed development sas building work databases languages matlab problems modelling complex nosql develop understanding sets quantitative pig scala structured team regression good unstructured solutions applied visualization real new scripting ability familiarity hands analytical relational masters time proficiency datasets advantage expertise background model computing code optimization platform open business deep
#
# Topic number:3
# und von der mit sie oder im die fr zu sowie den kenntnisse eine zur auf das wie ihre aus entwicklung bereich statistik ein gute data sind erfahrung sehr informatik kunden erfahrungen wir mathematik einer auch lsungen ber dem bei einem umfeld anwendung analytische haben als des methoden zum projekte physik technologien bis studium unserer analyse bereichen big mining datenmengen uns durch wirtschafts beratung abgeschlossenes analytics sich unter aufgaben fragestellungen untersttzen eines arbeiten umgang deutsch daten englischkenntnisse entwickeln ist projekten umsetzung modellierung modelle datenanalyse fhigkeit verfahren ihr durchfhrung neue optimierung online reisebereitschaft spss otto algorithmen untersttzung datenbanken unsere erste bi
#
# Topic number:4
# en van een je met het ervaring et des op te la hebt kennis voor om bij als aan les bent jaar le opleiding wo hbo werken goed goede vous data afgeronde minimaal die zoals nieuwe onze gebied richting ou salaris java veel binnen du sur jij werkervaring technieken informatica pour naar omgeving donnes functie zeer voorkeur werk pre dans analyse tot au klanten technische vakantiedagen zijn deze dveloppement avec kunnen afhankelijk une big wiskunde ontwikkelen werkweek urige maken programmeren intelligence aantoonbare eigen communicatief relevante creatief sterk zowel ruimte uit informatie dit kunt flexibele ook denkniveau jouw pensioenregeling technologien datawarehouse

# %%
def tokenizer(description):
    '''
    Purpose: Tokenize, stem  and remove stopwords from job_descriptions
    Input: string
    Output: List of string of words
    '''
    description = re.findall(r'\w+', description.lower())

    stop = stopwords.words('english')
    stop.extend(stopwords.words('german'))
    stop.extend(stopwords.words('french'))
    stop.extend(stopwords.words('spanish'))
    
    desc_stop = [word for word in description if word not in stop]

    #snowball = SnowballStemmer('english')
    #clean_description = " ".join([str(snowball.stem(word)) for word in desc_stop])
    clean_description = " ".join(desc_stop)
    return clean_description

# %%
description = [tokenizer(str(desc))for desc in df.job_description]

# %%
cnt = Counter()

# %%
for desc in description:
    for word in desc.split(' '):
        cnt[str(word)] += 1

# %%
for i in df.location.unique():
    print re.findall(r"[\w']+", i.lower())
# Out:
# ['melbourne', 'australia']
# ['sydney']
# ['perth', 'australia']
# ['sydney', 'melbourne', 'or', 'canberra']
# ['sydney', 'and', 'melbourne', 'positions', 'available']
# ['sydney', 'au']
# ['north', 'ryde', 'au']
# ['melbourne']
# ['brisbane', 'au']
# ['nsw', 'sydney', 'cbd']
# ['melbourne', 'au']
# ['perth']
# ['australia', 'new', 'south', 'wales', 'north', 'sydney']
# ['sydney', 'area', 'australia']
# ['sydney', 'australia']
# ['perth', 'au']
# ['brisbane', 'australia']
# ['various', 'sydney', 'inner', 'suburbs', 'cbd']
# ['vic', 'melbourne', 'cbd']
# ['qld', 'brisbane', 'cbd']
# ['middle', 'creek', 'au']
# ['vienna', 'at']
# ['wattens', 'at']
# ['brussels', 'area', 'belgium']
# ['antwerp', 'area', 'belgium']
# ['europe']
# ['antwerpen', 'be']
# ['gent', 'be']
# ['brussels', 'be']
# ['bruxelles']
# ['diegem', 'be']
# ['diegem']
# ['hasselt', 'be']
# ['brazil', 'brazil', 'jaguariuna']
# ['so', 'paulo', 'br']
# ['braslia', 'br']
# ['bulgaria', 'area']
# ['toronto', 'on']
# ['toronto', 'on', 'ca']
# ['toronto', 'canada', 'area']
# ['vancouver', 'bc', 'canada']
# ['calgary', 'ca']
# ['montral', 'ca']
# ['mississauga', 'ca']
# ['toronto', 'ca']
# ['liberty', 'village']
# ['downtown', 'toronto']
# ['vancouver', 'ca']
# ['ottawa']
# ['waterloo']
# ['california', 'ca']
# ['edmonton', 'ca']
# ['richmond', 'ca']
# ['shanghai']
# ['shenzhen', 'guangdong', 'china']
# ['beijing', 'beijing', 'china']
# ['shanghai', 'shanghai', 'cn']
# ['beijing', 'cn']
# ['shanghai', 'cn']
# ['dalian', 'cn']
# ['chongqing', 'cn']
# ['shanghai']
# ['prague', 'hradec', 'kralove', 'or', 'ostrava', 'czech', 'republic']
# ['prague', 'cz']
# ['denmark', 'bjerringbro']
# ['denmark', 'billund']
# ['copenhagen', 'area', 'capital', 'region', 'denmark']
# ['helsinki', 'area', 'finland']
# ['helsinki', 'fi']
# ['finland']
# ['france', 'france', 'massy']
# ['rgion', 'de', 'paris', 'france']
# ['paris', 'area', 'france']
# ['paris']
# ['massy', 'fr']
# ['chtillon']
# ['nanterre']
# ['levallois', 'perret']
# ['villejuif']
# ['france', 'vlizy', 'villacoublay', 'cedex']
# ['rgion', 'de', 'lyon', 'france']
# ['paris', 'france']
# ['paris', 'fr']
# ['montrouge', 'fr']
# ['villejuif', 'fr']
# ['suresnes', 'france']
# ['france']
# ['toulouse', 'le', 'chteau', 'fr']
# ['la', 'madeleine', 'fr']
# ['lyon', 'fr']
# ['nantes']
# ['lille', 'fr']
# ['gennevilliers']
# ['rgion', 'de', 'poitiers', 'france']
# ['paris', 'france']
# ['cergy', 'fr']
# ['berlin', 'area', 'germany']
# ['cologne', 'area', 'germany']
# ['frankfurt']
# ['munich']
# ['hamburg']
# ['berlin', 'de']
# ['berlin', 'berlin']
# ['berlin', 'berlin', 'germany']
# ['essen']
# ['berlin']
# ['mlheim', 'ruhr', 'de']
# ['stuttgart', 'de']
# ['hamburg', 'de']
# ['kln', 'und', 'umgebung', 'deutschland']
# ['frankfurt', 'am', 'main', 'area', 'germany']
# ['dsseldorf', 'de']
# ['ger', 'dusseldorf']
# ['munich', 'de']
# ['germany', 'mlheim', 'an', 'der', 'ruhr']
# ['karlsruhe', 'de']
# ['gppingen', 'de']
# ['wolfsburg', 'de']
# ['nrnberg', 'de']
# ['coburg', 'de']
# ['kln', 'de']
# ['tettnang', 'de']
# ['freising', 'de']
# ['frankfurt', 'am', 'main', 'de']
# ['sulzbach', 'rosenberg', 'de']
# ['aachen', 'de']
# ['hannover', 'de']
# ['essen', 'de']
# ['bonn', 'de']
# ['neudorf', 'de']
# ['mnchen', 'und', 'umgebung', 'deutschland']
# ['halle', 'saale']
# ['heidelberg', 'de']
# ['rostock', 'de']
# ['erlangen', 'de']
# ['hong', 'kong', 'hk']
# ['hu', 'bu', 'budapest', 'budapest']
# ['budapest', 'hu']
# ['mumbai', 'area', 'india']
# ['bangalore', 'india']
# ['bengaluru', 'area', 'india']
# ['hyderabad', 'india']
# ['bangalore', 'in']
# ['gurgaon', 'india']
# ['ahmedabad', 'in']
# ['chennai', 'in']
# ['pune', 'in']
# ['bangalore', 'karnataka', 'india']
# ['bangalore']
# ['bangalore', 'mumbai']
# ['pune']
# ['elphinstone', 'road']
# ['mumbai']
# ['hyderabad', 'in']
# ['navi', 'mumbai', 'in']
# ['jaipur', 'in']
# ['gurgaon', 'in']
# ['kolkata', 'in']
# ['mumbai', 'in']
# ['secunderabad', 'in']
# ['noida', 'in']
# ['noida', 'indore', 'india']
# ['chennai', 'in']
# ['delhi', 'in']
# ['dohad', 'in']
# ['cochin', 'in']
# ['gurgaon']
# ['hyderabad', 'area', 'india']
# ['gurgaon', 'haryana', 'in']
# ['bangalore', 'pune', 'hyderabad', 'chennai']
# ['uttarkashi', 'in']
# ['greater', 'jakarta', 'area', 'indonesia']
# ['kerinci']
# ['dublin', 'ireland']
# ['dublin', 'ie']
# ['cork', 'ie']
# ['ramat', 'gan']
# ['israel']
# ['netanya']
# ['ramat', 'gan']
# ['tel', 'aviv']
# ['ramat', 'gan', 'il']
# ['tel', 'aviv', 'il']
# ['jerusalem', 'il']
# ['herzelia', 'israel']
# ['jerusalem', 'yerushalayim', 'israel']
# ['tel', 'aviv', 'israel']
# ['milan']
# ['italy', 'sesto', 'fiorentino']
# ['milan', 'area', 'italy']
# ['roma']
# ['milano', 'it']
# ['rome', 'it']
# ['italy', 'lazio', 'rome']
# ['italy', 'lombardy', 'milan']
# ['jp', 'capital', 'area', 'tokyo']
# ['tokyo', 'japan']
# ['within', '23', 'wards', 'tokyo', 'japan']
# ['tokyo', 'jp']
# ['nairobi', 'ke']
# ['songpa', 'gu', 'seoul']
# ['seoul', 'kr']
# ['bertrange']
# ['luxembourg']
# ['luxembourg', 'lu']
# ['malta']
# ['mexico', 'city', 'mx']
# ['oslo', 'no']
# ['bonifacio', 'global', 'city', 'taguig']
# ['philippines']
# ['ncr']
# ['mandaluyong', 'metro', 'manila', 'national', 'capital', 'philippines']
# ['davao', 'ph']
# ['philippines', 'ph']
# ['krakow']
# ['poland', 'warsaw']
# ['warsaw', 'masovian', 'voivodeship', 'poland']
# ['warsaw', 'pl']
# ['krakw', 'pl']
# ['bydgoszcz', 'pl']
# ['coimbra', 'area', 'portugal']
# ['lisboa', 'e', 'regio', 'portugal']
# ['portugal', 'pt']
# ['lisbon', 'pt']
# ['guarda', 'pt']
# ['porto', 'pt']
# ['santarm', 'pt']
# ['cluj', 'napoca']
# ['cluj', 'napoca', 'the', 'office', 'building']
# ['bucharest', 'ro']
# ['bucuresti', 'ro']
# ['moscow']
# []
# ['novosibirsk', 'ru']
# ['moscow', 'ru']
# ['kaliningrad', 'ru']
# ['kazan', 'ru']
# ['barnaul', 'ru']
# ['izhevsk', 'ru']
# ['omsk', 'ru']
# ['yekaterinburg', 'ru']
# ['samara', 'ru']
# ['nizhniy', 'novgorod', 'ru']
# ['petropavlovsk', 'kamchatsky', 'ru']
# ['saint', 'petersburg', 'ru']
# ['vladivostok', 'ru']
# ['vologda', 'ru']
# ['petrozavodsk', 'ru']
# ['rostov', 'na', 'donu', 'ru']
# ['barcelona', 'area', 'spain']
# ['madrid', 'spain']
# ['spain', 'madrid']
# ['barcelona', 'es']
# ['barcelona', 'y', 'alrededores', 'espaa']
# ['madrid', 'y', 'alrededores', 'espaa']
# ['madrid', 'es']
# ['barcelona', 'spain']
# ['barcelona']
# ['zrich', 'und', 'umgebung', 'schweiz']
# ['switzerland', 'zrich', 'zrich']
# ['geneva', 'geneva', 'switzerland']
# ['zrich', 'ch']
# ['wallisellen', 'ch']
# ['washington', 'd', 'c', 'metro', 'area']
# ['san', 'francisco', 'california', 'us']
# ['palo', 'alto', 'ca', 'us']
# ['herndon', 'va']
# ['us', 'oregon', 'hillsboro']
# ['greater', 'philadelphia', 'area']
# ['irvine', 'california']
# ['l5', 'chicago', 'il', 'cnvr', '60606']
# ['chicago', 'il', 'us']
# ['mountain', 'view', 'ca']
# ['redmond', 'wa', 'us']
# ['greater', 'new', 'york', 'city', 'area']
# ['new', 'york', 'ny']
# ['santa', 'clara', 'ca', 'us']
# ['nj', 'all']
# ['columbia', 'md']
# ['san', 'francisco', 'bay', 'area']
# ['santa', 'monica', 'ca', 'us']
# ['philadelphia', 'pa']
# ['irvine', 'ca']
# ['augusta', 'ga']
# ['denver', 'co']
# ['dallas', 'tx']
# ['greater', 'boston', 'area']
# ['cambridge', 'ma', 'us']
# ['lake', 'forest', 'or', 'rosemont', 'il', 'or', 'fond', 'du', 'lac', 'wi']
# ['new', 'york', 'ny', 'usa']
# ['san', 'francisco', 'ca', 'us']
# ['austin', 'tx', 'us']
# ['boston', 'massachusetts']
# ['greater', 'chicago', 'area']
# ['us', 'wa', 'bellevue']
# ['mayfield', 'village', 'oh']
# ['bellevue', 'wa', 'us']
# ['usa', 'texas', 'dallas', 'metroplex']
# ['charlotte', 'north', 'carolina', 'area']
# ['palo', 'alto', 'ca']
# ['rtp', 'nc']
# ['el', 'segundo', 'california', 'us']
# ['chicago', 'il']
# ['new', 'york', 'city', 'ny', 'us']
# ['hershey', 'pa', 'us']
# ['west', 'des', 'moines', 'ia', 'us']
# ['seattle', 'wa', 'us']
# ['charlottesville', 'va', 'us']
# ['philadelphia', 'pa', 'area']
# ['boston']
# ['boston', 'ma']
# ['plano', 'tx']
# ['san', 'francisco', 'ca']
# ['downtown', 'manhattan']
# ['downtown', 'seattle']
# ['lincoln', 'ne']
# ['na', 'usa', 'iowa', 'johnston']
# ['bellevue', 'wa', 'us']
# ['mountain', 'view', 'ca']
# ['greater', 'los', 'angeles', 'area']
# ['redwood', 'city', 'ca']
# ['dallas', 'tx']
# ['us', 'wa', 'seattle']
# ['boise', 'id', 'us']
# ['miami', 'fort', 'lauderdale', 'area']
# ['englewood', 'co']
# ['new', 'york', 'ny']
# ['annapolis', 'junction', 'maryland']
# ['seattle', 'wa']
# ['boston', 'ma', 'or', 'los', 'angeles', 'ca']
# ['andover', 'ma']
# ['greater', 'new', 'york', 'area']
# ['greater', 'atlanta', 'area']
# ['san', 'jose', 'ca']
# ['homewood']
# ['culver', 'city', 'ca']
# ['greater', 'denver', 'area']
# ['phoenix', 'arizona', 'area']
# ['mclean', 'va', 'us']
# ['san', 'diego', 'ca', 'us']
# ['washington', 'd', 'c', 'dc', 'us']
# ['san', 'jose', 'ca', 'us']
# ['arlington', 'va', 'us']
# ['san', 'mateo', 'ca', 'us']
# ['birmingham', 'al', 'us']
# ['boston', 'ma', 'us']
# ['carlsbad', 'ca', 'us']
# ['ann', 'arbor', 'mi', 'us']
# ['bristol', 'ct', 'us']
# ['calabasas', 'ca', 'us']
# ['columbia', 'md', 'us']
# ['menlo', 'park', 'ca', 'us']
# ['atlanta', 'ga', 'us']
# ['los', 'angeles', 'ca', 'us']
# ['beverly', 'hills', 'ca', 'us']
# ['louisville', 'ky', 'us']
# ['folsom', 'ca', 'us']
# ['medford', 'ma', 'us']
# ['chicago', 'il', 'area']
# ['chicago']
# ['san', 'francisco']
# ['vinings', 'ga', 'us']
# ['annapolis', 'md', 'us']
# ['santa', 'barbara', 'california', 'area']
# ['chicago', 'illinois']
# ['golden', 'valley', 'mn', 'us']
# ['san', 'bruno', 'ca']
# ['framingham']
# ['usa', 'alpharetta', 'ga']
# ['chicago', 'illinois']
# ['mclean', 'virginia']
# ['wilmington', 'de']
# ['san', 'francisco', 'california']
# ['seattle', 'wa']
# ['portland', 'or']
# ['sunnyvale', 'ca']
# ['woodlands', 'texas']
# ['san', 'francisco', 'ca']
# ['draper', 'ut']
# ['venice', 'ca']
# ['chantilly', 'va', 'us']
# ['grand', 'rapids']
# ['springfield', 'va', 'us']
# ['us', 'dc', 'washington', 'd', 'c', '1300', 'con']
# ['wayne', 'pa', 'us']
# ['san', 'ramon', 'ca']
# ['gaithersburg', 'md']
# ['greenville', 'sc', 'us']
# ['st', 'louis', 'mo', 'us']
# ['fairfield', 'ca', 'us']
# ['herndon', 'va', 'us']
# ['america', 'il', 'us']
# ['honolulu', 'hi', 'us']
# ['alexandria', 'va', 'us']
# ['dallas', 'tx', 'us']
# ['bentonville', 'ar', 'us']
# ['tampa', 'fl', 'us']
# ['pittsburgh', 'pa', 'us']
# ['mountain', 'view', 'ca', 'us']
# ['denver', 'co', 'us']
# ['columbus', 'in', 'us']
# ['philadelphia', 'pa', 'us']
# ['windsor', 'ct', 'us']
# ['woburn', 'ma', 'us']
# ['ridge', 'ny', 'us']
# ['redwood', 'city', 'ca', 'us']
# ['eagan', 'mn', 'us']
# ['scotts', 'valley', 'ca', 'us']
# ['baltimore', 'md', 'us']
# ['framingham', 'ma', 'us']
# ['silver', 'spring', 'md', 'us']
# ['norwalk', 'ct', 'us']
# ['hoffman', 'estates', 'il', 'us']
# ['windsor', 'locks', 'ct', 'us']
# ['washington', 'ma', 'us']
# ['san', 'antonio', 'tx', 'us']
# ['reston', 'va', 'us']
# ['sunnyvale', 'sunnyvale', 'california', 'united', 'states']
# ['natick', 'ma', 'us']
# ['san', 'francisco', 'ca', 'united', 'states']
# ['plano', 'tx', 'us']
# ['salt', 'lake', 'city', 'ut', 'us']
# ['irving', 'tx', 'us']
# ['costa', 'mesa', 'ca', 'us']
# ['boulder', 'co', 'us']
# ['homewood', 'il', 'us']
# ['brooklyn', 'ny', 'us']
# ['worcester', 'ma', 'us']
# ['kent', 'wa', 'us']
# ['rochester', 'mn', 'us']
# ['nashville', 'tn', 'us']
# ['raleigh', 'nc', 'us']
# ['provo', 'ut', 'us']
# ['fort', 'collins', 'co', 'us']
# ['ridgecrest', 'ca', 'us']
# ['oldsmar', 'fl', 'us']
# ['indianapolis', 'in', 'us']
# ['hartford', 'ct', 'us']
# ['detroit', 'mi', 'us']
# ['miami', 'fl', 'us']
# ['berkeley', 'heights', 'nj', 'us']
# ['princeton', 'nj', 'us']
# ['southfield', 'mi', 'us']
# ['dearborn', 'mi', 'us']
# ['morrisville', 'nc', 'us']
# ['mesa', 'az', 'us']
# ['jacksonville', 'fl', 'us']
# ['west', 'jordan', 'ut', 'us']
# ['crystal', 'spring', 'va', 'us']
# ['hopewell', 'va', 'us']
# ['bethesda', 'md', 'us']
# ['wilmington', 'de', 'us']
# ['fort', 'washington', 'pa', 'us']
# ['somerville', 'ma', 'us']
# ['camden', 'nj', 'us']
# ['charlotte', 'nc', 'us']
# ['alpharetta', 'ga', 'us']
# ['draper', 'ut', 'us']
# ['white', 'plains', 'ny', 'us']
# ['emeryville', 'ca', 'us']
# ['green', 'bay', 'wi', 'us']
# ['port', 'washington', 'ny', 'us']
# ['jenkintown', 'pa', 'us']
# ['kansas', 'city', 'mo', 'us']
# ['south', 'san', 'francisco', 'ca', 'us']
# ['downstown', 'nj', 'us']
# ['irvine', 'ca', 'us']
# ['portland', 'or', 'us']
# ['san', 'carlos', 'ca', 'us']
# ['waltham', 'ma', 'us']
# ['greensboro', 'nc', 'us']
# ['troy', 'mi', 'us']
# ['auburn', 'hills', 'mi', 'us']
# ['burlingame', 'ca', 'us']
# ['greater', 'seattle', 'area']
# ['hanover', 'md', 'us']
# ['santa', 'clara', 'valley', 'california', 'us']
# ['cincinnati', 'ohio', 'us']
# ['emeryville', 'ca']
# ['san', 'francisco', 'ca']
# ['dallas', 'or', 'houston', 'tx']
# ['south', 'norwalk', 'ct']
# ['provo', 'ut']
# ['houston', 'us']
# ['us', 'mn', 'golden', 'valley']
# ['grapevine', 'us', 'tx']
# ['philadelphia', 'pa']
# ['washington', 'd', 'c']
# ['santa', 'clara', 'california']
# ['us', 'maryland', 'chevy', 'chase']
# ['los', 'gatos', 'california']
# ['us', 'virginia', 'arlington']
# ['santa', 'monica', 'ca']
# ['southlake', 'us', 'tx']
# ['palo', 'alto']
# ['austin']
# ['campbell', 'ca']
# ['beverly', 'hills', 'california']
# ['usa', 'california', 'santa', 'clara']
# ['san', 'francisco', 'california', 'us']
# ['north', 'america', 'us', 'ca', 'san', 'francisco']
# ['shelton', 'ct']
# ['los', 'angeles', 'ca']
# ['oakland', 'ca']
# ['new', 'york']
# ['san', 'francisco']
# ['home', 'based', 'ideally', 'us', 'west', 'coast', 'or', 'mountain', 'region']
# ['san', 'francisco', 'financial', 'district']
# ['pleasanton', 'ca', 'usa']
# ['usa', 'sunnyvale', 'ca']
# ['mahwah', 'nj', 'us']
# ['menlo', 'park', 'ca']
# ['dallas', 'tx', 'us']
# ['new', 'york', 'city', 'ny']
# ['rockville', 'md']
# ['us', 'ca', 'mountain', 'view']
# ['chicago', 'illinois', 'us']
# ['us', 'co', 'longmont', 'colorado']
# ['los', 'altos', 'california']
# ['alpharetta']
# ['us', 'california', 'westlake', 'village']
# ['san', 'jose', 'ca']
# ['san', 'francisco', 'ca', 'us']
# ['san', 'francisco', 'ca', 'downtown']
# ['london']
# ['national']
# ['irvine', 'usa', 'ca']
# ['ca', 'san', 'mateo']
# ['new', 'york', 'us', 'ny']
# ['us', 'ny', 'new', 'york']
# ['san', 'ramon', 'ca']
# ['san', 'jose', 'or', 'san', 'francisco']
# ['houston', 'tx', 'us']
# ['eden', 'prairie', 'mn', 'us']
# ['westminster', 'co', 'us']
# ['fayetteville', 'nc', 'us']
# ['fairfax', 'va', 'us']
# ['phoenix', 'az', 'us']
# ['sunnyvale', 'ca', 'us']
# ['houston', 'texas']
# ['santa', 'monica']
# ['austin', 'texas', 'area']
# ['lafayette', 'la', 'us']
# ['lehi', 'ut', 'us']
# ['new', 'york', 'metro']
# ['san', 'francisco', 'california', 'us']
# ['redwood', 'city', 'california', 'us']
# ['new', 'york', 'city']
# ['san', 'francisco', 'california', 'usa']
# ['north', 'america', 'us', 'md', 'columbia_md']
# ['new', 'york', 'ny', 'us']
# ['washington']
# ['austin', 'tx', 'us']
# ['greater', 'baltimore', 'area']
# ['mountain', 'view']
# ['hanover', 'ma']
# ['cambridge', 'ma']
# ['campbell', 'ca', 'us']
# ['menlo', 'park', 'california', 'us']
# ['redwood', 'city', 'ca']
# ['somers']
# ['orlando', 'florida', 'area']
# ['round', 'rock', 'tx']
# ['us']
# ['phoenix', 'az', 'will', 'relocate', 'you', 'from', 'any', 'us', 'state', 'ny', 'ma', 'etc']
# ['atlanta', 'ga']
# ['san', 'mateo', 'ca']
# ['armonk', 'ny']
# ['baltimore', 'maryland', 'area']
# ['scotts', 'valley', 'ca']
# ['us', 'tx', 'dallas', 'ft', 'worth', 'southlake']
# ['cincinnati', 'area']
# ['boston', 'ma', 'or', 'los', 'angeles', 'ca']
# ['nyc']
# ['us', 'ca', 'sunnyvale']
# ['sunnyvale']
# ['us', 'tx', 'houston', 'corp']
# ['dearborn', 'michigan']
# ['mountain', 'view', 'castro', 'station']
# ['seattle']
# ['northbrook', 'il']
# ['mc', 'lean', 'va']
# ['sunnyvale', 'ca']
# ['us', 'california', 'palo', 'alto']
# ['cleveland', 'oh']
# ['st', 'louis', 'missouri']
# ['chicago', 'illinois', 'us']
# ['multiple', 'locations']
# ['us', 'morrisville', 'nc', '27560']
# ['us', 'austin', 'tx', '78759']
# ['manhattan']
# ['omaha', 'ne']
# ['saint', 'paul', 'mn', 'us']
# ['columbus', 'oh', 'us']
# ['mahwah', 'nj', 'us']
# ['south', 'jordan', 'ut', 'us']
# ['islandia', 'ny', 'us']
# ['us', 'ca', 'san', 'diego']
# ['broomfield', 'co', 'us']
# ['pleasanton', 'ca', 'us']
# ['gaithersburg', 'md', 'us']
# ['santa', 'clara', 'santa', 'clara', 'california', 'united', 'states']
# ['township', 'of', 'hazlet', 'nj', 'us']
# ['blue', 'bell', 'pa', 'us']
# ['englewood', 'co', 'us']
# ['long', 'island', 'ny', 'us']
# ['saint', 'petersburg', 'fl', 'us']
# ['san', 'diego', 'county', 'ca', 'us']
# ['north', 'america', 'us', 'il', 'schaumburg']
# ['buffalo']
# ['dallas', 'fort', 'worth', 'area']
# ['mountain', 'view', 'ca', 'usa']
# ['maryland', 'annapolis']
# ['pennsylvania', 'usa']
# ['alexandria', 'va']
# ['cleveland']
# ['san', 'francisco', 'ca']
# ['san', 'carlos']
# ['malvern', 'pa']
# ['bellevue', 'wa']
# ['stamford', 'ct']
# ['los', 'altos', 'ca']
# ['reston', 'va']
# ['plano', 'texas']
# ['crystal', 'city', 'va']
# ['los', 'angeles', 'county', 'ca', 'us']
# ['north', 'sc', 'us']
# ['linthicum', 'heights', 'md']
# ['deerfield', 'il']
# ['new', 'york', 'ny', 'us']
# ['boca', 'raton', 'fl', 'us']
# ['san', 'jose', 'ca', '95131', '408']
# ['us', 'ny', 'rensselaer']
# ['us', 'wa', 'bothell']
# ['palo', 'alto', 'california']
# ['us', 'ca', 'sunnyvale']
# ['nashville', 'tn']
# ['somerville', 'ma']
# ['austin', 'tx']
# ['kansas', 'city', 'mo']
# ['san', 'bruno', 'ca', 'us']
# ['syracuse', 'ny', 'us']
# ['new', 'york', 'ny', 'us']
# ['pasadena', 'ca']
# ['addison', 'tx', 'us']
# ['boston']
# ['berkeley', 'ca', 'us']
# ['jersey', 'city', 'nj', 'us']
# ['monterey', 'ca', 'us']
# ['duluth', 'ga', 'us']
# ['midtown', 'manhattan']
# ['simsbury', 'ct', 'us']
# ['temple', 'terrace', 'fl', 'us']
# ['kirkland', 'wa', 'us']
# ['bohemia', 'ny', 'us']
# ['colorado', 'springs', 'co', 'us']
# ['meade', 'ks', 'us']
# ['fishers', 'in', 'us']
# ['corona', 'ca', 'us']
# ['scottsdale', 'az', 'us']
# ['fort', 'meade', 'md', 'us']
# ['rockville', 'md', 'us']
# ['oakland', 'ca', 'right', 'off', '19th', 'street', 'bart', 'station']
# ['us', 'ny', 'new', 'york', 'city', 'ny', 'usa', 'clt']
# ['washington', 'court', 'house', 'oh', 'us']
# ['redwood', 'shores', 'ca', 'us']
# ['newark', 'de', 'us']
# ['remote', 'lake', 'mn', 'us']
# ['falls', 'church', 'va', 'us']
# ['northbrook', 'il', 'us']
# ['urban', 'pa', 'us']
# ['clarksburg', 'wv', 'us']
# ['woodland', 'hills', 'ca', 'us']
# ['minneapolis', 'mn', 'us']
# ['wellesley', 'ma', 'us']
# ['livonia', 'mi', 'us']
# ['little', 'rock', 'ar', 'us']
# ['creve', 'coeur', 'mo', 'us']
# ['naperville', 'il', 'us']
# ['overland', 'park', 'ks', 'us']
# ['mountain', 'view', 'ca', 'or', 'san', 'francisco', 'ca']
# ['valencia', 'ca', 'us']
# ['minnetonka', 'mn', 'us']
# ['hillsboro', 'or', 'us']
# ['madrid']
# ['spain']
# ['madrid', 'area', 'spain']
# ['marbella', 'es']
# ['pozuelo', 'de', 'alarcn', 'es']
# ['vevy']
# ['zurich']
# ['switzerland', 'zurich', 'zurich']
# ['lausanne', 'ch']
# ['ch', 'geneva', '24', 'chemin', 'de', 'la', 'mai']
# ['genve', 'ch']

# %%
cnt.most_common()
# Out:
# [('data', 8613),
#  ('experience', 4950),
#  ('business', 2213),
#  ('analysis', 1959),
#  ('work', 1892),
#  ('learning', 1756),
#  ('skills', 1681),
#  ('analytics', 1643),
#  ('machine', 1552),
#  ('science', 1531),
#  ('ability', 1456),
#  ('statistical', 1410),
#  ('years', 1316),
#  ('team', 1287),
#  ('strong', 1250),
#  ('knowledge', 1230),
#  ('statistics', 1187),
#  ('r', 1180),
#  ('models', 1088),
#  ('python', 1081),
#  ('modeling', 1037),
#  ('working', 1029),
#  ('new', 1006),
#  ('tools', 974),
#  ('mining', 963),
#  ('development', 947),
#  ('big', 935),
#  ('large', 896),
#  ('sql', 884),
#  ('degree', 882),
#  ('develop', 871),
#  ('solutions', 871),
#  ('algorithms', 863),
#  ('technical', 830),
#  ('design', 821),
#  ('analytical', 814),
#  ('computer', 814),
#  ('using', 813),
#  ('techniques', 812),
#  ('predictive', 759),
#  ('etc', 756),
#  ('research', 755),
#  ('hadoop', 753),
#  ('product', 725),
#  ('advanced', 705),
#  ('related', 702),
#  ('programming', 697),
#  ('engineering', 691),
#  ('management', 675),
#  ('software', 673),
#  ('complex', 669),
#  ('plus', 658),
#  ('including', 655),
#  ('environment', 645),
#  ('quantitative', 620),
#  ('insights', 617),
#  ('problems', 614),
#  ('systems', 587),
#  ('sas', 586),
#  ('field', 581),
#  ('teams', 578),
#  ('one', 564),
#  ('java', 562),
#  ('communication', 557),
#  ('understanding', 554),
#  ('mathematics', 547),
#  ('customer', 531),
#  ('must', 529),
#  ('preferred', 512),
#  ('projects', 507),
#  ('high', 507),
#  ('support', 498),
#  ('time', 493),
#  ('methods', 491),
#  ('marketing', 483),
#  ('build', 478),
#  ('scientist', 465),
#  ('language', 465),
#  ('company', 462),
#  ('technologies', 459),
#  ('use', 459),
#  ('results', 458),
#  ('excellent', 457),
#  ('required', 455),
#  ('3', 443),
#  ('technology', 439),
#  ('sets', 438),
#  ('sources', 431),
#  ('least', 429),
#  ('information', 422),
#  ('industry', 418),
#  ('problem', 418),
#  ('identify', 418),
#  ('based', 416),
#  ('phd', 404),
#  ('5', 404),
#  ('languages', 404),
#  ('drive', 402),
#  ('processing', 402),
#  ('level', 401),
#  ('performance', 398),
#  ('g', 392),
#  ('communicate', 388),
#  ('well', 384),
#  ('provide', 380),
#  ('visualization', 377),
#  ('model', 377),
#  ('across', 371),
#  ('able', 367),
#  ('solving', 364),
#  ('hive', 363),
#  ('databases', 362),
#  ('spark', 360),
#  ('building', 359),
#  ('applied', 358),
#  ('relevant', 358),
#  ('understand', 352),
#  ('help', 351),
#  ('driven', 351),
#  ('2', 348),
#  ('products', 348),
#  ('matlab', 347),
#  ('scale', 347),
#  ('create', 346),
#  ('background', 344),
#  ('requirements', 344),
#  ('multiple', 342),
#  ('expertise', 341),
#  ('analyze', 338),
#  ('like', 336),
#  ('written', 328),
#  ('analytic', 327),
#  ('real', 326),
#  ('developing', 321),
#  ('operations', 321),
#  ('optimization', 319),
#  ('improve', 319),
#  ('proficiency', 311),
#  ('customers', 311),
#  ('key', 309),
#  ('client', 307),
#  ('implement', 307),
#  ('within', 301),
#  ('world', 294),
#  ('services', 288),
#  ('best', 287),
#  ('apply', 287),
#  ('internal', 284),
#  ('project', 283),
#  ('clients', 283),
#  ('regression', 279),
#  ('ms', 278),
#  ('masters', 277),
#  ('decision', 276),
#  ('expert', 275),
#  ('lead', 275),
#  ('processes', 270),
#  ('approaches', 266),
#  ('non', 262),
#  ('user', 262),
#  ('hands', 259),
#  ('position', 259),
#  ('demonstrated', 257),
#  ('deep', 257),
#  ('proven', 252),
#  ('analyses', 252),
#  ('reporting', 250),
#  ('intelligence', 250),
#  ('quality', 249),
#  ('datasets', 249),
#  ('actionable', 248),
#  ('perform', 248),
#  ('highly', 246),
#  ('impact', 242),
#  ('database', 240),
#  ('following', 239),
#  ('process', 239),
#  ('fast', 238),
#  ('role', 236),
#  ('metrics', 234),
#  ('professional', 234),
#  ('application', 234),
#  ('good', 233),
#  ('opportunities', 232),
#  ('various', 230),
#  ('concepts', 229),
#  ('learn', 229),
#  ('testing', 229),
#  ('self', 227),
#  ('physics', 227),
#  ('web', 226),
#  ('relational', 226),
#  ('scripting', 224),
#  ('excel', 224),
#  ('1', 224),
#  ('solve', 223),
#  ('reports', 222),
#  ('math', 222),
#  ('distributed', 222),
#  ('spss', 222),
#  ('equivalent', 221),
#  ('economics', 220),
#  ('senior', 220),
#  ('passion', 219),
#  ('practices', 219),
#  ('innovative', 218),
#  ('familiarity', 218),
#  ('job', 218),
#  ('needs', 217),
#  ('production', 214),
#  ('effectively', 214),
#  ('cross', 214),
#  ('structured', 211),
#  ('test', 211),
#  ('make', 209),
#  ('value', 209),
#  ('applications', 208),
#  ('pig', 208),
#  ('sales', 207),
#  ('similar', 207),
#  ('organization', 206),
#  ('trends', 206),
#  ('minimum', 204),
#  ('leadership', 203),
#  ('deliver', 202),
#  ('findings', 200),
#  ('implementation', 198),
#  ('platform', 196),
#  ('clustering', 195),
#  ('mathematical', 195),
#  ('end', 195),
#  ('oriented', 195),
#  ('closely', 193),
#  ('tableau', 193),
#  ('need', 193),
#  ('collaborate', 192),
#  ('functional', 192),
#  ('computing', 190),
#  ('benefits', 189),
#  ('recommendations', 187),
#  ('digital', 187),
#  ('mapreduce', 186),
#  ('areas', 186),
#  ('decisions', 186),
#  ('competitive', 186),
#  ('code', 185),
#  ('external', 185),
#  ('opportunity', 184),
#  ('social', 183),
#  ('unstructured', 182),
#  ('variety', 181),
#  ('solid', 181),
#  ('open', 180),
#  ('scientists', 180),
#  ('questions', 180),
#  ('strategic', 179),
#  ('ideas', 178),
#  ('people', 177),
#  ('natural', 177),
#  ('solution', 177),
#  ('leading', 177),
#  ('online', 176),
#  ('discipline', 176),
#  ('verbal', 174),
#  ('nosql', 173),
#  ('analyzing', 173),
#  ('maintain', 171),
#  ('platforms', 171),
#  ('classification', 170),
#  ('stakeholders', 169),
#  ('series', 167),
#  ('us', 167),
#  ('financial', 165),
#  ('looking', 164),
#  ('modelling', 164),
#  ('track', 164),
#  ('system', 163),
#  ('packages', 162),
#  ('strategy', 162),
#  ('creative', 161),
#  ('bs', 161),
#  ('existing', 160),
#  ('methodologies', 159),
#  ('cloud', 159),
#  ('ensure', 159),
#  ('record', 159),
#  ('b', 158),
#  ('presentation', 158),
#  ('members', 157),
#  ('manage', 156),
#  ('ad', 155),
#  ('paced', 155),
#  ('making', 154),
#  ('4', 154),
#  ('extensive', 153),
#  ('vision', 152),
#  ('global', 152),
#  ('issues', 152),
#  ('preferably', 151),
#  ('experiments', 151),
#  ('great', 150),
#  ('multi', 150),
#  ('english', 149),
#  ('insurance', 148),
#  ('security', 147),
#  ('independently', 147),
#  ('health', 147),
#  ('growth', 147),
#  ('text', 146),
#  ('master', 145),
#  ('salary', 145),
#  ('forecasting', 145),
#  ('engineers', 145),
#  ('service', 144),
#  ('market', 144),
#  ('scala', 143),
#  ('clear', 143),
#  ('source', 143),
#  ('designing', 142),
#  ('appropriate', 142),
#  ('candidate', 142),
#  ('risk', 142),
#  ('enterprise', 142),
#  ('perl', 141),
#  ('consulting', 140),
#  ('others', 140),
#  ('travel', 138),
#  ('office', 138),
#  ('features', 137),
#  ('microsoft', 136),
#  ('responsibilities', 136),
#  ('qualifications', 135),
#  ('define', 135),
#  ('medical', 134),
#  ('delivery', 133),
#  ('teradata', 132),
#  ('line', 132),
#  ('bi', 132),
#  ('fields', 132),
#  ('search', 132),
#  ('managers', 131),
#  ('part', 131),
#  ('applying', 131),
#  ('linear', 130),
#  ('manner', 130),
#  ('top', 130),
#  ('present', 130),
#  ('capabilities', 130),
#  ('linux', 129),
#  ('effective', 128),
#  ('current', 128),
#  ('full', 128),
#  ('partners', 128),
#  ('different', 128),
#  ('writing', 128),
#  ('creating', 128),
#  ('10', 126),
#  ('please', 126),
#  ('bachelors', 126),
#  ('include', 126),
#  ('implementing', 125),
#  ('diverse', 123),
#  ('flexible', 123),
#  ('year', 123),
#  ('practical', 123),
#  ('detail', 123),
#  ('demonstrate', 123),
#  ('patterns', 122),
#  ('consumer', 122),
#  ('day', 122),
#  ('candidates', 121),
#  ('network', 120),
#  ('integration', 120),
#  ('behavior', 120),
#  ('training', 119),
#  ('delivering', 119),
#  ('ph', 119),
#  ('take', 118),
#  ('around', 118),
#  ('challenges', 118),
#  ('u', 118),
#  ('subject', 117),
#  ('map', 117),
#  ('proficient', 117),
#  ('collaborative', 117),
#  ('program', 117),
#  ('attention', 117),
#  ('scientific', 116),
#  ('media', 116),
#  ('architecture', 116),
#  ('coding', 116),
#  ('reduce', 115),
#  ('relationships', 115),
#  ('translate', 115),
#  ('dynamic', 114),
#  ('life', 113),
#  ('motivated', 113),
#  ('evaluate', 113),
#  ('successful', 112),
#  ('education', 112),
#  ('group', 112),
#  ('critical', 112),
#  ('culture', 111),
#  ('would', 111),
#  ('audiences', 111),
#  ('levels', 110),
#  ('segmentation', 110),
#  ('interpersonal', 110),
#  ('networks', 110),
#  ('area', 109),
#  ('strategies', 109),
#  ('applicants', 109),
#  ('specific', 109),
#  ('edge', 109),
#  ('future', 108),
#  ('core', 108),
#  ('scalable', 107),
#  ('better', 107),
#  ('assist', 107),
#  ('focus', 107),
#  ('advertising', 106),
#  ('thinking', 106),
#  ('start', 106),
#  ('fr', 106),
#  ('infrastructure', 106),
#  ('cases', 106),
#  ('environments', 106),
#  ('frameworks', 105),
#  ('tool', 105),
#  ('considered', 105),
#  ('users', 105),
#  ('ruby', 104),
#  ('state', 104),
#  ('agile', 104),
#  ('paid', 104),
#  ('change', 103),
#  ('player', 102),
#  ('success', 102),
#  ('detection', 102),
#  ('managing', 101),
#  ('package', 101),
#  ('extract', 101),
#  ('international', 101),
#  ('fun', 101),
#  ('quickly', 101),
#  ('needed', 100),
#  ('meet', 100),
#  ('bayesian', 100),
#  ('partner', 100),
#  ('responsible', 99),
#  ('location', 99),
#  ('academic', 99),
#  ('mysql', 99),
#  ('computational', 99),
#  ('trees', 99),
#  ('oral', 99),
#  ('comfortable', 99),
#  ('approach', 99),
#  ('sciences', 98),
#  ('activities', 98),
#  ('dental', 97),
#  ('plan', 97),
#  ('domain', 97),
#  ('audience', 97),
#  ('conduct', 97),
#  ('providing', 96),
#  ('goals', 96),
#  ('passionate', 96),
#  ('set', 95),
#  ('javascript', 95),
#  ('ba', 95),
#  ('fraud', 95),
#  ('used', 95),
#  ('class', 95),
#  ('methodology', 94),
#  ('algorithm', 94),
#  ('write', 94),
#  ('base', 94),
#  ('basic', 94),
#  ('bachelor', 94),
#  ('recommendation', 94),
#  ('hoc', 93),
#  ('extraction', 93),
#  ('may', 93),
#  ('neural', 93),
#  ('initiatives', 92),
#  ('hbase', 92),
#  ('enable', 91),
#  ('executive', 91),
#  ('wide', 91),
#  ('framework', 91),
#  ('econometrics', 91),
#  ('tasks', 90),
#  ('order', 90),
#  ('generate', 90),
#  ('operational', 90),
#  ('want', 89),
#  ('contribute', 89),
#  ('documentation', 89),
#  ('focused', 89),
#  ('presentations', 89),
#  ('programs', 89),
#  ('find', 89),
#  ('cutting', 89),
#  ('efforts', 89),
#  ('multivariate', 89),
#  ('execute', 89),
#  ('objectives', 88),
#  ('apache', 88),
#  ('query', 88),
#  ('mahout', 88),
#  ('engagement', 87),
#  ('way', 87),
#  ('healthcare', 87),
#  ('random', 87),
#  ('plans', 87),
#  ('innovation', 87),
#  ('oracle', 86),
#  ('content', 86),
#  ('interest', 86),
#  ('think', 86),
#  ('significant', 86),
#  ('leverage', 85),
#  ('finance', 85),
#  ('dashboards', 84),
#  ('insight', 84),
#  ('experimental', 84),
#  ('share', 84),
#  ('organizational', 84),
#  ('access', 84),
#  ('collaboration', 84),
#  ('7', 83),
#  ('deploy', 83),
#  ('interpret', 83),
#  ('analyse', 83),
#  ('efficient', 83),
#  ('retrieval', 83),
#  ('nlp', 83),
#  ('changing', 83),
#  ('graph', 82),
#  ('improvement', 82),
#  ('analysts', 82),
#  ('get', 82),
#  ('unix', 81),
#  ('direction', 81),
#  ('outcomes', 81),
#  ('employees', 81),
#  ('functions', 81),
#  ('small', 81),
#  ('range', 81),
#  ('desire', 80),
#  ('structures', 80),
#  ('familiar', 80),
#  ('amounts', 80),
#  ('optimize', 80),
#  ('object', 79),
#  ('exposure', 79),
#  ('scikit', 79),
#  ('sowie', 79),
#  ('action', 78),
#  ('6', 78),
#  ('email', 78),
#  ('validation', 78),
#  ('visualizations', 78),
#  ('fluency', 78),
#  ('hypothesis', 78),
#  ('graduate', 77),
#  ('mobile', 77),
#  ('basis', 77),
#  ('identifying', 77),
#  ('evaluation', 77),
#  ('leveraging', 77),
#  ('accuracy', 76),
#  ('etl', 76),
#  ('guidance', 76),
#  ('principles', 76),
#  ('growing', 76),
#  ('logistic', 76),
#  ('desired', 76),
#  ('today', 76),
#  ('supply', 76),
#  ('feature', 75),
#  ('influence', 75),
#  ('keep', 75),
#  ('analyst', 75),
#  ('warehouse', 75),
#  ('exceptional', 75),
#  ('term', 75),
#  ('explore', 75),
#  ('prior', 74),
#  ('validate', 74),
#  ('experienced', 74),
#  ('simulation', 74),
#  ('pandas', 74),
#  ('manipulation', 74),
#  ('hard', 74),
#  ('collection', 74),
#  ('join', 74),
#  ('status', 74),
#  ('participate', 73),
#  ('monitoring', 73),
#  ('cluster', 73),
#  ('8', 73),
#  ('every', 73),
#  ('manipulating', 73),
#  ('know', 73),
#  ('address', 72),
#  ('improvements', 72),
#  ('power', 71),
#  ('desirable', 71),
#  ('prepare', 71),
#  ('communicating', 71),
#  ('bonus', 71),
#  ('enhance', 71),
#  ('industrial', 71),
#  ('forward', 71),
#  ('achieve', 71),
#  ('provides', 71),
#  ('available', 71),
#  ('authorized', 70),
#  ('startup', 70),
#  ('supporting', 70),
#  ('care', 70),
#  ('linkedin', 70),
#  ('companies', 70),
#  ('fluent', 70),
#  ('potential', 70),
#  ('server', 70),
#  ('general', 70),
#  ('individual', 70),
#  ('ml', 70),
#  ('report', 70),
#  ('career', 70),
#  ('unique', 69),
#  ('internet', 69),
#  ('domains', 69),
#  ('recognition', 69),
#  ('explain', 69),
#  ('establish', 69),
#  ('clearly', 68),
#  ('utilizing', 68),
#  ('mongodb', 68),
#  ('commercial', 68),
#  ('two', 68),
#  ('energy', 68),
#  ('retail', 68),
#  ('staff', 68),
#  ('leaders', 68),
#  ('free', 68),
#  ('storm', 68),
#  ('art', 68),
#  ('offer', 67),
#  ('prediction', 67),
#  ('d3', 67),
#  ('document', 67),
#  ('long', 67),
#  ('driving', 67),
#  ('community', 66),
#  ('com', 66),
#  ('game', 66),
#  ('procedures', 66),
#  ('novel', 66),
#  ('facing', 66),
#  ('advantage', 66),
#  ('details', 65),
#  ('especially', 65),
#  ('google', 65),
#  ('planning', 65),
#  ('k', 64),
#  ('measure', 64),
#  ('numpy', 64),
#  ('performing', 64),
#  ('setting', 64),
#  ('groups', 64),
#  ('generation', 64),
#  ('right', 63),
#  ('probability', 63),
#  ('cybercoders', 63),
#  ('pattern', 63),
#  ('disciplines', 63),
#  ('direct', 63),
#  ('priorities', 63),
#  ('standards', 63),
#  ('challenging', 63),
#  ('employment', 63),
#  ('resources', 62),
#  ('designs', 62),
#  ('experimentation', 62),
#  ('post', 62),
#  ('supervised', 62),
#  ('capability', 62),
#  ('go', 62),
#  ('works', 62),
#  ('powerpoint', 62),
#  ('asset', 62),
#  ('effectiveness', 62),
#  ('queries', 62),
#  ('major', 61),
#  ('meaningful', 61),
#  ('directly', 61),
#  ('necessary', 61),
#  ('possess', 61),
#  ('prototypes', 61),
#  ('401k', 61),
#  ('transform', 61),
#  ('stata', 61),
#  ('exploratory', 61),
#  ('ways', 61),
#  ('proactively', 61),
#  ('developers', 60),
#  ('command', 60),
#  ('clinical', 60),
#  ('execution', 60),
#  ('creation', 60),
#  ('overall', 60),
#  ('campaign', 60),
#  ('integrate', 60),
#  ('deadlines', 60),
#  ('public', 60),
#  ('creativity', 60),
#  ('presenting', 60),
#  ('mentor', 60),
#  ('changes', 60),
#  ('scipy', 60),
#  ('volume', 60),
#  ('volumes', 60),
#  ('chain', 59),
#  ('hdfs', 59),
#  ('inference', 59),
#  ('transformation', 59),
#  ('clean', 59),
#  ('additional', 59),
#  ('prioritize', 59),
#  ('member', 59),
#  ('pricing', 58),
#  ('engage', 58),
#  ('site', 58),
#  ('integrity', 58),
#  ('depth', 58),
#  ('starter', 58),
#  ('university', 58),
#  ('employer', 58),
#  ('credit', 58),
#  ('matter', 58),
#  ('policy', 58),
#  ('cassandra', 58),
#  ('account', 58),
#  ('industries', 58),
#  ('hypotheses', 58),
#  ('via', 57),
#  ('attitude', 57),
#  ('willing', 57),
#  ('compensation', 57),
#  ('strongly', 57),
#  ('things', 56),
#  ('standard', 56),
#  ('comfort', 56),
#  ('emerging', 56),
#  ('modern', 56),
#  ('deployment', 56),
#  ('ecosystem', 56),
#  ('demand', 56),
#  ('junior', 56),
#  ('automated', 56),
#  ('san', 55),
#  ('rapidly', 55),
#  ('another', 55),
#  ('control', 55),
#  ('equity', 55),
#  ('broad', 55),
#  ('resume', 55),
#  ('answering', 55),
#  ('common', 55),
#  ('discovery', 55),
#  ('revenue', 55),
#  ('determine', 55),
#  ('markets', 55),
#  ('rapid', 55),
#  ('willingness', 54),
#  ('prototyping', 54),
#  ('studies', 54),
#  ('towards', 54),
#  ('communications', 54),
#  ('answer', 54),
#  ('cleaning', 54),
#  ('executives', 54),
#  ('regular', 54),
#  ('varying', 54),
#  ('limited', 54),
#  ('theory', 54),
#  ('review', 54),
#  ('interact', 54),
#  ('discover', 53),
#  ('experiment', 53),
#  ('targeting', 53),
#  ('tests', 53),
#  ('unsupervised', 53),
#  ('libraries', 53),
#  ('re', 52),
#  ('conceptual', 52),
#  ('love', 52),
#  ('maintaining', 52),
#  ('jobid', 52),
#  ('sense', 52),
#  ('stack', 52),
#  ('info', 52),
#  ('thought', 52),
#  ('experts', 52),
#  ('weka', 52),
#  ('dimensional', 52),
#  ('acquisition', 51),
#  ('improving', 51),
#  ('clearance', 51),
#  ('manipulate', 51),
#  ('engines', 51),
#  ('rules', 51),
#  ('utilize', 51),
#  ('listing', 51),
#  ('pay', 51),
#  ('consistent', 51),
#  ('cyber', 51),
#  ('millions', 51),
#  ('leader', 51),
#  ('independent', 50),
#  ('produce', 50),
#  ('increase', 50),
#  ('employee', 50),
#  ('active', 50),
#  ('dealing', 50),
#  ('continuous', 50),
#  ('semi', 50),
#  ('proof', 50),
#  ('description', 50),
#  ('pre', 50),
#  ('without', 50),
#  ('essential', 50),
#  ('tech', 49),
#  ('curious', 49),
#  ('going', 49),
#  ('colleagues', 49),
#  ('kenntnisse', 49),
#  ('cs', 49),
#  ('website', 49),
#  ('recruiter', 49),
#  ('daily', 49),
#  ('portfolio', 49),
#  ('games', 49),
#  ('given', 49),
#  ('mission', 49),
#  ('defining', 49),
#  ('prototype', 48),
#  ('timely', 48),
#  ('next', 48),
#  ('topic', 48),
#  ('space', 48),
#  ('coverage', 48),
#  ('develops', 48),
#  ('smart', 48),
#  ('suite', 48),
#  ('aws', 48),
#  ('manager', 48),
#  ('behavioral', 48),
#  ('algorithmic', 48),
#  ('leads', 48),
#  ('example', 47),
#  ('previous', 47),
#  ('individuals', 47),
#  ('proactive', 47),
#  ('ideally', 47),
#  ('crm', 47),
#  ('empirical', 47),
#  ('machines', 47),
#  ('svm', 47),
#  ('requires', 47),
#  ('disability', 47),
#  ('trading', 47),
#  ('predict', 47),
#  ('gathering', 47),
#  ('amazon', 47),
#  ('capital', 47),
#  ('sentiment', 47),
#  ('banking', 47),
#  ('shell', 47),
#  ('automation', 47),
#  ('vacation', 46),
#  ('hours', 46),
#  ('word', 46),
#  ('php', 46),
#  ('forests', 46),
#  ('live', 46),
#  ('benefit', 46),
#  ('maintenance', 46),
#  ('structure', 46),
#  ('efficiency', 46),
#  ('youre', 46),
#  ('important', 46),
#  ('20', 46),
#  ('point', 46),
#  ('selection', 46),
#  ('brand', 46),
#  ('expected', 46),
#  ('several', 46),
#  ('ideal', 46),
#  ('donnes', 46),
#  ('z', 46),
#  ('educate', 45),
#  ('deliverables', 45),
#  ('many', 45),
#  ('detailed', 45),
#  ('comprehensive', 45),
#  ('conclusions', 45),
#  ('integrating', 45),
#  ('bring', 45),
#  ('campaigns', 45),
#  ('completion', 45),
#  ('electrical', 45),
#  ('party', 45),
#  ('curiosity', 45),
#  ('acumen', 45),
#  ('applicable', 45),
#  ('equal', 45),
#  ('compelling', 45),
#  ('serve', 45),
#  ('behaviors', 45),
#  ('bereich', 45),
#  ('local', 45),
#  ('miner', 45),
#  ('feedback', 44),
#  ('dimensionality', 44),
#  ('aspects', 44),
#  ('bioinformatics', 44),
#  ('measurement', 44),
#  ('youll', 44),
#  ('cost', 44),
#  ('accurate', 44),
#  ('first', 44),
#  ('responsibility', 44),
#  ('stock', 44),
#  ('administration', 44),
#  ('huge', 44),
#  ('context', 44),
#  ('unit', 43),
#  ('commerce', 43),
#  ('sap', 43),
#  ('continuously', 43),
#  ('experiences', 43),
#  ('000', 43),
#  ('run', 43),
#  ('demonstrable', 43),
#  ('recommend', 43),
#  ('human', 43),
#  ('grow', 43),
#  ('exploration', 43),
#  ('latest', 43),
#  ('particular', 43),
#  ('qualified', 43),
#  ('includes', 43),
#  ('higher', 43),
#  ('usage', 43),
#  ('logical', 42),
#  ('disparate', 42),
#  ('department', 42),
#  ('iquest', 42),
#  ('skill', 42),
#  ('articulate', 42),
#  ('vector', 42),
#  ('mine', 42),
#  ('study', 42),
#  ('form', 42),
#  ('interesting', 42),
#  ('channel', 42),
#  ('association', 42),
#  ('interactive', 42),
#  ('extremely', 42),
#  ('place', 42),
#  ('outside', 42),
#  ('personalization', 42),
#  ('positive', 41),
#  ('derive', 41),
#  ('massive', 41),
#  ('handle', 41),
#  ('architectures', 41),
#  ('francisco', 41),
#  ('keen', 41),
#  ('personal', 41),
#  ('js', 41),
#  ('ongoing', 41),
#  ('built', 41),
#  ('entwicklung', 41),
#  ('parallel', 41),
#  ('filtering', 41),
#  ('streaming', 41),
#  ('proprietary', 41),
#  ('types', 40),
#  ('engineer', 40),
#  ('channels', 40),
#  ('corporate', 40),
#  ('tracking', 40),
#  ('w', 40),
#  ('reliable', 40),
#  ...]

# %%
df_cities = pd.read_csv("../data/us_cities.csv", sep = '|', error_bad_lines=False)

# %%
df_cities.rename(columns ={"Holtsville" : 'city', 'NY' : 'state', 'New York' : 'statefull', 'SUFFOLK' : "county"}, inplace=True)

# %%
df_cities = pd.read_csv('../data/usa_cities.csv')
df_cities['city'] = df_cities['city'].apply(lambda x: x.lower())
df_cities = df_cities.drop(['Unnamed: 0', 'Internal Revenue Service,', 'County'], axis=1)

# %%
df_cities = df_cities.drop_duplicates('city')

# %%
df_cities.to_csv('../data/us_cities.csv')

# %%
from langdetect import detect

# %%
detect("results understand responsibilities applications improve key based experiments")
# Out:
# u'en'

# %%
datascience_desc = ['''Identifies unique opportunities to collect new data and mine existing data. Experience in disparate data sources and bridging 
various sources to create a market view that can be used as a proprietary source of market data. Experienced 
at leveraging both structured and unstructured data sources. Responsible for validation, quality control and 
integration of 3rd party data into systems ensuring cohesive, accurate reporting Designs new processes and is
able to build large, complex data sets. Strategises new uses for data and its interaction with data design using 
a variety of techniques and applications across various data sources. Minimum 2-3 years experience supporting multiple 
business functions, preferably progressive responsibilities within an established analytics team across Enterprise 
Projects. Masters or other advanced degree in Statistics, Mathematics or a related quantitative discipline Experience
with statistical methodologies and tools (R, SAS, SPSS, etc) and predictive modeling Experience with data 
visualisation tools such as Tableau and Qlikview Advanced knowledge of database technologies and SQL language 
for querying and manipulating datasets. Extensive exposure to data warehousing concepts including data integration
and data warehouse objects. Ability to understand and apply data and data relationships across multiple sources and 
domains Excellent communication, and presentation skills a must. The ability to bridge the gap between data science
and business management. Possesses both creative abilities and business knowledge. Ability to work under pressure and 
meet deadlines. Has strong organisational skills, is detail oriented, and a team player Someone with strong foundation
in statistics and advanced marketing analytics.''']

# %%
# Out:
# -2.2204460492503131e-16

# %%
v_input = vectorizer.transform(datascience_desc).todense()
cos = [] 

df['cosine_similarity'] = map(lambda x: cosine(x, v_input), v_job_desc)

df=df.sort_values('cosine_similarity')
df.[1]
# Out:
# 'Identifies unique opportunities to collect new data and mine existing data. Experience in disparate data sources and bridging various sources to create a market view that can be used as a proprietary source of market data. Experienced at leveraging both structured and unstructured data sources. Responsible for validation, quality control and integration of 3rd party data into systems ensuring cohesive, accurate reporting Designs new processes and is able to build large, complex data sets. Strategises new uses for data and its interaction with data design using a variety of techniques and applications across various data sources. Minimum 2-3 years experience supporting multiple business functions, preferably progressive responsibilities within an established analytics team across Enterprise Projects. Masters or other advanced degree in Statistics, Mathematics or a related quantitative discipline Experience with statistical methodologies and tools (R, SAS, SPSS, etc) and predictive modeling Experience with data visualisation tools such as Tableau and Qlikview Advanced knowledge of database technologies and SQL language for querying and manipulating datasets. Extensive exposure to data warehousing concepts including data integration and data warehouse objects. Ability to understand and apply data and data relationships across multiple sources and domains Excellent communication, and presentation skills a must. The ability to bridge the gap between data science and business management. Possesses both creative abilities and business knowledge. Ability to work under pressure and meet deadlines. Has strong organisational skills, is detail oriented, and a team player Someone with strong foundation in statistics and advanced marketing analytics.'

# %%
for i in xrange()
# Out:
# (1322, 10595)
# 10595
# 1322

# %%
describe_results(v_job_desc, nmf_weights, nmf_features)
# Out:
# Topic number:0
# data business analysis analytics sources sql reporting tools experience ability quality statistical database modeling sas sets develop advanced requirements skills models identify analytical excel tableau information understand management processes reports using knowledge work complex stakeholders large analyst techniques insights bi etl create warehouse needs big process analytic new analyze provide intelligence communicate warehousing multiple visualization mining degree use predictive strong interpret databases microsoft working issues ensure analyses statistics support users internal trends end solutions integration define queries understanding problem key team decisions hoc required organization metrics perform drive quantitative various including design results cleansing analysts systems teams transformation findings preferred
# **********************
# Topic number:1
# sales marketing client business clients customer analytics relationships team product digital media management teams solutions opportunities selling account new work key ability experience industry manage campaign customers build drive accounts strong revenue products partners campaigns advertising working managing track value salesforce deliver level technology company understanding online senior skills insights solution proven ensure support services ad strategic channel strategy develop performance market partner strategies executives success events enterprise executive mobile com operations building lead direct service role consulting day agency best engagement presentations delivery record projects time internal fast technical driven high provide web plan adobe including levels stakeholders development
# **********************
# Topic number:2
# learning machine experience science statistics data statistical python modeling research mining algorithms computer models mathematics analysis techniques predictive programming quantitative engineering phd problems language strong large field matlab applied plus product ability analytics degree skills analytical work java advanced related regression years languages optimization sas knowledge datasets methods spark hadoop tools new masters physics scikit using operations sets nlp math model following solving insights real preferred ph complex relevant retrieval working natural academic clustering scale processing world develop series proficiency hive sql problem modelling background engineers deep scala team mathematical economics including time learn analyses familiarity similar like visualization scipy
# **********************
# Topic number:3
# skills ability experience project development technical management work scientific support research analysis demonstrated design clinical knowledge communication strong required related team including process reports excellent regulatory years projects provide analytical environment chemistry systems written business preferred information software results quality requirements procedures cell internal processes issues problem multiple relevant effectively ensure functional laboratory verbal external methods application manage ms high field studies degree health biology documentation new solving experimental industry applications product testing review maintain study leadership perform writing cross drug develop training food expertise working activities database independently interpersonal assist bioinformatics based minimum critical technology highly solutions compliance oral
# **********************
# Topic number:4
# experience hadoop data big technologies development systems software java design years hive spark distributed working architecture solutions processing cloud computer pig strong science knowledge scale platform nosql mapreduce web sql understanding linux tools python engineering hbase hands building like agile etl plus source open aws technical developing environment code infrastructure frameworks scalable skills programming production storm using scripting kafka performance bs work unix ecosystem large databases integration build applications scala cassandra storage excellent related services languages implementation platforms team hdfs end solid application environments expert relational database designing good communication implement technology high real amazon testing oriented warehouse oracle mysql
# **********************

# %%
similarity = cosine_similarity(v_job_desc, v_input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-d8ddde0dd8e5> in <module>()
# ----> 1 similarity = cosine_similarity(v_job_desc, v_input)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in cosine_similarity(X, Y, dense_output)
#     879     # to avoid recursive import
#     880
# --> 881     X, Y = check_pairwise_arrays(X, Y)
#     882
#     883     X_normalized = normalize(X, copy=True)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in check_pairwise_arrays(X, Y, precomputed)
#     106         raise ValueError("Incompatible dimension for X and Y matrices: "
#     107                          "X.shape[1] == %d while Y.shape[1] == %d" % (
# --> 108                              X.shape[1], Y.shape[1]))
#     109
#     110     return X, Y
#
# ValueError: Incompatible dimension for X and Y matrices: X.shape[1] == 10595 while Y.shape[1] == 58

# %%
df2 = pd.read_csv('data/zip_data2')
df = df[df['job_description'] != '[]']

# %%
from bs4 import BeautifulSoup
import re
import requests
from time import sleep
from nltk.corpus import stopwords
import pandas as pd
import os
import numpy as np
from selenium import webdriver
import sys

# %%
def scrapying_selenium(url):
    headers = {"User-agent":"Mozilla/5.0 (X11; Linux x86_64) AppñleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36"}
    browser = webdriver.Chrome("/Applications/chromedriver")
    browser.set_page_load_timeout(5)
    browser.get(url) #Connects to Website
    soup = BeautifulSoup(browser.page_source)# Get the html from the site
    browser.quit()
    return soup

# %%
def cleaning_site(website):
    soup = scrapying_selenium(website)
    job_descriptions = soup.findAll('div', class_="rich-text")
    jobs_desc =[]
    for job_description in job_descriptions:
        for job in job_description.findAll('li'):
            jobs_desc.append(job.text)
    return jobs_desc

# %%
page = 49
x = indeed_url + '&start=' + str((page-1)*10)

# %%
indeed_url = 'http://www.indeed.com/jobs?q=' + 'data+scientist' + '&l='

# %%
10%9
# Out:
# 1

# %%
10%11
# Out:
# 10

# %%
32%10
# Out:
# 2

# %%
documents = (
"The sky is blue",
"The sun is bright",
"The sun in the sky is bright",
"We can see the shining sun, the bright sun"
)

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
print tfidf_matrix.shape
# Out:
# (4, 11)

# %%
cosine_similarity(tfidf_matrix[0:1], tfidf_matrix)
# Out:
# array([[ 1.        ,  0.36651513,  0.52305744,  0.13448867]])

# %%
tfidf_matrix[0:1]
# Out:
# <1x11 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>

# %%
code = 'AF|AX|AL|DZ|AS|AD|AO|AI|AQ|AG|AR|AM|AW|AU|AT|AZ|BS|BH|BD|BB|BY|BE|BZ|BJ|BM|BT|BO|BA|BW|BV|BR|IO|BN|BG|BF|BI|KH|CM|CA|CV|KY|CF|TD|CL|CN|CX|CC|CO|KM|CG|CD|CK|CR|CI|HR|CU|CY|CZ|DK|DJ|DM|DO|EC|EG|SV|GQ|ER|EE|ET|FK|FO|FJ|FI|FR|GF|PF|TF|GA|GM|GE|DE|GH|GI|GR|GL|GD|GP|GU|GT|GN|GW|GY|HT|HM|VA|HN|HK|HU|IS|IN|ID|IR|IQ|IE|IL|IT|JM|JP|JO|KZ|KE|KI|KP|KR|KW|KG|LA|LV|LB|LS|LR|LY|LI|LT|LU|MO|MK|MG|MW|MY|MV|ML|MT|MH|MQ|MR|MU|YT|MX|FM|MD|MC|MN|MS|MA|MZ|MM|NA|NR|NP|NL|AN|NC|NZ|NI|NE|NG|NU|NF|MP|NO|OM|PK|PW|PS|PA|PG|PY|PE|PH|PN|PL|PT|PR|QA|RE|RO|RU|RW|SH|KN|LC|PM|VC|WS|SM|ST|SA|SN|CS|SC|SL|SG|SK|SI|SB|SO|ZA|GS|ES|LK|SD|SR|SJ|SZ|SE|CH|SY|TW|TJ|TZ|TH|TL|TG|TK|TO|TT|TN|TR|TM|TC|TV|UG|UA|AE|GB|US|UM|UY|UZ|VU|VE|VN|VG|VI|WF|EH|YE|ZM|ZW'

# %%
code = str.lower(code)
code2 = str.replace(code, '|', '\',\'')

# %%
code2 = ['af','ax','al','dz','as','ad','ao','ai','aq','ag','ar','am','aw','au','at','az','bs','bh','bd','bb','by','be','bz','bj','bm','bt','bo','ba','bw','bv','br','io','bn','bg','bf','bi','kh','cm','ca','cv','ky','cf','td','cl','cn','cx','cc','co','km','cg','cd','ck','cr','ci','hr','cu','cy','cz','dk','dj','dm','do','ec','eg','sv','gq','er','ee','et','fk','fo','fj','fi','fr','gf','pf','tf','ga','gm','ge','de','gh','gi','gr','gl','gd','gp','gu','gt','gn','gw','gy','ht','hm','va','hn','hk','hu','is','in','id','ir','iq','ie','il','it','jm','jp','jo','kz','ke','ki','kp','kr','kw','kg','la','lv','lb','ls','lr','ly','li','lt','lu','mo','mk','mg','mw','my','mv','ml','mt','mh','mq','mr','mu','yt','mx','fm','md','mc','mn','ms','ma','mz','mm','na','nr','np','nl','an','nc','nz','ni','ne','ng','nu','nf','mp','no','om','pk','pw','ps','pa','pg','py','pe','ph','pn','pl','pt','pr','qa','re','ro','ru','rw','sh','kn','lc','pm','vc','ws','sm','st','sa','sn','cs','sc','sl','sg','sk','si','sb','so','za','gs','es','lk','sd','sr','sj','sz','se','ch','sy','tw','tj','tz','th','tl','tg','tk','to','tt','tn','tr','tm','tc','tv','ug','ua','ae','gb','us','um','uy','uz','vu','ve','vn','vg','vi','wf','eh','ye','zm','zw']

# %%
code2
# Out:
# ['af',
#  'ax',
#  'al',
#  'dz',
#  'as',
#  'ad',
#  'ao',
#  'ai',
#  'aq',
#  'ag',
#  'ar',
#  'am',
#  'aw',
#  'au',
#  'at',
#  'az',
#  'bs',
#  'bh',
#  'bd',
#  'bb',
#  'by',
#  'be',
#  'bz',
#  'bj',
#  'bm',
#  'bt',
#  'bo',
#  'ba',
#  'bw',
#  'bv',
#  'br',
#  'io',
#  'bn',
#  'bg',
#  'bf',
#  'bi',
#  'kh',
#  'cm',
#  'ca',
#  'cv',
#  'ky',
#  'cf',
#  'td',
#  'cl',
#  'cn',
#  'cx',
#  'cc',
#  'co',
#  'km',
#  'cg',
#  'cd',
#  'ck',
#  'cr',
#  'ci',
#  'hr',
#  'cu',
#  'cy',
#  'cz',
#  'dk',
#  'dj',
#  'dm',
#  'do',
#  'ec',
#  'eg',
#  'sv',
#  'gq',
#  'er',
#  'ee',
#  'et',
#  'fk',
#  'fo',
#  'fj',
#  'fi',
#  'fr',
#  'gf',
#  'pf',
#  'tf',
#  'ga',
#  'gm',
#  'ge',
#  'de',
#  'gh',
#  'gi',
#  'gr',
#  'gl',
#  'gd',
#  'gp',
#  'gu',
#  'gt',
#  'gn',
#  'gw',
#  'gy',
#  'ht',
#  'hm',
#  'va',
#  'hn',
#  'hk',
#  'hu',
#  'is',
#  'in',
#  'id',
#  'ir',
#  'iq',
#  'ie',
#  'il',
#  'it',
#  'jm',
#  'jp',
#  'jo',
#  'kz',
#  'ke',
#  'ki',
#  'kp',
#  'kr',
#  'kw',
#  'kg',
#  'la',
#  'lv',
#  'lb',
#  'ls',
#  'lr',
#  'ly',
#  'li',
#  'lt',
#  'lu',
#  'mo',
#  'mk',
#  'mg',
#  'mw',
#  'my',
#  'mv',
#  'ml',
#  'mt',
#  'mh',
#  'mq',
#  'mr',
#  'mu',
#  'yt',
#  'mx',
#  'fm',
#  'md',
#  'mc',
#  'mn',
#  'ms',
#  'ma',
#  'mz',
#  'mm',
#  'na',
#  'nr',
#  'np',
#  'nl',
#  'an',
#  'nc',
#  'nz',
#  'ni',
#  'ne',
#  'ng',
#  'nu',
#  'nf',
#  'mp',
#  'no',
#  'om',
#  'pk',
#  'pw',
#  'ps',
#  'pa',
#  'pg',
#  'py',
#  'pe',
#  'ph',
#  'pn',
#  'pl',
#  'pt',
#  'pr',
#  'qa',
#  're',
#  'ro',
#  'ru',
#  'rw',
#  'sh',
#  'kn',
#  'lc',
#  'pm',
#  'vc',
#  'ws',
#  'sm',
#  'st',
#  'sa',
#  'sn',
#  'cs',
#  'sc',
#  'sl',
#  'sg',
#  'sk',
#  'si',
#  'sb',
#  'so',
#  'za',
#  'gs',
#  'es',
#  'lk',
#  'sd',
#  'sr',
#  'sj',
#  'sz',
#  'se',
#  'ch',
#  'sy',
#  'tw',
#  'tj',
#  'tz',
#  'th',
#  'tl',
#  'tg',
#  'tk',
#  'to',
#  'tt',
#  'tn',
#  'tr',
#  'tm',
#  'tc',
#  'tv',
#  'ug',
#  'ua',
#  'ae',
#  'gb',
#  'us',
#  'um',
#  'uy',
#  'uz',
#  'vu',
#  've',
#  'vn',
#  'vg',
#  'vi',
#  'wf',
#  'eh',
#  'ye',
#  'zm',
#  'zw']
